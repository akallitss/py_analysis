# %%
import re
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import griddata
from sklearn.linear_model import LinearRegression
from mpl_toolkits.mplot3d import Axes3D

# %%
##filename = 'Mearure-planarity-PCB-WURTH-Thin.txt'
filename = 'planarity-active-zone.txt'
with open(filename, 'r', encoding='ISO-8859-1') as file:
    lines = file.readlines()

for line in lines: print(line.strip())
# Out:
# Elément            Réel       Val. nom.           Ecart       Tol. sup.       Tol. inf.           OK/HT
# (Dév PR)        (Tol PR)
# Point-1(De 1 pt)
# Coord. X =           20,154
# Coord. Y =          124,239
# Coord. Z =           11,365
#
# Point-2(De 1 pt)
# Coord. X =           22,166
# Coord. Y =          124,239
# Coord. Z =           11,365
#
# PointDeSymétrie-1(De 0 pt)
# Coord. X =           21,160
# Coord. Y =          124,239
# Coord. Z =           11,365
#
# PointDeSymétrie-2(De 0 pt)
# Coord. X =           21,160
# Coord. Y =          124,239
# Coord. Z =           11,365
#
# Distance-1 entre Point-1 et Point-2
# SC =            2,013
#
# Point-4(De 1 pt)
# Coord. X =           18,434
# Coord. Y =          122,910
# Coord. Z =           11,258
#
# Point-5[1,1](De 1 pt)
# Coord. X =            0,001
# Coord. Y =            0,001
# Coord. Z =           -0,001
#
# Point-5[1,2](De 1 pt)
# Coord. X =            0,001
# Coord. Y =           10,001
# Coord. Z =            0,241
#
# Point-5[1,3](De 1 pt)
# Coord. X =            0,001
# Coord. Y =           20,001
# Coord. Z =            0,376
#
# Point-5[1,4](De 1 pt)
# Coord. X =            0,001
# Coord. Y =           30,001
# Coord. Z =            0,462
#
# Point-5[1,5](De 1 pt)
# Coord. X =            0,001
# Coord. Y =           40,001
# Coord. Z =            0,541
#
# Point-5[1,6](De 1 pt)
# Coord. X =            0,001
# Coord. Y =           50,001
# Coord. Z =            0,550
#
# Point-5[1,7](De 1 pt)
# Coord. X =            0,001
# Coord. Y =           60,001
# Coord. Z =            0,536
#
# Point-5[1,8](De 1 pt)
# Coord. X =            0,001
# Coord. Y =           70,001
# Coord. Z =            0,529
#
# Point-5[1,9](De 1 pt)
# Coord. X =            0,001
# Coord. Y =           80,001
# Coord. Z =            0,610
#
# Point-5[1,10](De 1 pt)
# Coord. X =            0,001
# Coord. Y =           90,001
# Coord. Z =            0,729
#
# Point-5[1,11](De 1 pt)
# Coord. X =            0,001
# Coord. Y =          100,001
# Coord. Z =            0,797
#
# Point-5[1,12](De 1 pt)
# Coord. X =            0,001
# Coord. Y =          110,001
# Coord. Z =            0,892
#
# Point-5[1,13](De 1 pt)
# Coord. X =            0,001
# Coord. Y =          120,001
# Coord. Z =            0,879
#
# Point-5[2,1](De 1 pt)
# Coord. X =           10,001
# Coord. Y =            0,001
# Coord. Z =            0,071
#
# Point-5[2,2](De 1 pt)
# Coord. X =           10,001
# Coord. Y =           10,001
# Coord. Z =            0,365
#
# Point-5[2,3](De 1 pt)
# Coord. X =           10,001
# Coord. Y =           20,001
# Coord. Z =            0,502
#
# Point-5[2,4](De 1 pt)
# Coord. X =           10,001
# Coord. Y =           30,001
# Coord. Z =            0,541
#
# Point-5[2,5](De 1 pt)
# Coord. X =           10,001
# Coord. Y =           40,001
# Coord. Z =            0,574
#
# Point-5[2,6](De 1 pt)
# Coord. X =           10,001
# Coord. Y =           50,001
# Coord. Z =            0,576
#
# Point-5[2,7](De 1 pt)
# Coord. X =           10,001
# Coord. Y =           60,001
# Coord. Z =            0,550
#
# Point-5[2,8](De 1 pt)
# Coord. X =           10,001
# Coord. Y =           70,001
# Coord. Z =            0,618
#
# Point-5[2,9](De 1 pt)
# Coord. X =           10,001
# Coord. Y =           80,001
# Coord. Z =            0,599
#
# Point-5[2,10](De 1 pt)
# Coord. X =           10,001
# Coord. Y =           90,001
# Coord. Z =            0,774
#
# Point-5[2,11](De 1 pt)
# Coord. X =           10,001
# Coord. Y =          100,001
# Coord. Z =            0,790
#
# Point-5[2,12](De 1 pt)
# Coord. X =           10,001
# Coord. Y =          110,001
# Coord. Z =            0,860
#
# Point-5[2,13](De 1 pt)
# Coord. X =           10,001
# Coord. Y =          120,001
# Coord. Z =            0,888
#
# Point-5[3,1](De 1 pt)
# Coord. X =           20,001
# Coord. Y =            0,001
# Coord. Z =           -0,019
#
# Point-5[3,2](De 1 pt)
# Coord. X =           20,001
# Coord. Y =           10,001
# Coord. Z =            0,254
#
# Point-5[3,3](De 1 pt)
# Coord. X =           20,001
# Coord. Y =           20,001
# Coord. Z =            0,382
#
# Point-5[3,4](De 1 pt)
# Coord. X =           20,001
# Coord. Y =           30,001
# Coord. Z =            0,387
#
# Point-5[3,5](De 1 pt)
# Coord. X =           20,001
# Coord. Y =           40,001
# Coord. Z =            0,392
#
# Point-5[3,6](De 1 pt)
# Coord. X =           20,001
# Coord. Y =           50,001
# Coord. Z =            0,413
#
# Point-5[3,7](De 1 pt)
# Coord. X =           20,001
# Coord. Y =           60,001
# Coord. Z =            0,418
#
# Point-5[3,8](De 1 pt)
# Coord. X =           20,001
# Coord. Y =           70,001
# Coord. Z =            0,640
#
# Point-5[3,9](De 1 pt)
# Coord. X =           20,001
# Coord. Y =           80,001
# Coord. Z =            0,541
#
# Point-5[3,10](De 1 pt)
# Coord. X =           20,001
# Coord. Y =           90,001
# Coord. Z =            0,799
#
# Point-5[3,11](De 1 pt)
# Coord. X =           20,001
# Coord. Y =          100,001
# Coord. Z =            0,772
#
# Point-5[3,12](De 1 pt)
# Coord. X =           20,001
# Coord. Y =          110,001
# Coord. Z =            0,822
#
# Point-5[3,13](De 1 pt)
# Coord. X =           20,001
# Coord. Y =          120,001
# Coord. Z =            0,909
#
# Point-5[4,1](De 1 pt)
# Coord. X =           30,001
# Coord. Y =            0,001
# Coord. Z =           -0,143
#
# Point-5[4,2](De 1 pt)
# Coord. X =           30,001
# Coord. Y =           10,001
# Coord. Z =            0,060
#
# Point-5[4,3](De 1 pt)
# Coord. X =           30,001
# Coord. Y =           20,001
# Coord. Z =            0,180
#
# Point-5[4,4](De 1 pt)
# Coord. X =           30,001
# Coord. Y =           30,001
# Coord. Z =            0,222
#
# Point-5[4,5](De 1 pt)
# Coord. X =           30,001
# Coord. Y =           40,001
# Coord. Z =            0,252
#
# Point-5[4,6](De 1 pt)
# Coord. X =           30,001
# Coord. Y =           50,001
# Coord. Z =            0,279
#
# Point-5[4,7](De 1 pt)
# Coord. X =           30,001
# Coord. Y =           60,001
# Coord. Z =            0,354
#
# Point-5[4,8](De 1 pt)
# Coord. X =           30,001
# Coord. Y =           70,001
# Coord. Z =            0,635
#
# Point-5[4,9](De 1 pt)
# Coord. X =           30,001
# Coord. Y =           80,001
# Coord. Z =            0,507
#
# Point-5[4,10](De 1 pt)
# Coord. X =           30,001
# Coord. Y =           90,001
# Coord. Z =            0,804
#
# Point-5[4,11](De 1 pt)
# Coord. X =           30,001
# Coord. Y =          100,001
# Coord. Z =            0,751
#
# Point-5[4,12](De 1 pt)
# Coord. X =           30,001
# Coord. Y =          110,001
# Coord. Z =            0,801
#
# Point-5[4,13](De 1 pt)
# Coord. X =           30,001
# Coord. Y =          120,001
# Coord. Z =            0,912
#
# Point-5[5,1](De 1 pt)
# Coord. X =           40,001
# Coord. Y =            0,001
# Coord. Z =           -0,210
#
# Point-5[5,2](De 1 pt)
# Coord. X =           40,001
# Coord. Y =           10,001
# Coord. Z =           -0,055
#
# Point-5[5,3](De 1 pt)
# Coord. X =           40,001
# Coord. Y =           20,001
# Coord. Z =            0,072
#
# Point-5[5,4](De 1 pt)
# Coord. X =           40,001
# Coord. Y =           30,001
# Coord. Z =            0,169
#
# Point-5[5,5](De 1 pt)
# Coord. X =           40,001
# Coord. Y =           40,001
# Coord. Z =            0,224
#
# Point-5[5,6](De 1 pt)
# Coord. X =           40,001
# Coord. Y =           50,001
# Coord. Z =            0,259
#
# Point-5[5,7](De 1 pt)
# Coord. X =           40,001
# Coord. Y =           60,001
# Coord. Z =            0,328
#
# Point-5[5,8](De 1 pt)
# Coord. X =           40,001
# Coord. Y =           70,001
# Coord. Z =            0,624
#
# Point-5[5,9](De 1 pt)
# Coord. X =           40,001
# Coord. Y =           80,001
# Coord. Z =            0,481
#
# Point-5[5,10](De 1 pt)
# Coord. X =           40,001
# Coord. Y =           90,001
# Coord. Z =            0,801
#
# Point-5[5,11](De 1 pt)
# Coord. X =           40,001
# Coord. Y =          100,001
# Coord. Z =            0,732
#
# Point-5[5,12](De 1 pt)
# Coord. X =           40,001
# Coord. Y =          110,001
# Coord. Z =            0,787
#
# Point-5[5,13](De 1 pt)
# Coord. X =           40,001
# Coord. Y =          120,001
# Coord. Z =            0,911
#
# Point-5[6,1](De 1 pt)
# Coord. X =           50,001
# Coord. Y =            0,001
# Coord. Z =           -0,216
#
# Point-5[6,2](De 1 pt)
# Coord. X =           50,001
# Coord. Y =           10,001
# Coord. Z =           -0,078
#
# Point-5[6,3](De 1 pt)
# Coord. X =           50,001
# Coord. Y =           20,001
# Coord. Z =            0,057
#
# Point-5[6,4](De 1 pt)
# Coord. X =           50,001
# Coord. Y =           30,001
# Coord. Z =            0,172
#
# Point-5[6,5](De 1 pt)
# Coord. X =           50,001
# Coord. Y =           40,001
# Coord. Z =            0,228
#
# Point-5[6,6](De 1 pt)
# Coord. X =           50,001
# Coord. Y =           50,001
# Coord. Z =            0,269
#
# Point-5[6,7](De 1 pt)
# Coord. X =           50,001
# Coord. Y =           60,001
# Coord. Z =            0,316
#
# Point-5[6,8](De 1 pt)
# Coord. X =           50,001
# Coord. Y =           70,001
# Coord. Z =            0,609
#
# Point-5[6,9](De 1 pt)
# Coord. X =           50,001
# Coord. Y =           80,001
# Coord. Z =            0,462
#
# Point-5[6,10](De 1 pt)
# Coord. X =           50,001
# Coord. Y =           90,001
# Coord. Z =            0,798
#
# Point-5[6,11](De 1 pt)
# Coord. X =           50,001
# Coord. Y =          100,001
# Coord. Z =            0,716
#
# Point-5[6,12](De 1 pt)
# Coord. X =           50,001
# Coord. Y =          110,001
# Coord. Z =            0,771
#
# Point-5[6,13](De 1 pt)
# Coord. X =           50,001
# Coord. Y =          120,001
# Coord. Z =            0,903
#
# Point-5[7,1](De 1 pt)
# Coord. X =           60,001
# Coord. Y =            0,001
# Coord. Z =           -0,202
#
# Point-5[7,2](De 1 pt)
# Coord. X =           60,001
# Coord. Y =           10,001
# Coord. Z =           -0,070
#
# Point-5[7,3](De 1 pt)
# Coord. X =           60,001
# Coord. Y =           20,001
# Coord. Z =            0,066
#
# Point-5[7,4](De 1 pt)
# Coord. X =           60,001
# Coord. Y =           30,001
# Coord. Z =            0,166
#
# Point-5[7,5](De 1 pt)
# Coord. X =           60,001
# Coord. Y =           40,001
# Coord. Z =            0,220
#
# Point-5[7,6](De 1 pt)
# Coord. X =           60,001
# Coord. Y =           50,001
# Coord. Z =            0,263
#
# Point-5[7,7](De 1 pt)
# Coord. X =           60,001
# Coord. Y =           60,001
# Coord. Z =            0,314
#
# Point-5[7,8](De 1 pt)
# Coord. X =           60,001
# Coord. Y =           70,001
# Coord. Z =            0,587
#
# Point-5[7,9](De 1 pt)
# Coord. X =           60,001
# Coord. Y =           80,001
# Coord. Z =            0,452
#
# Point-5[7,10](De 1 pt)
# Coord. X =           60,001
# Coord. Y =           90,001
# Coord. Z =            0,784
#
# Point-5[7,11](De 1 pt)
# Coord. X =           60,001
# Coord. Y =          100,001
# Coord. Z =            0,709
#
# Point-5[7,12](De 1 pt)
# Coord. X =           60,001
# Coord. Y =          110,001
# Coord. Z =            0,768
#
# Point-5[7,13](De 1 pt)
# Coord. X =           60,001
# Coord. Y =          120,001
# Coord. Z =            0,864
#
# Point-5[8,1](De 1 pt)
# Coord. X =           70,001
# Coord. Y =            0,001
# Coord. Z =           -0,187
#
# Point-5[8,2](De 1 pt)
# Coord. X =           70,001
# Coord. Y =           10,001
# Coord. Z =           -0,070
#
# Point-5[8,3](De 1 pt)
# Coord. X =           70,001
# Coord. Y =           20,001
# Coord. Z =            0,059
#
# Point-5[8,4](De 1 pt)
# Coord. X =           70,001
# Coord. Y =           30,001
# Coord. Z =            0,149
#
# Point-5[8,5](De 1 pt)
# Coord. X =           70,001
# Coord. Y =           40,001
# Coord. Z =            0,198
#
# Point-5[8,6](De 1 pt)
# Coord. X =           70,001
# Coord. Y =           50,001
# Coord. Z =            0,242
#
# Point-5[8,7](De 1 pt)
# Coord. X =           70,001
# Coord. Y =           60,001
# Coord. Z =            0,302
#
# Point-5[8,8](De 1 pt)
# Coord. X =           70,001
# Coord. Y =           70,001
# Coord. Z =            0,553
#
# Point-5[8,9](De 1 pt)
# Coord. X =           70,001
# Coord. Y =           80,001
# Coord. Z =            0,453
#
# Point-5[8,10](De 1 pt)
# Coord. X =           70,001
# Coord. Y =           90,001
# Coord. Z =            0,761
#
# Point-5[8,11](De 1 pt)
# Coord. X =           70,001
# Coord. Y =          100,001
# Coord. Z =            0,711
#
# Point-5[8,12](De 1 pt)
# Coord. X =           70,001
# Coord. Y =          110,001
# Coord. Z =            0,765
#
# Point-5[8,13](De 1 pt)
# Coord. X =           70,001
# Coord. Y =          120,001
# Coord. Z =            0,782
#
# Point-5[9,1](De 1 pt)
# Coord. X =           80,001
# Coord. Y =            0,001
# Coord. Z =           -0,178
#
# Point-5[9,2](De 1 pt)
# Coord. X =           80,001
# Coord. Y =           10,001
# Coord. Z =           -0,068
#
# Point-5[9,3](De 1 pt)
# Coord. X =           80,001
# Coord. Y =           20,001
# Coord. Z =            0,052
#
# Point-5[9,4](De 1 pt)
# Coord. X =           80,001
# Coord. Y =           30,001
# Coord. Z =            0,127
#
# Point-5[9,5](De 1 pt)
# Coord. X =           80,001
# Coord. Y =           40,001
# Coord. Z =            0,176
#
# Point-5[9,6](De 1 pt)
# Coord. X =           80,001
# Coord. Y =           50,001
# Coord. Z =            0,218
#
# Point-5[9,7](De 1 pt)
# Coord. X =           80,001
# Coord. Y =           60,001
# Coord. Z =            0,277
#
# Point-5[9,8](De 1 pt)
# Coord. X =           80,001
# Coord. Y =           70,001
# Coord. Z =            0,513
#
# Point-5[9,9](De 1 pt)
# Coord. X =           80,001
# Coord. Y =           80,001
# Coord. Z =            0,458
#
# Point-5[9,10](De 1 pt)
# Coord. X =           80,001
# Coord. Y =           90,001
# Coord. Z =            0,739
#
# Point-5[9,11](De 1 pt)
# Coord. X =           80,001
# Coord. Y =          100,001
# Coord. Z =            0,713
#
# Point-5[9,12](De 1 pt)
# Coord. X =           80,001
# Coord. Y =          110,001
# Coord. Z =            0,757
#
# Point-5[9,13](De 1 pt)
# Coord. X =           80,001
# Coord. Y =          120,001
# Coord. Z =            0,730
#
# Point-5[10,1](De 1 pt)
# Coord. X =           90,001
# Coord. Y =            0,001
# Coord. Z =           -0,151
#
# Point-5[10,2](De 1 pt)
# Coord. X =           90,001
# Coord. Y =           10,001
# Coord. Z =           -0,051
#
# Point-5[10,3](De 1 pt)
# Coord. X =           90,001
# Coord. Y =           20,001
# Coord. Z =            0,041
#
# Point-5[10,4](De 1 pt)
# Coord. X =           90,001
# Coord. Y =           30,001
# Coord. Z =            0,101
#
# Point-5[10,5](De 1 pt)
# Coord. X =           90,001
# Coord. Y =           40,001
# Coord. Z =            0,143
#
# Point-5[10,6](De 1 pt)
# Coord. X =           90,001
# Coord. Y =           50,001
# Coord. Z =            0,194
#
# Point-5[10,7](De 1 pt)
# Coord. X =           90,001
# Coord. Y =           60,001
# Coord. Z =            0,243
#
# Point-5[10,8](De 1 pt)
# Coord. X =           90,001
# Coord. Y =           70,001
# Coord. Z =            0,481
#
# Point-5[10,9](De 1 pt)
# Coord. X =           90,001
# Coord. Y =           80,001
# Coord. Z =            0,447
#
# Point-5[10,10](De 1 pt)
# Coord. X =           90,001
# Coord. Y =           90,001
# Coord. Z =            0,743
#
# Point-5[10,11](De 1 pt)
# Coord. X =           90,001
# Coord. Y =          100,001
# Coord. Z =            0,708
#
# Point-5[10,12](De 1 pt)
# Coord. X =           90,001
# Coord. Y =          110,001
# Coord. Z =            0,748
#
# Point-5[10,13](De 1 pt)
# Coord. X =           90,001
# Coord. Y =          120,001
# Coord. Z =            0,691
#
# Point-5[11,1](De 1 pt)
# Coord. X =          100,001
# Coord. Y =            0,001
# Coord. Z =           -0,127
#
# Point-5[11,2](De 1 pt)
# Coord. X =          100,001
# Coord. Y =           10,001
# Coord. Z =           -0,049
#
# Point-5[11,3](De 1 pt)
# Coord. X =          100,001
# Coord. Y =           20,001
# Coord. Z =            0,017
#
# Point-5[11,4](De 1 pt)
# Coord. X =          100,001
# Coord. Y =           30,001
# Coord. Z =            0,066
#
# Point-5[11,5](De 1 pt)
# Coord. X =          100,001
# Coord. Y =           40,001
# Coord. Z =            0,111
#
# Point-5[11,6](De 1 pt)
# Coord. X =          100,001
# Coord. Y =           50,001
# Coord. Z =            0,161
#
# Point-5[11,7](De 1 pt)
# Coord. X =          100,001
# Coord. Y =           60,001
# Coord. Z =            0,202
#
# Point-5[11,8](De 1 pt)
# Coord. X =          100,001
# Coord. Y =           70,001
# Coord. Z =            0,441
#
# Point-5[11,9](De 1 pt)
# Coord. X =          100,001
# Coord. Y =           80,001
# Coord. Z =            0,444
#
# Point-5[11,10](De 1 pt)
# Coord. X =          100,001
# Coord. Y =           90,001
# Coord. Z =            0,746
#
# Point-5[11,11](De 1 pt)
# Coord. X =          100,001
# Coord. Y =          100,001
# Coord. Z =            0,701
#
# Point-5[11,12](De 1 pt)
# Coord. X =          100,001
# Coord. Y =          110,001
# Coord. Z =            0,737
#
# Point-5[11,13](De 1 pt)
# Coord. X =          100,001
# Coord. Y =          120,001
# Coord. Z =            0,651
#
# Point-5[12,1](De 1 pt)
# Coord. X =          110,001
# Coord. Y =            0,001
# Coord. Z =           -0,114
#
# Point-5[12,2](De 1 pt)
# Coord. X =          110,001
# Coord. Y =           10,001
# Coord. Z =           -0,072
#
# Point-5[12,3](De 1 pt)
# Coord. X =          110,001
# Coord. Y =           20,001
# Coord. Z =           -0,014
#
# Point-5[12,4](De 1 pt)
# Coord. X =          110,001
# Coord. Y =           30,001
# Coord. Z =            0,036
#
# Point-5[12,5](De 1 pt)
# Coord. X =          110,001
# Coord. Y =           40,001
# Coord. Z =            0,080
#
# Point-5[12,6](De 1 pt)
# Coord. X =          110,001
# Coord. Y =           50,001
# Coord. Z =            0,124
#
# Point-5[12,7](De 1 pt)
# Coord. X =          110,001
# Coord. Y =           60,001
# Coord. Z =            0,177
#
# Point-5[12,8](De 1 pt)
# Coord. X =          110,001
# Coord. Y =           70,001
# Coord. Z =            0,394
#
# Point-5[12,9](De 1 pt)
# Coord. X =          110,001
# Coord. Y =           80,001
# Coord. Z =            0,453
#
# Point-5[12,10](De 1 pt)
# Coord. X =          110,001
# Coord. Y =           90,001
# Coord. Z =            0,734
#
# Point-5[12,11](De 1 pt)
# Coord. X =          110,001
# Coord. Y =          100,001
# Coord. Z =            0,701
#
# Point-5[12,12](De 1 pt)
# Coord. X =          110,001
# Coord. Y =          110,001
# Coord. Z =            0,720
#
# Point-5[12,13](De 1 pt)
# Coord. X =          110,001
# Coord. Y =          120,001
# Coord. Z =            0,657
#
# Point-5[13,1](De 1 pt)
# Coord. X =          120,001
# Coord. Y =            0,001
# Coord. Z =           -0,086
#
# Point-5[13,2](De 1 pt)
# Coord. X =          120,001
# Coord. Y =           10,001
# Coord. Z =           -0,062
#
# Point-5[13,3](De 1 pt)
# Coord. X =          120,001
# Coord. Y =           20,001
# Coord. Z =           -0,028
#
# Point-5[13,4](De 1 pt)
# Coord. X =          120,001
# Coord. Y =           30,001
# Coord. Z =            0,008
#
# Point-5[13,5](De 1 pt)
# Coord. X =          120,001
# Coord. Y =           40,001
# Coord. Z =            0,055
#
# Point-5[13,6](De 1 pt)
# Coord. X =          120,001
# Coord. Y =           50,001
# Coord. Z =            0,100
#
# Point-5[13,7](De 1 pt)
# Coord. X =          120,001
# Coord. Y =           60,001
# Coord. Z =            0,157
#
# Point-5[13,8](De 1 pt)
# Coord. X =          120,001
# Coord. Y =           70,001
# Coord. Z =            0,342
#
# Point-5[13,9](De 1 pt)
# Coord. X =          120,001
# Coord. Y =           80,001
# Coord. Z =            0,467
#
# Point-5[13,10](De 1 pt)
# Coord. X =          120,001
# Coord. Y =           90,001
# Coord. Z =            0,710
#
# Point-5[13,11](De 1 pt)
# Coord. X =          120,001
# Coord. Y =          100,001
# Coord. Z =            0,705
#
# Point-5[13,12](De 1 pt)
# Coord. X =          120,001
# Coord. Y =          110,001
# Coord. Z =            0,704
#
# Point-5[13,13](De 1 pt)
# Coord. X =          120,001
# Coord. Y =          120,001
# Coord. Z =            0,646
#
# Plan-1(De 174 pt)
# Coord. X =           58,340
# Coord. Y =           58,307
# Coord. Z =            0,390
# Angle (XY) =          -73,113
# Angle X =           89,865
# Angle Y =           90,444
# Angle Z =            0,464
# Planéité =                                            0,486
# Plan. min =                                            0,192
# Plan. max =                                            0,295

# %%
# Initialize variables to store point IDs and corresponding coordinates
point_data = []

# Regular expressions to match point ID and coordinate lines
point_id_pattern = r'\[([\d,]+)\]'
coord_pattern = r'Coord\. ([XYZ]) =\s*([-+]?\d+,\d+)'

# Extract point IDs and coordinates from lines
current_point_id = None
current_coords = {}

skipped_lines = 0
for line in lines:
    if skipped_lines < 3 and not line.startswith('Plan'):
        skipped_lines += 1
        continue
    elif line.startswith('Plan'):
        break
    # Check if the line contains a point ID
    match_id = re.search(point_id_pattern, line)
    if match_id:
        current_point_id = match_id.group(1)
        current_coords = {}
        continue

    # Check if the line contains a coordinate
    match_coord = re.search(coord_pattern, line)
    if match_coord and current_point_id:
        coord_type = match_coord.group(1)
        coord_value = float(match_coord.group(2).replace(',', '.'))
        
        # Check if the Y coordinate is not equal to 0.002
        if coord_type == 'Y' and coord_value == 0.002:
            continue  # Skip this coordinate
        if coord_type == 'X' and coord_value == 0.0 and coord_type == 'Y' and coord_value == 50.0: 
            continue
        if coord_type == 'X' and coord_value == 80.0:
            if coord_type == 'Y' and coord_value == 20.0:
                continue
        current_coords[coord_type] = coord_value

        # If all coordinates are found, add them to the point data
        if len(current_coords) == 3 and current_coords['Y']>0 :# and current_coords['X'] == 150. and current_coords['Y'] == 150.:
        #if len(current_coords) == 3 and current_coords['X']>70.0 and current_coords['Y']<25.:
            point_data.append((current_point_id, current_coords))
            current_point_id = None

# Print the extracted point data
for point_id, coords in point_data:
    print("Point ID:", point_id)
    print("Coordinates:", coords)
# Out:
# Point ID: 1,1
# Coordinates: {'X': 0.001, 'Y': 0.001, 'Z': -0.001}
# Point ID: 1,2
# Coordinates: {'X': 0.001, 'Y': 10.001, 'Z': 0.241}
# Point ID: 1,3
# Coordinates: {'X': 0.001, 'Y': 20.001, 'Z': 0.376}
# Point ID: 1,4
# Coordinates: {'X': 0.001, 'Y': 30.001, 'Z': 0.462}
# Point ID: 1,5
# Coordinates: {'X': 0.001, 'Y': 40.001, 'Z': 0.541}
# Point ID: 1,6
# Coordinates: {'X': 0.001, 'Y': 50.001, 'Z': 0.55}
# Point ID: 1,7
# Coordinates: {'X': 0.001, 'Y': 60.001, 'Z': 0.536}
# Point ID: 1,8
# Coordinates: {'X': 0.001, 'Y': 70.001, 'Z': 0.529}
# Point ID: 1,9
# Coordinates: {'X': 0.001, 'Y': 80.001, 'Z': 0.61}
# Point ID: 1,10
# Coordinates: {'X': 0.001, 'Y': 90.001, 'Z': 0.729}
# Point ID: 1,11
# Coordinates: {'X': 0.001, 'Y': 100.001, 'Z': 0.797}
# Point ID: 1,12
# Coordinates: {'X': 0.001, 'Y': 110.001, 'Z': 0.892}
# Point ID: 1,13
# Coordinates: {'X': 0.001, 'Y': 120.001, 'Z': 0.879}
# Point ID: 2,1
# Coordinates: {'X': 10.001, 'Y': 0.001, 'Z': 0.071}
# Point ID: 2,2
# Coordinates: {'X': 10.001, 'Y': 10.001, 'Z': 0.365}
# Point ID: 2,3
# Coordinates: {'X': 10.001, 'Y': 20.001, 'Z': 0.502}
# Point ID: 2,4
# Coordinates: {'X': 10.001, 'Y': 30.001, 'Z': 0.541}
# Point ID: 2,5
# Coordinates: {'X': 10.001, 'Y': 40.001, 'Z': 0.574}
# Point ID: 2,6
# Coordinates: {'X': 10.001, 'Y': 50.001, 'Z': 0.576}
# Point ID: 2,7
# Coordinates: {'X': 10.001, 'Y': 60.001, 'Z': 0.55}
# Point ID: 2,8
# Coordinates: {'X': 10.001, 'Y': 70.001, 'Z': 0.618}
# Point ID: 2,9
# Coordinates: {'X': 10.001, 'Y': 80.001, 'Z': 0.599}
# Point ID: 2,10
# Coordinates: {'X': 10.001, 'Y': 90.001, 'Z': 0.774}
# Point ID: 2,11
# Coordinates: {'X': 10.001, 'Y': 100.001, 'Z': 0.79}
# Point ID: 2,12
# Coordinates: {'X': 10.001, 'Y': 110.001, 'Z': 0.86}
# Point ID: 2,13
# Coordinates: {'X': 10.001, 'Y': 120.001, 'Z': 0.888}
# Point ID: 3,1
# Coordinates: {'X': 20.001, 'Y': 0.001, 'Z': -0.019}
# Point ID: 3,2
# Coordinates: {'X': 20.001, 'Y': 10.001, 'Z': 0.254}
# Point ID: 3,3
# Coordinates: {'X': 20.001, 'Y': 20.001, 'Z': 0.382}
# Point ID: 3,4
# Coordinates: {'X': 20.001, 'Y': 30.001, 'Z': 0.387}
# Point ID: 3,5
# Coordinates: {'X': 20.001, 'Y': 40.001, 'Z': 0.392}
# Point ID: 3,6
# Coordinates: {'X': 20.001, 'Y': 50.001, 'Z': 0.413}
# Point ID: 3,7
# Coordinates: {'X': 20.001, 'Y': 60.001, 'Z': 0.418}
# Point ID: 3,8
# Coordinates: {'X': 20.001, 'Y': 70.001, 'Z': 0.64}
# Point ID: 3,9
# Coordinates: {'X': 20.001, 'Y': 80.001, 'Z': 0.541}
# Point ID: 3,10
# Coordinates: {'X': 20.001, 'Y': 90.001, 'Z': 0.799}
# Point ID: 3,11
# Coordinates: {'X': 20.001, 'Y': 100.001, 'Z': 0.772}
# Point ID: 3,12
# Coordinates: {'X': 20.001, 'Y': 110.001, 'Z': 0.822}
# Point ID: 3,13
# Coordinates: {'X': 20.001, 'Y': 120.001, 'Z': 0.909}
# Point ID: 4,1
# Coordinates: {'X': 30.001, 'Y': 0.001, 'Z': -0.143}
# Point ID: 4,2
# Coordinates: {'X': 30.001, 'Y': 10.001, 'Z': 0.06}
# Point ID: 4,3
# Coordinates: {'X': 30.001, 'Y': 20.001, 'Z': 0.18}
# Point ID: 4,4
# Coordinates: {'X': 30.001, 'Y': 30.001, 'Z': 0.222}
# Point ID: 4,5
# Coordinates: {'X': 30.001, 'Y': 40.001, 'Z': 0.252}
# Point ID: 4,6
# Coordinates: {'X': 30.001, 'Y': 50.001, 'Z': 0.279}
# Point ID: 4,7
# Coordinates: {'X': 30.001, 'Y': 60.001, 'Z': 0.354}
# Point ID: 4,8
# Coordinates: {'X': 30.001, 'Y': 70.001, 'Z': 0.635}
# Point ID: 4,9
# Coordinates: {'X': 30.001, 'Y': 80.001, 'Z': 0.507}
# Point ID: 4,10
# Coordinates: {'X': 30.001, 'Y': 90.001, 'Z': 0.804}
# Point ID: 4,11
# Coordinates: {'X': 30.001, 'Y': 100.001, 'Z': 0.751}
# Point ID: 4,12
# Coordinates: {'X': 30.001, 'Y': 110.001, 'Z': 0.801}
# Point ID: 4,13
# Coordinates: {'X': 30.001, 'Y': 120.001, 'Z': 0.912}
# Point ID: 5,1
# Coordinates: {'X': 40.001, 'Y': 0.001, 'Z': -0.21}
# Point ID: 5,2
# Coordinates: {'X': 40.001, 'Y': 10.001, 'Z': -0.055}
# Point ID: 5,3
# Coordinates: {'X': 40.001, 'Y': 20.001, 'Z': 0.072}
# Point ID: 5,4
# Coordinates: {'X': 40.001, 'Y': 30.001, 'Z': 0.169}
# Point ID: 5,5
# Coordinates: {'X': 40.001, 'Y': 40.001, 'Z': 0.224}
# Point ID: 5,6
# Coordinates: {'X': 40.001, 'Y': 50.001, 'Z': 0.259}
# Point ID: 5,7
# Coordinates: {'X': 40.001, 'Y': 60.001, 'Z': 0.328}
# Point ID: 5,8
# Coordinates: {'X': 40.001, 'Y': 70.001, 'Z': 0.624}
# Point ID: 5,9
# Coordinates: {'X': 40.001, 'Y': 80.001, 'Z': 0.481}
# Point ID: 5,10
# Coordinates: {'X': 40.001, 'Y': 90.001, 'Z': 0.801}
# Point ID: 5,11
# Coordinates: {'X': 40.001, 'Y': 100.001, 'Z': 0.732}
# Point ID: 5,12
# Coordinates: {'X': 40.001, 'Y': 110.001, 'Z': 0.787}
# Point ID: 5,13
# Coordinates: {'X': 40.001, 'Y': 120.001, 'Z': 0.911}
# Point ID: 6,1
# Coordinates: {'X': 50.001, 'Y': 0.001, 'Z': -0.216}
# Point ID: 6,2
# Coordinates: {'X': 50.001, 'Y': 10.001, 'Z': -0.078}
# Point ID: 6,3
# Coordinates: {'X': 50.001, 'Y': 20.001, 'Z': 0.057}
# Point ID: 6,4
# Coordinates: {'X': 50.001, 'Y': 30.001, 'Z': 0.172}
# Point ID: 6,5
# Coordinates: {'X': 50.001, 'Y': 40.001, 'Z': 0.228}
# Point ID: 6,6
# Coordinates: {'X': 50.001, 'Y': 50.001, 'Z': 0.269}
# Point ID: 6,7
# Coordinates: {'X': 50.001, 'Y': 60.001, 'Z': 0.316}
# Point ID: 6,8
# Coordinates: {'X': 50.001, 'Y': 70.001, 'Z': 0.609}
# Point ID: 6,9
# Coordinates: {'X': 50.001, 'Y': 80.001, 'Z': 0.462}
# Point ID: 6,10
# Coordinates: {'X': 50.001, 'Y': 90.001, 'Z': 0.798}
# Point ID: 6,11
# Coordinates: {'X': 50.001, 'Y': 100.001, 'Z': 0.716}
# Point ID: 6,12
# Coordinates: {'X': 50.001, 'Y': 110.001, 'Z': 0.771}
# Point ID: 6,13
# Coordinates: {'X': 50.001, 'Y': 120.001, 'Z': 0.903}
# Point ID: 7,1
# Coordinates: {'X': 60.001, 'Y': 0.001, 'Z': -0.202}
# Point ID: 7,2
# Coordinates: {'X': 60.001, 'Y': 10.001, 'Z': -0.07}
# Point ID: 7,3
# Coordinates: {'X': 60.001, 'Y': 20.001, 'Z': 0.066}
# Point ID: 7,4
# Coordinates: {'X': 60.001, 'Y': 30.001, 'Z': 0.166}
# Point ID: 7,5
# Coordinates: {'X': 60.001, 'Y': 40.001, 'Z': 0.22}
# Point ID: 7,6
# Coordinates: {'X': 60.001, 'Y': 50.001, 'Z': 0.263}
# Point ID: 7,7
# Coordinates: {'X': 60.001, 'Y': 60.001, 'Z': 0.314}
# Point ID: 7,8
# Coordinates: {'X': 60.001, 'Y': 70.001, 'Z': 0.587}
# Point ID: 7,9
# Coordinates: {'X': 60.001, 'Y': 80.001, 'Z': 0.452}
# Point ID: 7,10
# Coordinates: {'X': 60.001, 'Y': 90.001, 'Z': 0.784}
# Point ID: 7,11
# Coordinates: {'X': 60.001, 'Y': 100.001, 'Z': 0.709}
# Point ID: 7,12
# Coordinates: {'X': 60.001, 'Y': 110.001, 'Z': 0.768}
# Point ID: 7,13
# Coordinates: {'X': 60.001, 'Y': 120.001, 'Z': 0.864}
# Point ID: 8,1
# Coordinates: {'X': 70.001, 'Y': 0.001, 'Z': -0.187}
# Point ID: 8,2
# Coordinates: {'X': 70.001, 'Y': 10.001, 'Z': -0.07}
# Point ID: 8,3
# Coordinates: {'X': 70.001, 'Y': 20.001, 'Z': 0.059}
# Point ID: 8,4
# Coordinates: {'X': 70.001, 'Y': 30.001, 'Z': 0.149}
# Point ID: 8,5
# Coordinates: {'X': 70.001, 'Y': 40.001, 'Z': 0.198}
# Point ID: 8,6
# Coordinates: {'X': 70.001, 'Y': 50.001, 'Z': 0.242}
# Point ID: 8,7
# Coordinates: {'X': 70.001, 'Y': 60.001, 'Z': 0.302}
# Point ID: 8,8
# Coordinates: {'X': 70.001, 'Y': 70.001, 'Z': 0.553}
# Point ID: 8,9
# Coordinates: {'X': 70.001, 'Y': 80.001, 'Z': 0.453}
# Point ID: 8,10
# Coordinates: {'X': 70.001, 'Y': 90.001, 'Z': 0.761}
# Point ID: 8,11
# Coordinates: {'X': 70.001, 'Y': 100.001, 'Z': 0.711}
# Point ID: 8,12
# Coordinates: {'X': 70.001, 'Y': 110.001, 'Z': 0.765}
# Point ID: 8,13
# Coordinates: {'X': 70.001, 'Y': 120.001, 'Z': 0.782}
# Point ID: 9,1
# Coordinates: {'X': 80.001, 'Y': 0.001, 'Z': -0.178}
# Point ID: 9,2
# Coordinates: {'X': 80.001, 'Y': 10.001, 'Z': -0.068}
# Point ID: 9,3
# Coordinates: {'X': 80.001, 'Y': 20.001, 'Z': 0.052}
# Point ID: 9,4
# Coordinates: {'X': 80.001, 'Y': 30.001, 'Z': 0.127}
# Point ID: 9,5
# Coordinates: {'X': 80.001, 'Y': 40.001, 'Z': 0.176}
# Point ID: 9,6
# Coordinates: {'X': 80.001, 'Y': 50.001, 'Z': 0.218}
# Point ID: 9,7
# Coordinates: {'X': 80.001, 'Y': 60.001, 'Z': 0.277}
# Point ID: 9,8
# Coordinates: {'X': 80.001, 'Y': 70.001, 'Z': 0.513}
# Point ID: 9,9
# Coordinates: {'X': 80.001, 'Y': 80.001, 'Z': 0.458}
# Point ID: 9,10
# Coordinates: {'X': 80.001, 'Y': 90.001, 'Z': 0.739}
# Point ID: 9,11
# Coordinates: {'X': 80.001, 'Y': 100.001, 'Z': 0.713}
# Point ID: 9,12
# Coordinates: {'X': 80.001, 'Y': 110.001, 'Z': 0.757}
# Point ID: 9,13
# Coordinates: {'X': 80.001, 'Y': 120.001, 'Z': 0.73}
# Point ID: 10,1
# Coordinates: {'X': 90.001, 'Y': 0.001, 'Z': -0.151}
# Point ID: 10,2
# Coordinates: {'X': 90.001, 'Y': 10.001, 'Z': -0.051}
# Point ID: 10,3
# Coordinates: {'X': 90.001, 'Y': 20.001, 'Z': 0.041}
# Point ID: 10,4
# Coordinates: {'X': 90.001, 'Y': 30.001, 'Z': 0.101}
# Point ID: 10,5
# Coordinates: {'X': 90.001, 'Y': 40.001, 'Z': 0.143}
# Point ID: 10,6
# Coordinates: {'X': 90.001, 'Y': 50.001, 'Z': 0.194}
# Point ID: 10,7
# Coordinates: {'X': 90.001, 'Y': 60.001, 'Z': 0.243}
# Point ID: 10,8
# Coordinates: {'X': 90.001, 'Y': 70.001, 'Z': 0.481}
# Point ID: 10,9
# Coordinates: {'X': 90.001, 'Y': 80.001, 'Z': 0.447}
# Point ID: 10,10
# Coordinates: {'X': 90.001, 'Y': 90.001, 'Z': 0.743}
# Point ID: 10,11
# Coordinates: {'X': 90.001, 'Y': 100.001, 'Z': 0.708}
# Point ID: 10,12
# Coordinates: {'X': 90.001, 'Y': 110.001, 'Z': 0.748}
# Point ID: 10,13
# Coordinates: {'X': 90.001, 'Y': 120.001, 'Z': 0.691}
# Point ID: 11,1
# Coordinates: {'X': 100.001, 'Y': 0.001, 'Z': -0.127}
# Point ID: 11,2
# Coordinates: {'X': 100.001, 'Y': 10.001, 'Z': -0.049}
# Point ID: 11,3
# Coordinates: {'X': 100.001, 'Y': 20.001, 'Z': 0.017}
# Point ID: 11,4
# Coordinates: {'X': 100.001, 'Y': 30.001, 'Z': 0.066}
# Point ID: 11,5
# Coordinates: {'X': 100.001, 'Y': 40.001, 'Z': 0.111}
# Point ID: 11,6
# Coordinates: {'X': 100.001, 'Y': 50.001, 'Z': 0.161}
# Point ID: 11,7
# Coordinates: {'X': 100.001, 'Y': 60.001, 'Z': 0.202}
# Point ID: 11,8
# Coordinates: {'X': 100.001, 'Y': 70.001, 'Z': 0.441}
# Point ID: 11,9
# Coordinates: {'X': 100.001, 'Y': 80.001, 'Z': 0.444}
# Point ID: 11,10
# Coordinates: {'X': 100.001, 'Y': 90.001, 'Z': 0.746}
# Point ID: 11,11
# Coordinates: {'X': 100.001, 'Y': 100.001, 'Z': 0.701}
# Point ID: 11,12
# Coordinates: {'X': 100.001, 'Y': 110.001, 'Z': 0.737}
# Point ID: 11,13
# Coordinates: {'X': 100.001, 'Y': 120.001, 'Z': 0.651}
# Point ID: 12,1
# Coordinates: {'X': 110.001, 'Y': 0.001, 'Z': -0.114}
# Point ID: 12,2
# Coordinates: {'X': 110.001, 'Y': 10.001, 'Z': -0.072}
# Point ID: 12,3
# Coordinates: {'X': 110.001, 'Y': 20.001, 'Z': -0.014}
# Point ID: 12,4
# Coordinates: {'X': 110.001, 'Y': 30.001, 'Z': 0.036}
# Point ID: 12,5
# Coordinates: {'X': 110.001, 'Y': 40.001, 'Z': 0.08}
# Point ID: 12,6
# Coordinates: {'X': 110.001, 'Y': 50.001, 'Z': 0.124}
# Point ID: 12,7
# Coordinates: {'X': 110.001, 'Y': 60.001, 'Z': 0.177}
# Point ID: 12,8
# Coordinates: {'X': 110.001, 'Y': 70.001, 'Z': 0.394}
# Point ID: 12,9
# Coordinates: {'X': 110.001, 'Y': 80.001, 'Z': 0.453}
# Point ID: 12,10
# Coordinates: {'X': 110.001, 'Y': 90.001, 'Z': 0.734}
# Point ID: 12,11
# Coordinates: {'X': 110.001, 'Y': 100.001, 'Z': 0.701}
# Point ID: 12,12
# Coordinates: {'X': 110.001, 'Y': 110.001, 'Z': 0.72}
# Point ID: 12,13
# Coordinates: {'X': 110.001, 'Y': 120.001, 'Z': 0.657}
# Point ID: 13,1
# Coordinates: {'X': 120.001, 'Y': 0.001, 'Z': -0.086}
# Point ID: 13,2
# Coordinates: {'X': 120.001, 'Y': 10.001, 'Z': -0.062}
# Point ID: 13,3
# Coordinates: {'X': 120.001, 'Y': 20.001, 'Z': -0.028}
# Point ID: 13,4
# Coordinates: {'X': 120.001, 'Y': 30.001, 'Z': 0.008}
# Point ID: 13,5
# Coordinates: {'X': 120.001, 'Y': 40.001, 'Z': 0.055}
# Point ID: 13,6
# Coordinates: {'X': 120.001, 'Y': 50.001, 'Z': 0.1}
# Point ID: 13,7
# Coordinates: {'X': 120.001, 'Y': 60.001, 'Z': 0.157}
# Point ID: 13,8
# Coordinates: {'X': 120.001, 'Y': 70.001, 'Z': 0.342}
# Point ID: 13,9
# Coordinates: {'X': 120.001, 'Y': 80.001, 'Z': 0.467}
# Point ID: 13,10
# Coordinates: {'X': 120.001, 'Y': 90.001, 'Z': 0.71}
# Point ID: 13,11
# Coordinates: {'X': 120.001, 'Y': 100.001, 'Z': 0.705}
# Point ID: 13,12
# Coordinates: {'X': 120.001, 'Y': 110.001, 'Z': 0.704}
# Point ID: 13,13
# Coordinates: {'X': 120.001, 'Y': 120.001, 'Z': 0.646}

# %%
# Extract X, Y, Z values and corresponding point IDs
point_ids = []
x_values = []
y_values = []
z_values = []

for point_id, coords in point_data:
    point_ids.append(point_id)
    x_values.append(coords['X'])
    y_values.append(coords['Y'])
    z_values.append(coords['Z'])

# Plot the XYZ points relative to their point IDs
fig = plt.figure(figsize=(20, 16))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_values, y_values, z_values)

# Label each point with its corresponding ID
for i, point_id in enumerate(point_ids):
    ax.text(x_values[i], y_values[i], z_values[i], point_id)

# Set labels and title
ax.set_xlabel('X [mm]', fontsize=14, fontweight='bold')
ax.set_ylabel('Y [mm]', fontsize=14, fontweight='bold')
ax.set_zlabel('Z [mm]', fontsize=14, fontweight='bold')
ax.set_title('Position Points XYZ', fontsize=11, fontweight='bold')

plt.show()

# %%
plt.figure(figsize=(15, 11))
plt.scatter(x_values, y_values, c=z_values, cmap='viridis', s=50)
plt.colorbar(label='Z [mm] (Weight)')
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Planarity Plot with Z (Weight)', fontsize=11, fontweight='bold')
plt.grid(True)
plt.show()

# %%
# Create a regular grid to interpolate onto
x_grid = np.linspace(min(x_values), max(x_values), 100)
y_grid = np.linspace(min(y_values), max(y_values), 100)
X, Y = np.meshgrid(x_grid, y_grid)

# Interpolate Z values onto the grid
Z = griddata((x_values, y_values), z_values, (X, Y), method='linear')
Z_grid = np.linspace(min(z_values), max(z_values), 100)
#colorbar = plt.colorbar(heatmap, label='Z [mm]', ticks=np.linspace(Z_grid.min(), Z_grid.max(), num=10))

# Plot the heatmap
plt.figure(figsize=(15, 11))
plt.pcolormesh(X, Y, Z, cmap='viridis')
plt.colorbar(label='Z [mm]', ticks=np.linspace(Z_grid.min(), Z_grid.max(), num=10))
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Interpolated Heatmap of XYZ', fontsize=11, fontweight='bold')
plt.show()

# %%
# Flatten the interpolated Z values
Z_flat = Z.flatten()

# Calculate the Root Mean Square (RMS)
rms = np.sqrt(np.mean(Z_flat**2))

print("Root Mean Square (RMS) of the heatmap:", rms)
# Out:
# Root Mean Square (RMS) of the heatmap: 0.49990443486317243

# %%
print(Z_flat)
# Out:
# [-0.001       0.00772727  0.01645455 ...  0.64866667  0.64733333
#   0.646     ]

# %%
# Find the NaN points
nan_indices = np.isnan(Z)
nan_points = np.column_stack((X[nan_indices], Y[nan_indices]))

# Print the NaN points
print("NaN Points (X, Y):")
print(nan_points)
# Out:
# NaN Points (X, Y):
# []

# %%
# Calculate the Root Mean Square (RMS) excluding NaN values
rms = np.sqrt(np.nanmean(Z_flat**2))

print("Root Mean Square (RMS) of the heatmap (excluding NaN points):", rms)
# Out:
# Root Mean Square (RMS) of the heatmap (excluding NaN points): 0.49990443486317243

# %%
std_dev = np.std(Z_flat, ddof=1)
RMS = round(std_dev, 6)
print("RMS RAW =", RMS)
# Out:
# RMS RAW = 0.296888

# %%
# Create the histogram
plt.figure(figsize=(12, 10))

plt.hist(z_values, bins=50, color='green', edgecolor='black', alpha=0.8)
# Add mean, median, and standard deviation lines
mean_value = np.mean(z_values)
median_value = np.median(z_values)
std_dev = np.std(z_values)

plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean_value:.2f}')
plt.axvline(median_value, color='green', linestyle='dashed', linewidth=1, label=f'Median: {median_value:.2f}')
plt.axvline(mean_value + std_dev, color='orange', linestyle='dashed', linewidth=1, label=f'Standard Deviation: {std_dev:.2f}')
plt.axvline(mean_value - std_dev, color='orange', linestyle='dashed', linewidth=1)

plt.legend()
plt.xlabel('Z Measured [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Entries', fontsize=14, fontweight='bold')
#plt.title('Histogram of Z Values')
#plt.title('Histogram with Statistics')
plt.grid(True)
plt.show()

# %%
# Group Z values by X values
x_groups = {}
for x, z in zip(x_values, z_values):
    if x not in x_groups:
        x_groups[x] = []
    x_groups[x].append(z)

# Plot scatter plots for each X group
plt.figure(figsize=(40, 20))
for x, z_group in x_groups.items():
    plt.scatter([x] * len(z_group), z_group, label=f"X = {x}")

plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Z [mm]', fontsize=14, fontweight='bold')
plt.title('Scatter Plot of Z Values for Each X Group', fontsize=11, fontweight='bold')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Group Z values by Y values
y_groups = {}
for y, z in zip(y_values, z_values):
    if y not in y_groups:
        y_groups[y] = []
    y_groups[y].append(z)

# Plot scatter plots for each X group
plt.figure(figsize=(40, 20))
for y, z_group in y_groups.items():
    indices = range(1, len(z_values) + 1)
    #plt.scatter(indices, z_values, label=f'Y = {y}')

    plt.scatter([y] * len(z_group), z_group, label=f"Y = {y}")

plt.xlabel('Y [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Z [mm]', fontsize=14, fontweight='bold')
plt.title('Scatter Plot of Z Values for Each Y Group', fontsize=11, fontweight='bold')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Initialize variables to store point IDs and corresponding coordinates
point_data = []

# Regular expressions to match point ID and coordinate lines
point_id_pattern = r'\[([\d,]+)\]'
coord_pattern = r'Coord\. ([XYZ]) =\s*([-+]?\d+,\d+)'

# Extract point IDs and coordinates from lines
current_point_id = None
current_coords = {}

skipped_lines = 0
for line in lines:
    if skipped_lines < 3 and not line.startswith('Plan'):
        skipped_lines += 1
        continue
    elif line.startswith('Plan'):
        break
    # Check if the line contains a point ID
    match_id = re.search(point_id_pattern, line)
    if match_id:
        current_point_id = match_id.group(1)
        current_coords = {}
        continue

   # Check if the line contains a coordinate
    match_coord = re.search(coord_pattern, line)
    if match_coord and current_point_id:
        coord_type = match_coord.group(1)
        coord_value = float(match_coord.group(2).replace(',', '.'))
        
        # Check if the Y coordinate is not equal to 0.002
        if coord_type == 'Y' and coord_value == 0.002:
            continue  # Skip this coordinate
        if coord_type == 'X' and coord_value == 0.0 and coord_type == 'Y' and coord_value == 50.0: 
            continue
             
        current_coords[coord_type] = coord_value

        # If all coordinates are found, add them to the point data
        if len(current_coords) == 3 and current_coords['Y']>0:# and current_coords['X'] == 150. and current_coords['Y'] == 150.:
            point_data.append((current_point_id, current_coords))
            current_point_id = None

# Convert the data to the desired format
formatted_data = []
for point_id, coords in point_data:
    formatted_coords = {'X': coords['X'], 'Y': coords['Y'], 'Z': coords['Z']}
    formatted_data.append((point_id, formatted_coords))

# Print the formatted data
for point_id, coords in formatted_data:
    print("Point ID:", point_id)
    print("Coordinates:", coords)
# Out:
# Point ID: 1,1
# Coordinates: {'X': 0.001, 'Y': 0.001, 'Z': -0.001}
# Point ID: 1,2
# Coordinates: {'X': 0.001, 'Y': 10.001, 'Z': 0.241}
# Point ID: 1,3
# Coordinates: {'X': 0.001, 'Y': 20.001, 'Z': 0.376}
# Point ID: 1,4
# Coordinates: {'X': 0.001, 'Y': 30.001, 'Z': 0.462}
# Point ID: 1,5
# Coordinates: {'X': 0.001, 'Y': 40.001, 'Z': 0.541}
# Point ID: 1,6
# Coordinates: {'X': 0.001, 'Y': 50.001, 'Z': 0.55}
# Point ID: 1,7
# Coordinates: {'X': 0.001, 'Y': 60.001, 'Z': 0.536}
# Point ID: 1,8
# Coordinates: {'X': 0.001, 'Y': 70.001, 'Z': 0.529}
# Point ID: 1,9
# Coordinates: {'X': 0.001, 'Y': 80.001, 'Z': 0.61}
# Point ID: 1,10
# Coordinates: {'X': 0.001, 'Y': 90.001, 'Z': 0.729}
# Point ID: 1,11
# Coordinates: {'X': 0.001, 'Y': 100.001, 'Z': 0.797}
# Point ID: 1,12
# Coordinates: {'X': 0.001, 'Y': 110.001, 'Z': 0.892}
# Point ID: 1,13
# Coordinates: {'X': 0.001, 'Y': 120.001, 'Z': 0.879}
# Point ID: 2,1
# Coordinates: {'X': 10.001, 'Y': 0.001, 'Z': 0.071}
# Point ID: 2,2
# Coordinates: {'X': 10.001, 'Y': 10.001, 'Z': 0.365}
# Point ID: 2,3
# Coordinates: {'X': 10.001, 'Y': 20.001, 'Z': 0.502}
# Point ID: 2,4
# Coordinates: {'X': 10.001, 'Y': 30.001, 'Z': 0.541}
# Point ID: 2,5
# Coordinates: {'X': 10.001, 'Y': 40.001, 'Z': 0.574}
# Point ID: 2,6
# Coordinates: {'X': 10.001, 'Y': 50.001, 'Z': 0.576}
# Point ID: 2,7
# Coordinates: {'X': 10.001, 'Y': 60.001, 'Z': 0.55}
# Point ID: 2,8
# Coordinates: {'X': 10.001, 'Y': 70.001, 'Z': 0.618}
# Point ID: 2,9
# Coordinates: {'X': 10.001, 'Y': 80.001, 'Z': 0.599}
# Point ID: 2,10
# Coordinates: {'X': 10.001, 'Y': 90.001, 'Z': 0.774}
# Point ID: 2,11
# Coordinates: {'X': 10.001, 'Y': 100.001, 'Z': 0.79}
# Point ID: 2,12
# Coordinates: {'X': 10.001, 'Y': 110.001, 'Z': 0.86}
# Point ID: 2,13
# Coordinates: {'X': 10.001, 'Y': 120.001, 'Z': 0.888}
# Point ID: 3,1
# Coordinates: {'X': 20.001, 'Y': 0.001, 'Z': -0.019}
# Point ID: 3,2
# Coordinates: {'X': 20.001, 'Y': 10.001, 'Z': 0.254}
# Point ID: 3,3
# Coordinates: {'X': 20.001, 'Y': 20.001, 'Z': 0.382}
# Point ID: 3,4
# Coordinates: {'X': 20.001, 'Y': 30.001, 'Z': 0.387}
# Point ID: 3,5
# Coordinates: {'X': 20.001, 'Y': 40.001, 'Z': 0.392}
# Point ID: 3,6
# Coordinates: {'X': 20.001, 'Y': 50.001, 'Z': 0.413}
# Point ID: 3,7
# Coordinates: {'X': 20.001, 'Y': 60.001, 'Z': 0.418}
# Point ID: 3,8
# Coordinates: {'X': 20.001, 'Y': 70.001, 'Z': 0.64}
# Point ID: 3,9
# Coordinates: {'X': 20.001, 'Y': 80.001, 'Z': 0.541}
# Point ID: 3,10
# Coordinates: {'X': 20.001, 'Y': 90.001, 'Z': 0.799}
# Point ID: 3,11
# Coordinates: {'X': 20.001, 'Y': 100.001, 'Z': 0.772}
# Point ID: 3,12
# Coordinates: {'X': 20.001, 'Y': 110.001, 'Z': 0.822}
# Point ID: 3,13
# Coordinates: {'X': 20.001, 'Y': 120.001, 'Z': 0.909}
# Point ID: 4,1
# Coordinates: {'X': 30.001, 'Y': 0.001, 'Z': -0.143}
# Point ID: 4,2
# Coordinates: {'X': 30.001, 'Y': 10.001, 'Z': 0.06}
# Point ID: 4,3
# Coordinates: {'X': 30.001, 'Y': 20.001, 'Z': 0.18}
# Point ID: 4,4
# Coordinates: {'X': 30.001, 'Y': 30.001, 'Z': 0.222}
# Point ID: 4,5
# Coordinates: {'X': 30.001, 'Y': 40.001, 'Z': 0.252}
# Point ID: 4,6
# Coordinates: {'X': 30.001, 'Y': 50.001, 'Z': 0.279}
# Point ID: 4,7
# Coordinates: {'X': 30.001, 'Y': 60.001, 'Z': 0.354}
# Point ID: 4,8
# Coordinates: {'X': 30.001, 'Y': 70.001, 'Z': 0.635}
# Point ID: 4,9
# Coordinates: {'X': 30.001, 'Y': 80.001, 'Z': 0.507}
# Point ID: 4,10
# Coordinates: {'X': 30.001, 'Y': 90.001, 'Z': 0.804}
# Point ID: 4,11
# Coordinates: {'X': 30.001, 'Y': 100.001, 'Z': 0.751}
# Point ID: 4,12
# Coordinates: {'X': 30.001, 'Y': 110.001, 'Z': 0.801}
# Point ID: 4,13
# Coordinates: {'X': 30.001, 'Y': 120.001, 'Z': 0.912}
# Point ID: 5,1
# Coordinates: {'X': 40.001, 'Y': 0.001, 'Z': -0.21}
# Point ID: 5,2
# Coordinates: {'X': 40.001, 'Y': 10.001, 'Z': -0.055}
# Point ID: 5,3
# Coordinates: {'X': 40.001, 'Y': 20.001, 'Z': 0.072}
# Point ID: 5,4
# Coordinates: {'X': 40.001, 'Y': 30.001, 'Z': 0.169}
# Point ID: 5,5
# Coordinates: {'X': 40.001, 'Y': 40.001, 'Z': 0.224}
# Point ID: 5,6
# Coordinates: {'X': 40.001, 'Y': 50.001, 'Z': 0.259}
# Point ID: 5,7
# Coordinates: {'X': 40.001, 'Y': 60.001, 'Z': 0.328}
# Point ID: 5,8
# Coordinates: {'X': 40.001, 'Y': 70.001, 'Z': 0.624}
# Point ID: 5,9
# Coordinates: {'X': 40.001, 'Y': 80.001, 'Z': 0.481}
# Point ID: 5,10
# Coordinates: {'X': 40.001, 'Y': 90.001, 'Z': 0.801}
# Point ID: 5,11
# Coordinates: {'X': 40.001, 'Y': 100.001, 'Z': 0.732}
# Point ID: 5,12
# Coordinates: {'X': 40.001, 'Y': 110.001, 'Z': 0.787}
# Point ID: 5,13
# Coordinates: {'X': 40.001, 'Y': 120.001, 'Z': 0.911}
# Point ID: 6,1
# Coordinates: {'X': 50.001, 'Y': 0.001, 'Z': -0.216}
# Point ID: 6,2
# Coordinates: {'X': 50.001, 'Y': 10.001, 'Z': -0.078}
# Point ID: 6,3
# Coordinates: {'X': 50.001, 'Y': 20.001, 'Z': 0.057}
# Point ID: 6,4
# Coordinates: {'X': 50.001, 'Y': 30.001, 'Z': 0.172}
# Point ID: 6,5
# Coordinates: {'X': 50.001, 'Y': 40.001, 'Z': 0.228}
# Point ID: 6,6
# Coordinates: {'X': 50.001, 'Y': 50.001, 'Z': 0.269}
# Point ID: 6,7
# Coordinates: {'X': 50.001, 'Y': 60.001, 'Z': 0.316}
# Point ID: 6,8
# Coordinates: {'X': 50.001, 'Y': 70.001, 'Z': 0.609}
# Point ID: 6,9
# Coordinates: {'X': 50.001, 'Y': 80.001, 'Z': 0.462}
# Point ID: 6,10
# Coordinates: {'X': 50.001, 'Y': 90.001, 'Z': 0.798}
# Point ID: 6,11
# Coordinates: {'X': 50.001, 'Y': 100.001, 'Z': 0.716}
# Point ID: 6,12
# Coordinates: {'X': 50.001, 'Y': 110.001, 'Z': 0.771}
# Point ID: 6,13
# Coordinates: {'X': 50.001, 'Y': 120.001, 'Z': 0.903}
# Point ID: 7,1
# Coordinates: {'X': 60.001, 'Y': 0.001, 'Z': -0.202}
# Point ID: 7,2
# Coordinates: {'X': 60.001, 'Y': 10.001, 'Z': -0.07}
# Point ID: 7,3
# Coordinates: {'X': 60.001, 'Y': 20.001, 'Z': 0.066}
# Point ID: 7,4
# Coordinates: {'X': 60.001, 'Y': 30.001, 'Z': 0.166}
# Point ID: 7,5
# Coordinates: {'X': 60.001, 'Y': 40.001, 'Z': 0.22}
# Point ID: 7,6
# Coordinates: {'X': 60.001, 'Y': 50.001, 'Z': 0.263}
# Point ID: 7,7
# Coordinates: {'X': 60.001, 'Y': 60.001, 'Z': 0.314}
# Point ID: 7,8
# Coordinates: {'X': 60.001, 'Y': 70.001, 'Z': 0.587}
# Point ID: 7,9
# Coordinates: {'X': 60.001, 'Y': 80.001, 'Z': 0.452}
# Point ID: 7,10
# Coordinates: {'X': 60.001, 'Y': 90.001, 'Z': 0.784}
# Point ID: 7,11
# Coordinates: {'X': 60.001, 'Y': 100.001, 'Z': 0.709}
# Point ID: 7,12
# Coordinates: {'X': 60.001, 'Y': 110.001, 'Z': 0.768}
# Point ID: 7,13
# Coordinates: {'X': 60.001, 'Y': 120.001, 'Z': 0.864}
# Point ID: 8,1
# Coordinates: {'X': 70.001, 'Y': 0.001, 'Z': -0.187}
# Point ID: 8,2
# Coordinates: {'X': 70.001, 'Y': 10.001, 'Z': -0.07}
# Point ID: 8,3
# Coordinates: {'X': 70.001, 'Y': 20.001, 'Z': 0.059}
# Point ID: 8,4
# Coordinates: {'X': 70.001, 'Y': 30.001, 'Z': 0.149}
# Point ID: 8,5
# Coordinates: {'X': 70.001, 'Y': 40.001, 'Z': 0.198}
# Point ID: 8,6
# Coordinates: {'X': 70.001, 'Y': 50.001, 'Z': 0.242}
# Point ID: 8,7
# Coordinates: {'X': 70.001, 'Y': 60.001, 'Z': 0.302}
# Point ID: 8,8
# Coordinates: {'X': 70.001, 'Y': 70.001, 'Z': 0.553}
# Point ID: 8,9
# Coordinates: {'X': 70.001, 'Y': 80.001, 'Z': 0.453}
# Point ID: 8,10
# Coordinates: {'X': 70.001, 'Y': 90.001, 'Z': 0.761}
# Point ID: 8,11
# Coordinates: {'X': 70.001, 'Y': 100.001, 'Z': 0.711}
# Point ID: 8,12
# Coordinates: {'X': 70.001, 'Y': 110.001, 'Z': 0.765}
# Point ID: 8,13
# Coordinates: {'X': 70.001, 'Y': 120.001, 'Z': 0.782}
# Point ID: 9,1
# Coordinates: {'X': 80.001, 'Y': 0.001, 'Z': -0.178}
# Point ID: 9,2
# Coordinates: {'X': 80.001, 'Y': 10.001, 'Z': -0.068}
# Point ID: 9,3
# Coordinates: {'X': 80.001, 'Y': 20.001, 'Z': 0.052}
# Point ID: 9,4
# Coordinates: {'X': 80.001, 'Y': 30.001, 'Z': 0.127}
# Point ID: 9,5
# Coordinates: {'X': 80.001, 'Y': 40.001, 'Z': 0.176}
# Point ID: 9,6
# Coordinates: {'X': 80.001, 'Y': 50.001, 'Z': 0.218}
# Point ID: 9,7
# Coordinates: {'X': 80.001, 'Y': 60.001, 'Z': 0.277}
# Point ID: 9,8
# Coordinates: {'X': 80.001, 'Y': 70.001, 'Z': 0.513}
# Point ID: 9,9
# Coordinates: {'X': 80.001, 'Y': 80.001, 'Z': 0.458}
# Point ID: 9,10
# Coordinates: {'X': 80.001, 'Y': 90.001, 'Z': 0.739}
# Point ID: 9,11
# Coordinates: {'X': 80.001, 'Y': 100.001, 'Z': 0.713}
# Point ID: 9,12
# Coordinates: {'X': 80.001, 'Y': 110.001, 'Z': 0.757}
# Point ID: 9,13
# Coordinates: {'X': 80.001, 'Y': 120.001, 'Z': 0.73}
# Point ID: 10,1
# Coordinates: {'X': 90.001, 'Y': 0.001, 'Z': -0.151}
# Point ID: 10,2
# Coordinates: {'X': 90.001, 'Y': 10.001, 'Z': -0.051}
# Point ID: 10,3
# Coordinates: {'X': 90.001, 'Y': 20.001, 'Z': 0.041}
# Point ID: 10,4
# Coordinates: {'X': 90.001, 'Y': 30.001, 'Z': 0.101}
# Point ID: 10,5
# Coordinates: {'X': 90.001, 'Y': 40.001, 'Z': 0.143}
# Point ID: 10,6
# Coordinates: {'X': 90.001, 'Y': 50.001, 'Z': 0.194}
# Point ID: 10,7
# Coordinates: {'X': 90.001, 'Y': 60.001, 'Z': 0.243}
# Point ID: 10,8
# Coordinates: {'X': 90.001, 'Y': 70.001, 'Z': 0.481}
# Point ID: 10,9
# Coordinates: {'X': 90.001, 'Y': 80.001, 'Z': 0.447}
# Point ID: 10,10
# Coordinates: {'X': 90.001, 'Y': 90.001, 'Z': 0.743}
# Point ID: 10,11
# Coordinates: {'X': 90.001, 'Y': 100.001, 'Z': 0.708}
# Point ID: 10,12
# Coordinates: {'X': 90.001, 'Y': 110.001, 'Z': 0.748}
# Point ID: 10,13
# Coordinates: {'X': 90.001, 'Y': 120.001, 'Z': 0.691}
# Point ID: 11,1
# Coordinates: {'X': 100.001, 'Y': 0.001, 'Z': -0.127}
# Point ID: 11,2
# Coordinates: {'X': 100.001, 'Y': 10.001, 'Z': -0.049}
# Point ID: 11,3
# Coordinates: {'X': 100.001, 'Y': 20.001, 'Z': 0.017}
# Point ID: 11,4
# Coordinates: {'X': 100.001, 'Y': 30.001, 'Z': 0.066}
# Point ID: 11,5
# Coordinates: {'X': 100.001, 'Y': 40.001, 'Z': 0.111}
# Point ID: 11,6
# Coordinates: {'X': 100.001, 'Y': 50.001, 'Z': 0.161}
# Point ID: 11,7
# Coordinates: {'X': 100.001, 'Y': 60.001, 'Z': 0.202}
# Point ID: 11,8
# Coordinates: {'X': 100.001, 'Y': 70.001, 'Z': 0.441}
# Point ID: 11,9
# Coordinates: {'X': 100.001, 'Y': 80.001, 'Z': 0.444}
# Point ID: 11,10
# Coordinates: {'X': 100.001, 'Y': 90.001, 'Z': 0.746}
# Point ID: 11,11
# Coordinates: {'X': 100.001, 'Y': 100.001, 'Z': 0.701}
# Point ID: 11,12
# Coordinates: {'X': 100.001, 'Y': 110.001, 'Z': 0.737}
# Point ID: 11,13
# Coordinates: {'X': 100.001, 'Y': 120.001, 'Z': 0.651}
# Point ID: 12,1
# Coordinates: {'X': 110.001, 'Y': 0.001, 'Z': -0.114}
# Point ID: 12,2
# Coordinates: {'X': 110.001, 'Y': 10.001, 'Z': -0.072}
# Point ID: 12,3
# Coordinates: {'X': 110.001, 'Y': 20.001, 'Z': -0.014}
# Point ID: 12,4
# Coordinates: {'X': 110.001, 'Y': 30.001, 'Z': 0.036}
# Point ID: 12,5
# Coordinates: {'X': 110.001, 'Y': 40.001, 'Z': 0.08}
# Point ID: 12,6
# Coordinates: {'X': 110.001, 'Y': 50.001, 'Z': 0.124}
# Point ID: 12,7
# Coordinates: {'X': 110.001, 'Y': 60.001, 'Z': 0.177}
# Point ID: 12,8
# Coordinates: {'X': 110.001, 'Y': 70.001, 'Z': 0.394}
# Point ID: 12,9
# Coordinates: {'X': 110.001, 'Y': 80.001, 'Z': 0.453}
# Point ID: 12,10
# Coordinates: {'X': 110.001, 'Y': 90.001, 'Z': 0.734}
# Point ID: 12,11
# Coordinates: {'X': 110.001, 'Y': 100.001, 'Z': 0.701}
# Point ID: 12,12
# Coordinates: {'X': 110.001, 'Y': 110.001, 'Z': 0.72}
# Point ID: 12,13
# Coordinates: {'X': 110.001, 'Y': 120.001, 'Z': 0.657}
# Point ID: 13,1
# Coordinates: {'X': 120.001, 'Y': 0.001, 'Z': -0.086}
# Point ID: 13,2
# Coordinates: {'X': 120.001, 'Y': 10.001, 'Z': -0.062}
# Point ID: 13,3
# Coordinates: {'X': 120.001, 'Y': 20.001, 'Z': -0.028}
# Point ID: 13,4
# Coordinates: {'X': 120.001, 'Y': 30.001, 'Z': 0.008}
# Point ID: 13,5
# Coordinates: {'X': 120.001, 'Y': 40.001, 'Z': 0.055}
# Point ID: 13,6
# Coordinates: {'X': 120.001, 'Y': 50.001, 'Z': 0.1}
# Point ID: 13,7
# Coordinates: {'X': 120.001, 'Y': 60.001, 'Z': 0.157}
# Point ID: 13,8
# Coordinates: {'X': 120.001, 'Y': 70.001, 'Z': 0.342}
# Point ID: 13,9
# Coordinates: {'X': 120.001, 'Y': 80.001, 'Z': 0.467}
# Point ID: 13,10
# Coordinates: {'X': 120.001, 'Y': 90.001, 'Z': 0.71}
# Point ID: 13,11
# Coordinates: {'X': 120.001, 'Y': 100.001, 'Z': 0.705}
# Point ID: 13,12
# Coordinates: {'X': 120.001, 'Y': 110.001, 'Z': 0.704}
# Point ID: 13,13
# Coordinates: {'X': 120.001, 'Y': 120.001, 'Z': 0.646}

# %%
# Group the data by X coordinate
plt.figure(figsize=(40, 20))

grouped_data = {}
for point_id, coords in formatted_data:
    x_coord = coords['X']
    if x_coord not in grouped_data:
        grouped_data[x_coord] = []
    grouped_data[x_coord].append((point_id, coords['Y'], coords['Z']))

# Plot each group separately
for x, points in grouped_data.items():
    point_ids, ys, zs = zip(*points)
    plt.scatter(ys, zs, label=f'X = {x}')

# Add labels and legend
plt.xlabel('Y [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Z [mm]', fontsize=14, fontweight='bold')
plt.title('Scatter Plot of Points with the Same X Coordinate', fontsize=11, fontweight='bold')
plt.legend()
plt.show()

# %%
# Extract X, Y, and Z values from the data
x_values = []
y_values = []
z_values = []
for position, coords in formatted_data:
    x_values.append(coords['X'])
    y_values.append(coords['Y'])
    z_values.append(coords['Z'])

# Perform linear regression to fit a line to the data
slope_y, intercept_y = np.polyfit(y_values, z_values, 1)

# Calculate the fitted line
fitted_line_y = slope_y * np.array(y_values) + intercept_y

# Subtract the fitted line from the original Z values to correct for the slope in the Y direction
corrected_z_values_y = np.array(z_values) - fitted_line_y

# Plot the original and corrected Z values
plt.figure(figsize=(10, 6))
plt.scatter(y_values, z_values, label='Original Z Values')
plt.plot(y_values, fitted_line_y, color='red', label='Fitted Line')
plt.scatter(y_values, corrected_z_values_y, color='green', label='Corrected Z Values')
plt.xlabel('Y [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Z [mm]', fontsize=14, fontweight='bold')
plt.title('Original and Corrected Z Values (Y direction)', fontsize=11, fontweight='bold')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create a regular grid to interpolate onto
x_grid = np.linspace(min(x_values), max(x_values), 100)
y_grid = np.linspace(min(y_values), max(y_values), 100)
X, Y = np.meshgrid(x_grid, y_grid)

# Interpolate Z values onto the grid
Z = griddata((x_values, y_values), corrected_z_values_y, (X, Y), method='linear')

# Plot the heatmap
plt.figure(figsize=(10, 6))
plt.pcolormesh(X, Y, Z, cmap='viridis')
plt.colorbar(label='Z [mm]')
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Interpolated Heatmap of XYZ with Corrected Z -Simultaneous Fit', fontsize=11, fontweight='bold')
plt.show()

# %%
# Flatten the interpolated Z values
Z_flat = Z.flatten()

# Calculate the Root Mean Square (RMS) excluding NaN values
rms = np.sqrt(np.nanmean(Z_flat**2))

print("Root Mean Square (RMS) of the heatmap (excluding NaN points):", rms)
# Out:
# Root Mean Square (RMS) of the heatmap (excluding NaN points): 0.11542738993812607

# %%
std_dev = np.std(Z_flat, ddof=1)
RMS = round(std_dev, 6)
print("RMS RAW =", RMS)
# Out:
# RMS RAW = 0.115398

# %%
# Create the histogram
plt.figure(figsize=(12, 10))

plt.hist(corrected_z_values_y, bins=50, color='green', edgecolor='black', alpha=0.8)
# Add mean, median, and standard deviation lines
mean_value = np.mean(corrected_z_values_y)
median_value = np.median(corrected_z_values_y)
std_dev = np.std(corrected_z_values_y)

plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_value:.2f}')
plt.axvline(median_value, color='green', linestyle='dashed', linewidth=1, label=f'Median: {median_value:.2f}')
plt.axvline(mean_value + std_dev, color='orange', linestyle='dashed', linewidth=1, label=f'Standard Deviation: {std_dev:.2f}')
plt.axvline(mean_value - std_dev, color='orange', linestyle='dashed', linewidth=1)

plt.legend()
plt.xlabel('Z [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Entries', fontsize=14, fontweight='bold')
plt.title('Histogram of Z corrected Values -Simultaneous Fit', fontsize=11, fontweight='bold')
plt.grid(True)
plt.show()

# %%
# Group the data by X coordinate
plt.figure(figsize=(20, 12))

grouped_data = {}
for point_id, coords in formatted_data:
    y_coord = coords['Y']
    if y_coord not in grouped_data:
        grouped_data[y_coord] = []
    grouped_data[y_coord].append((point_id, coords['X'], coords['Z']))

# Plot each group separately
for y, points in grouped_data.items():
    point_ids, xs, zs = zip(*points)
    plt.scatter(xs, zs, label=f'Y = {y}')

# Add labels and legend
plt.xlabel('Y [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Z [mm]', fontsize=14, fontweight='bold')
plt.title('Scatter Plot of Points with the Same Y Coordinate', fontsize=11, fontweight='bold')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(11, 11))

Z = griddata((x_values, y_values), z_values, (X, Y), method='linear')

# Plot the heatmap
plt.subplot(2, 1, 1)
im = plt.pcolormesh(X, Y, Z, cmap='viridis')
plt.colorbar(im, label='Z [mm]')
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Heatmap of XYZ',  fontsize=11, fontweight='bold')

# Overlay XY points on top of the heatmap
plt.scatter(x_values, y_values, color='brown', marker='o', label='XY Points')
plt.legend()

Z = griddata((x_values, y_values), corrected_z_values_y, (X, Y), method='linear')

# Plot the scatter plot
plt.subplot(2, 1, 2)
sc = plt.pcolormesh(X, Y, Z, cmap='viridis')
plt.colorbar(sc, label='Z [mm]')
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Corrected Heatmap of XYZ - Simultaneous Fit', fontsize=11, fontweight='bold')
# Overlay XY points on top of the heatmap
plt.scatter(x_values, y_values, color='brown', marker='o', label='XY Points')
plt.legend()


plt.tight_layout()
plt.show()

# %% [raw]
# Fitting a plane to a set of 3D points is a common technique used in planarity analysis. This technique is often employed in various fields such as computer vision, robotics, geomatics, and manufacturing to assess the flatness or planarity of a surface.
#
# The fitting of a plane involves finding the best-fitting plane that minimizes the sum of squared distances between the plane and the data points. This can be achieved using mathematical techniques such as least squares regression or principal component analysis (PCA).
#
# Once the plane is fitted to the data, various metrics can be calculated to assess the planarity, such as the root mean square (RMS) of the distances between the data points and the fitted plane, or the deviation of the data points from the plane.
#
# Overall, fitting a plane to the data provides a quantitative measure of planarity and can be a useful tool for quality control, surface inspection, and geometric analysis.

# %% [raw]
# The goal is to find the values of a and b that minimize the sum of the squared residuals. This is why it's called "least squares" regression.

# %%
def fit_plane(formatted_data):   
    # Extract X, Y, and Z coordinates from the formatted data 
    X = np.array([coords['X'] for _, coords in formatted_data])
    Y = np.array([coords['Y'] for _, coords in formatted_data])
    Z = np.array([coords['Z'] for _, coords in formatted_data])
    
    # Construct the design matrix contains the independent variables
    A = np.vstack((X, Y, np.ones_like(X))).T #stacking X, Y, and a column of ones (for the intercept term) vertically and transposing it. 
    #This design matrix is used in the least squares regression.
    
    # Perform least squares regression to find the plane parameters
    #params, _, _, _ = np.linalg.lstsq(A, Z, rcond=None) 
    params, residuals, rank, singular_values = np.linalg.lstsq(A, Z, rcond=None)

    #contains the coefficients of the plane equation (a, b, c) that minimize the sum of squared residuals.
    #assigned to _ to indicate that they're being ignored.
    
    # Extract plane parameters (coefficients of the plane equation: ax + by + c = z)
    a, b, c = params
    residuals = residuals  #the residual sum of squares, which represents the sum of squared differences between the observed and predicted values of Z
    singular_values = singular_values # the singular values of A
    return a, b, c, residuals, singular_values

a, b, c, residuals, singular_values = fit_plane(formatted_data)
print("Plane parameters: a =", a, ", b =", b, ", c =", c, ", residuals = ", residuals, ", singular values = ", singular_values)
# Out:
# Plane parameters: a = -0.0023444209636517372 , b = 0.007753719357565515 , c = 0.07477988233305172 , residuals =  [1.44994846] , singular values =  [1205.64590662  486.41546028    5.24482433]

# %%
# Visualize the fitted plane and original points
def visualize_plane_and_points(formatted_data, a, b, c, residuals, singular_values):
    X = np.array([coords['X'] for _, coords in formatted_data])
    Y = np.array([coords['Y'] for _, coords in formatted_data])
    Z = np.array([coords['Z'] for _, coords in formatted_data])
    
    # Create a meshgrid for X and Y coordinates
    X_grid, Y_grid = np.meshgrid(np.linspace(min(X), max(X), 10), np.linspace(min(Y), max(Y), 10))
    
    # Calculate Z values for the fitted plane
    Z_plane = a * X_grid + b * Y_grid + c

    # Plot the points
    fig = plt.figure(figsize=(20, 15))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(X, Y, Z, color='b', label='Original Points')
    
    # Plot the fitted plane
    ax.plot_surface(X_grid, Y_grid, Z_plane, alpha=0.5, color='r', label='Fitted Plane')
    
    # Set labels and title
    ax.set_xlabel('X [mm]', fontsize=14, fontweight='bold')
    ax.set_xlabel('X [mm]', fontsize=14, fontweight='bold')
    ax.set_ylabel('Y [mm]', fontsize=14, fontweight='bold')
    ax.set_zlabel('Z [mm]', fontsize=14, fontweight='bold')
    ax.set_title('Planarity Fitted Plane', fontsize=11, fontweight='bold')
    
    # Add legend
    ax.legend()
    
    # Show plot
    plt.show()

# %%
#a, b, c = fit_plane(formatted_data)
a, b, c, residuals, singular_values = fit_plane(formatted_data)
#visualize_plane_and_points(formatted_data, a, b, c)
visualize_plane_and_points(formatted_data, a, b, c, residuals, singular_values)

# %%
def calculate_planarity_metrics(formatted_data, a, b, c):
    # Extract X, Y, and Z coordinates from the formatted data
    X = np.array([coords['X'] for _, coords in formatted_data])
    Y = np.array([coords['Y'] for _, coords in formatted_data])
    Z = np.array([coords['Z'] for _, coords in formatted_data])
    
    # Calculate distances from points to the fitted plane
    distances = np.abs(a * X + b * Y - Z + c) / np.sqrt(a**2 + b**2 + 1)
    
    # Calculate RMS of the distances
    rms_distance = np.sqrt(np.mean(distances**2))
    
    # Calculate deviation of the points from the plane
    deviation = distances.mean()
    
    return rms_distance, deviation

# %%
rms_distance, deviation = calculate_planarity_metrics(formatted_data, a, b, c)
print("RMS Distance:", rms_distance) #the root mean square (RMS) of the distances between the data points and the fitted plane
print("Deviation:", deviation) #the deviation of the data points from the plane
# Out:
# RMS Distance: 0.09262296554233379
# Deviation: 0.0734862524473062

# %% [raw]
# It calculates the distances from each point to the fitted plane, then computes the RMS of these distances and the deviation of the points from the plane.

# %%
# Define the point IDs
point_4_4_id = '4,4'
point_4_13_id = '4,13'
point_13_4_id = '13,4'
point_13_13_id = '13,13'


# Find the XY coordinates corresponding to the specified point IDs
point_4_4_xy = None
point_4_13_xy = None
point_13_4_xy = None
point_13_13_xy = None

for point_id, coords in formatted_data:
    if point_id == point_4_4_id:
        point_4_4_xy = (coords['X'], coords['Y'])
    elif point_id == point_4_13_id:
        point_4_13_xy = (coords['X'], coords['Y'])
    elif point_id == point_13_4_id:
        point_13_4_xy = (coords['X'], coords['Y'])
    elif point_id == point_13_13_id:
        point_13_13_xy = (coords['X'], coords['Y'])

# Plot the heatmap of Z
plt.figure(figsize=(12, 6))
plt.pcolormesh(X, Y, Z, cmap='viridis')
plt.colorbar(label='Z [mm]')
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Heatmap of Z Measured', fontsize=11, fontweight='bold')

# Overlay XY points on top of the heatmap
plt.scatter(x_values, y_values, color='red', marker='o', label='XY Points')

## Connect specified points with lines
# plt.plot([point_4_13_xy[0], point_13_13_xy[0]], [point_4_13_xy[1], point_13_13_xy[1]], color='blue', linestyle='-', linewidth=2)
# plt.plot([point_13_4_xy[0], point_13_13_xy[0]], [point_13_4_xy[1], point_13_13_xy[1]], color='blue', linestyle='-', linewidth=2) #perpendicular
# plt.plot([point_4_4_xy[0], point_4_13_xy[0]], [point_4_4_xy[1], point_4_13_xy[1]], color='blue', linestyle='-', linewidth=2) #perpendicular
# plt.plot([point_4_4_xy[0], point_13_4_xy[0]], [point_4_4_xy[1], point_13_4_xy[1]], color='blue', linestyle='-', linewidth=2) #perpendicular

plt.legend()
plt.tight_layout()
plt.show()

# %%
x_values = np.array([coords['X'] for _, coords in formatted_data])
y_values = np.array([coords['Y'] for _, coords in formatted_data])
z_values = np.array([coords['Z'] for _, coords in formatted_data])

# Correct the Z values based on the fitted plane
corrected_z_values = z_values - (a * x_values + b * y_values + c)

# Create a grid for the heatmap
X, Y = np.meshgrid(np.linspace(min(x_values), max(x_values), 100),
                   np.linspace(min(y_values), max(y_values), 100))

# Interpolate the corrected Z values onto the grid
Z_corrected = griddata((x_values, y_values), corrected_z_values, (X, Y), method='linear')


# Plot the heatmap of corrected Z values
plt.figure(figsize=(10, 10))
plt.pcolormesh(X, Y, Z_corrected, cmap='viridis')
plt.colorbar(label='Corrected fit plane Z [mm]')
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Heatmap of Corrected Z Values - Fit Plane', fontsize=11, fontweight='bold')

# Overlay XY points on top of the heatmap
plt.scatter(x_values, y_values, color='red', marker='o', label='XY Points')

plt.legend()
plt.tight_layout()
plt.show()

# %%
# Flatten the 2D array Z_corrected into a 1D array
Z_corrected_flat = corrected_z_values.flatten()

# Plot the histogram of the corrected Z values
plt.figure(figsize=(12, 10))
plt.hist(Z_corrected_flat, bins=50, color='green', edgecolor='black', alpha=0.8)
# Add mean, median, and standard deviation lines
mean_value = np.mean(Z_corrected_flat)
median_value = np.median(Z_corrected_flat)
std_deviation = np.std(Z_corrected_flat)
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean_value:.2f}')
plt.axvline(median_value, color='blue', linestyle='dashed', linewidth=1, label=f'Median: {median_value:.2f}')
plt.axvline(mean_value + std_deviation, color='orange', linestyle='dashed', linewidth=1, label=f'Standard Deviation: {std_deviation:.2f}')
plt.axvline(mean_value - std_deviation, color='orange', linestyle='dashed', linewidth=1)
plt.xlabel('Corrected Z [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Entries', fontsize=14, fontweight='bold')
plt.title('Histogram of Corrected Z Values - Fit plane', fontsize=11, fontweight='bold')
plt.legend()
plt.show()

# %%
X_test = np.column_stack((x_values, y_values, np.ones_like(x_values)))

# Fit linear regression model
model = LinearRegression().fit(X_test, z_values)

# Get the coefficients (normal vector) of the plane
normal_vector = model.coef_
intercept = model.intercept_

# Generate points on the plane for visualization
x_plane = np.linspace(min(x_values), max(x_values), 10)
y_plane = np.linspace(min(y_values), max(y_values), 10)
x_plane, y_plane = np.meshgrid(x_plane, y_plane)
z_plane = normal_vector[0] * x_plane + normal_vector[1] * y_plane + intercept

# Plot the original data points
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_values, y_values, z_values, c='b', marker='o', label='Data Points')

# Plot the plane
ax.plot_surface(x_plane, y_plane, z_plane, alpha=0.5)

ax.set_xlabel('X [mm]', fontsize=14, fontweight='bold')
ax.set_ylabel('Y [mm]', fontsize=14, fontweight='bold')
ax.set_zlabel('Z [mm]', fontsize=14, fontweight='bold')
ax.set_title('Plane Fitting')

plt.legend()
plt.show()
