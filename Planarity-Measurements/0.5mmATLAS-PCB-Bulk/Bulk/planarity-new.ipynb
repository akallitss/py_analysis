# %%
import re
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import griddata
from sklearn.linear_model import LinearRegression
from mpl_toolkits.mplot3d import Axes3D

# %%
##filename = 'Mearure-planarity-PCB-WURTH-Thin.txt'
#filename = 'Mearure-planarity-TOPlayer-sparePCB-Rohacel-original.txt'
filename = 'big-pillars-planarity-after-stffener.txt'
with open(filename, 'r', encoding='ISO-8859-1') as file:
    lines = file.readlines()

for line in lines: print(line.strip())
# Out:
# Elément            Réel       Val. nom.           Ecart       Tol. sup.       Tol. inf.           OK/HT
# (Dév PR)        (Tol PR)
# Point-1(De 1 pt)
# Coord. X =           72,011
# Coord. Y =          102,560
# Coord. Z =           11,480
#
# Point-2(De 1 pt)
# Coord. X =            0,004
# Coord. Y =           -0,004
# Coord. Z =            0,000
#
# Point-3(De 1 pt)
# Coord. X =           -0,002
# Coord. Y =           10,016
# Coord. Z =            0,009
#
# Point-4(De 1 pt)
# Coord. X =            0,020
# Coord. Y =           20,036
# Coord. Z =            0,006
#
# Point-5(De 1 pt)
# Coord. X =            0,020
# Coord. Y =           30,041
# Coord. Z =            0,004
#
# Point-6(De 1 pt)
# Coord. X =            0,014
# Coord. Y =           40,034
# Coord. Z =            0,003
#
# Point-7(De 1 pt)
# Coord. X =            0,014
# Coord. Y =           50,046
# Coord. Z =            0,000
#
# Point-8(De 1 pt)
# Coord. X =            0,031
# Coord. Y =           60,046
# Coord. Z =           -0,006
#
# Point-9(De 1 pt)
# Coord. X =            0,044
# Coord. Y =           70,070
# Coord. Z =           -0,013
#
# Point-10(De 1 pt)
# Coord. X =            0,049
# Coord. Y =           80,079
# Coord. Z =           -0,020
#
# Point-11(De 1 pt)
# Coord. X =            9,976
# Coord. Y =          -10,020
# Coord. Z =            0,011
#
# Point-12(De 1 pt)
# Coord. X =           10,000
# Coord. Y =           -0,012
# Coord. Z =            0,013
#
# Point-13(De 1 pt)
# Coord. X =           10,004
# Coord. Y =           10,000
# Coord. Z =            0,011
#
# Point-14(De 1 pt)
# Coord. X =           10,002
# Coord. Y =           20,007
# Coord. Z =            0,008
#
# Point-15(De 1 pt)
# Coord. X =           10,032
# Coord. Y =           30,015
# Coord. Z =            0,007
#
# Point-16(De 1 pt)
# Coord. X =           10,028
# Coord. Y =           40,029
# Coord. Z =            0,006
#
# Point-17(De 1 pt)
# Coord. X =           10,038
# Coord. Y =           50,037
# Coord. Z =            0,003
#
# Point-18(De 1 pt)
# Coord. X =           10,032
# Coord. Y =           60,040
# Coord. Z =           -0,001
#
# Point-19(De 1 pt)
# Coord. X =           10,064
# Coord. Y =           70,060
# Coord. Z =           -0,008
#
# Point-20(De 1 pt)
# Coord. X =           10,075
# Coord. Y =           80,065
# Coord. Z =           -0,013
#
# Point-21(De 1 pt)
# Coord. X =           10,074
# Coord. Y =           90,077
# Coord. Z =           -0,020
#
# Point-22(De 1 pt)
# Coord. X =           20,004
# Coord. Y =          -10,034
# Coord. Z =            0,017
#
# Point-23(De 1 pt)
# Coord. X =           20,010
# Coord. Y =           -0,020
# Coord. Z =            0,014
#
# Point-24(De 1 pt)
# Coord. X =           20,010
# Coord. Y =           10,000
# Coord. Z =            0,011
#
# Point-25(De 1 pt)
# Coord. X =           20,025
# Coord. Y =           20,009
# Coord. Z =            0,008
#
# Point-26(De 1 pt)
# Coord. X =           20,029
# Coord. Y =           30,010
# Coord. Z =            0,008
#
# Point-27(De 1 pt)
# Coord. X =           20,040
# Coord. Y =           40,022
# Coord. Z =            0,009
#
# Point-28(De 1 pt)
# Coord. X =           20,056
# Coord. Y =           50,041
# Coord. Z =            0,008
#
# Point-30(De 1 pt)
# Coord. X =           20,039
# Coord. Y =           60,023
# Coord. Z =            0,002
#
# Point-31(De 1 pt)
# Coord. X =           20,050
# Coord. Y =           70,047
# Coord. Z =           -0,005
#
# Point-32(De 1 pt)
# Coord. X =           20,074
# Coord. Y =           80,065
# Coord. Z =           -0,011
#
# Point-33(De 1 pt)
# Coord. X =           20,077
# Coord. Y =           90,074
# Coord. Z =           -0,019
#
# Point-34(De 1 pt)
# Coord. X =           30,022
# Coord. Y =          -10,028
# Coord. Z =            0,015
#
# Point-35(De 1 pt)
# Coord. X =           30,028
# Coord. Y =           -0,012
# Coord. Z =            0,013
#
# Point-36(De 1 pt)
# Coord. X =           30,025
# Coord. Y =            9,986
# Coord. Z =            0,007
#
# Point-37(De 1 pt)
# Coord. X =           30,033
# Coord. Y =           20,003
# Coord. Z =            0,008
#
# Point-38(De 1 pt)
# Coord. X =           30,033
# Coord. Y =           29,993
# Coord. Z =            0,009
#
# Point-39(De 1 pt)
# Coord. X =           30,051
# Coord. Y =           40,019
# Coord. Z =            0,010
#
# Point-40(De 1 pt)
# Coord. X =           30,049
# Coord. Y =           50,039
# Coord. Z =            0,007
#
# Point-41(De 1 pt)
# Coord. X =           30,065
# Coord. Y =           60,035
# Coord. Z =            0,001
#
# Point-42(De 1 pt)
# Coord. X =           30,067
# Coord. Y =           70,040
# Coord. Z =           -0,002
#
# Point-43(De 1 pt)
# Coord. X =           30,065
# Coord. Y =           80,046
# Coord. Z =           -0,009
#
# Point-44(De 1 pt)
# Coord. X =           30,075
# Coord. Y =           90,066
# Coord. Z =           -0,019
#
# Point-46(De 1 pt)
# Coord. X =           40,016
# Coord. Y =           -0,037
# Coord. Z =            0,016
#
# Point-47(De 1 pt)
# Coord. X =           40,017
# Coord. Y =            9,981
# Coord. Z =            0,013
#
# Point-48(De 1 pt)
# Coord. X =           40,044
# Coord. Y =           19,984
# Coord. Z =            0,012
#
# Point-49(De 1 pt)
# Coord. X =           40,045
# Coord. Y =           29,989
# Coord. Z =            0,012
#
# Point-50(De 1 pt)
# Coord. X =           40,052
# Coord. Y =           40,010
# Coord. Z =            0,012
#
# Point-51(De 1 pt)
# Coord. X =           40,079
# Coord. Y =           50,022
# Coord. Z =            0,007
#
# Point-52(De 1 pt)
# Coord. X =           40,077
# Coord. Y =           60,016
# Coord. Z =            0,003
#
# Point-53(De 1 pt)
# Coord. X =           40,072
# Coord. Y =           70,035
# Coord. Z =            0,001
#
# Point-54(De 1 pt)
# Coord. X =           40,069
# Coord. Y =           80,048
# Coord. Z =           -0,006
#
# Point-55(De 1 pt)
# Coord. X =           40,088
# Coord. Y =           90,058
# Coord. Z =           -0,013
#
# Point-56(De 1 pt)
# Coord. X =           40,026
# Coord. Y =          -10,024
# Coord. Z =            0,016
#
# Point-58(De 1 pt)
# Coord. X =           50,019
# Coord. Y =          -10,046
# Coord. Z =            0,013
#
# Point-59(De 1 pt)
# Coord. X =           50,038
# Coord. Y =           -0,026
# Coord. Z =            0,014
#
# Point-60(De 1 pt)
# Coord. X =           50,040
# Coord. Y =            9,974
# Coord. Z =            0,011
#
# Point-61(De 1 pt)
# Coord. X =           50,049
# Coord. Y =           19,982
# Coord. Z =            0,014
#
# Point-62(De 1 pt)
# Coord. X =           50,051
# Coord. Y =           29,986
# Coord. Z =            0,015
#
# Point-63(De 1 pt)
# Coord. X =           50,051
# Coord. Y =           39,990
# Coord. Z =            0,015
#
# Point-64(De 1 pt)
# Coord. X =           50,072
# Coord. Y =           50,009
# Coord. Z =            0,010
#
# Point-65(De 1 pt)
# Coord. X =           50,074
# Coord. Y =           60,017
# Coord. Z =            0,007
#
# Point-66(De 1 pt)
# Coord. X =           50,093
# Coord. Y =           70,034
# Coord. Z =            0,002
#
# Point-67(De 1 pt)
# Coord. X =           50,095
# Coord. Y =           80,047
# Coord. Z =           -0,004
#
# Point-68(De 1 pt)
# Coord. X =           50,106
# Coord. Y =           90,046
# Coord. Z =           -0,010
#
# Point-69(De 1 pt)
# Coord. X =           60,039
# Coord. Y =          -10,059
# Coord. Z =            0,008
#
# Point-70(De 1 pt)
# Coord. X =           60,039
# Coord. Y =           -0,050
# Coord. Z =            0,013
#
# Point-71(De 1 pt)
# Coord. X =           60,037
# Coord. Y =            9,953
# Coord. Z =            0,011
#
# Point-72(De 1 pt)
# Coord. X =           60,039
# Coord. Y =           19,971
# Coord. Z =            0,015
#
# Point-73(De 1 pt)
# Coord. X =           60,059
# Coord. Y =           29,977
# Coord. Z =            0,019
#
# Point-74(De 1 pt)
# Coord. X =           60,065
# Coord. Y =           39,993
# Coord. Z =            0,019
#
# Point-75(De 1 pt)
# Coord. X =           60,065
# Coord. Y =           50,007
# Coord. Z =            0,015
#
# Point-76(De 1 pt)
# Coord. X =           60,071
# Coord. Y =           60,018
# Coord. Z =            0,010
#
# Point-77(De 1 pt)
# Coord. X =           60,077
# Coord. Y =           70,013
# Coord. Z =            0,004
#
# Point-78(De 1 pt)
# Coord. X =           60,098
# Coord. Y =           90,045
# Coord. Z =           -0,005
#
# Point-79(De 1 pt)
# Coord. X =           60,111
# Coord. Y =           80,052
# Coord. Z =           -0,001
#
# Point-80(De 1 pt)
# Coord. X =           70,054
# Coord. Y =          -10,059
# Coord. Z =            0,015
#
# Point-81(De 1 pt)
# Coord. X =           70,056
# Coord. Y =           -0,047
# Coord. Z =            0,017
#
# Point-82(De 1 pt)
# Coord. X =           70,054
# Coord. Y =            9,952
# Coord. Z =            0,015
#
# Point-83(De 1 pt)
# Coord. X =           70,078
# Coord. Y =           19,975
# Coord. Z =            0,019
#
# Point-84(De 1 pt)
# Coord. X =           70,078
# Coord. Y =           29,985
# Coord. Z =            0,023
#
# Point-85(De 1 pt)
# Coord. X =           70,082
# Coord. Y =           39,983
# Coord. Z =            0,023
#
# Point-86(De 1 pt)
# Coord. X =           70,078
# Coord. Y =           49,982
# Coord. Z =            0,019
#
# Point-87(De 1 pt)
# Coord. X =           70,092
# Coord. Y =           60,002
# Coord. Z =            0,013
#
# Point-88(De 1 pt)
# Coord. X =           70,097
# Coord. Y =           70,016
# Coord. Z =            0,007
#
# Point-89(De 1 pt)
# Coord. X =           70,117
# Coord. Y =           80,030
# Coord. Z =            0,002
#
# Point-90(De 1 pt)
# Coord. X =           70,125
# Coord. Y =           90,035
# Coord. Z =           -0,003
#
# Point-91(De 1 pt)
# Coord. X =           80,071
# Coord. Y =          -10,054
# Coord. Z =            0,022
#
# Point-92(De 1 pt)
# Coord. X =           80,061
# Coord. Y =           -0,059
# Coord. Z =            0,030
#
# Point-93(De 1 pt)
# Coord. X =           80,067
# Coord. Y =            9,945
# Coord. Z =            0,026
#
# Point-94(De 1 pt)
# Coord. X =           80,067
# Coord. Y =           19,961
# Coord. Z =            0,029
#
# Point-95(De 1 pt)
# Coord. X =           80,082
# Coord. Y =           29,964
# Coord. Z =            0,031
#
# Point-96(De 1 pt)
# Coord. X =           80,104
# Coord. Y =           39,991
# Coord. Z =            0,029
#
# Point-97(De 1 pt)
# Coord. X =           80,104
# Coord. Y =           49,994
# Coord. Z =            0,022
#
# Point-98(De 1 pt)
# Coord. X =           80,107
# Coord. Y =           59,993
# Coord. Z =            0,014
#
# Point-99(De 1 pt)
# Coord. X =           80,121
# Coord. Y =           70,000
# Coord. Z =            0,006
#
# Point-100(De 1 pt)
# Coord. X =           80,125
# Coord. Y =           80,024
# Coord. Z =            0,004
#
# Point-101(De 1 pt)
# Coord. X =           80,131
# Coord. Y =           90,024
# Coord. Z =            0,002
#
# Point-102(De 1 pt)
# Coord. X =           90,071
# Coord. Y =          -10,063
# Coord. Z =            0,022
#
# Point-103(De 1 pt)
# Coord. X =           90,058
# Coord. Y =           -0,066
# Coord. Z =            0,031
#
# Point-104(De 1 pt)
# Coord. X =           90,077
# Coord. Y =            9,947
# Coord. Z =            0,035
#
# Point-105(De 1 pt)
# Coord. X =           90,082
# Coord. Y =           19,962
# Coord. Z =            0,041
#
# Point-106(De 1 pt)
# Coord. X =           90,080
# Coord. Y =           29,946
# Coord. Z =            0,039
#
# Point-107(De 1 pt)
# Coord. X =           90,100
# Coord. Y =           39,982
# Coord. Z =            0,035
#
# Point-108(De 1 pt)
# Coord. X =           90,098
# Coord. Y =           49,986
# Coord. Z =            0,025
#
# Point-109(De 1 pt)
# Coord. X =           90,106
# Coord. Y =           59,990
# Coord. Z =            0,016
#
# Point-110(De 1 pt)
# Coord. X =           90,121
# Coord. Y =           70,002
# Coord. Z =            0,011
#
# Point-111(De 1 pt)
# Coord. X =           90,123
# Coord. Y =           79,997
# Coord. Z =            0,009
#
# Point-112(De 1 pt)
# Coord. X =           90,117
# Coord. Y =           90,028
# Coord. Z =            0,007
#
# Point-113(De 1 pt)
# Coord. X =          100,070
# Coord. Y =           -0,087
# Coord. Z =            0,020
#
# Point-114(De 1 pt)
# Coord. X =          100,083
# Coord. Y =            9,935
# Coord. Z =            0,026
#
# Point-115(De 1 pt)
# Coord. X =          100,091
# Coord. Y =           19,947
# Coord. Z =            0,028
#
# Point-116(De 1 pt)
# Coord. X =          100,095
# Coord. Y =           29,940
# Coord. Z =            0,026
#
# Point-117(De 1 pt)
# Coord. X =          100,103
# Coord. Y =           39,955
# Coord. Z =            0,024
#
# Point-118(De 1 pt)
# Coord. X =          100,115
# Coord. Y =           49,973
# Coord. Z =            0,019
#
# Point-119(De 1 pt)
# Coord. X =          100,135
# Coord. Y =           59,992
# Coord. Z =            0,009
#
# Point-120(De 1 pt)
# Coord. X =          100,141
# Coord. Y =           69,991
# Coord. Z =            0,005
#
# Point-121(De 1 pt)
# Coord. X =          100,145
# Coord. Y =           80,010
# Coord. Z =            0,009
#
# Plan-1(De 118 pt)
# Coord. X =           49,639
# Coord. Y =           39,662
# Coord. Z =            0,010
# Angle (XY) =          134,837
# Angle X =           90,014
# Angle Y =           89,986
# Angle Z =            0,020
# Planéité =                                            0,033
# Plan. min =                                            0,016
# Plan. max =                                            0,017

# %%
# Initialize variables to store point IDs and corresponding coordinates
point_data = []

# Regular expressions to match point ID and coordinate lines
# point_id_pattern = r'\[([\d,]+)\]'
# coord_pattern = r'Coord\. ([XYZ]) =\s*([-+]?\d+,\d+)'
point_id_pattern = r'Point-(\d+)\(De 1 pt\)'
coord_pattern = r'Coord\. ([XYZ]) =\s*([-+]?\d+,\d+)'

# Extract point IDs and coordinates from lines
current_point_id = None
current_coords = {}

skipped_lines = 0
for line in lines:
    if skipped_lines < 3 and not line.startswith('Plan'):
        skipped_lines += 1
        continue
    elif line.startswith('Plan'):
        break
    # Check if the line contains a point ID
    match_id = re.search(point_id_pattern, line)
    if match_id:
        current_point_id = match_id.group(1)
        current_coords = {}
        continue

    # Check if the line contains a coordinate
    match_coord = re.search(coord_pattern, line)
    if match_coord and current_point_id:
        coord_type = match_coord.group(1)
        coord_value = float(match_coord.group(2).replace(',', '.'))
        
        # Check if the Y coordinate is not equal to 0.002
        if coord_type == 'Y' and coord_value == 0.002:
            continue  # Skip this coordinate
        if coord_type == 'X' and coord_value == 0.0 and coord_type == 'Y' and coord_value == 50.0: 
            continue
        if coord_type == 'X' and coord_value == 80.0:
            if coord_type == 'Y' and coord_value == 20.0:
                continue
        current_coords[coord_type] = coord_value

        # If all coordinates are found, add them to the point data
        if len(current_coords) == 3 and current_coords['Z']<5.: #and current_coords['Y']>0 and current_coords['Y']!= 70.412 and current_coords['Y']!= 70.36  :# and current_coords['X'] == 150. and current_coords['Y'] == 150.:
        #if len(current_coords) == 3 and current_coords['X']>70.0 and current_coords['Y']<25.:
            point_data.append((current_point_id, current_coords))
            current_point_id = None

# Print the extracted point data
for point_id, coords in point_data:
    print("Point ID:", point_id)
    print("Coordinates:", coords)
# Out:
# Point ID: 2
# Coordinates: {'X': 0.004, 'Y': -0.004, 'Z': 0.0}
# Point ID: 3
# Coordinates: {'X': -0.002, 'Y': 10.016, 'Z': 0.009}
# Point ID: 4
# Coordinates: {'X': 0.02, 'Y': 20.036, 'Z': 0.006}
# Point ID: 5
# Coordinates: {'X': 0.02, 'Y': 30.041, 'Z': 0.004}
# Point ID: 6
# Coordinates: {'X': 0.014, 'Y': 40.034, 'Z': 0.003}
# Point ID: 7
# Coordinates: {'X': 0.014, 'Y': 50.046, 'Z': 0.0}
# Point ID: 8
# Coordinates: {'X': 0.031, 'Y': 60.046, 'Z': -0.006}
# Point ID: 9
# Coordinates: {'X': 0.044, 'Y': 70.07, 'Z': -0.013}
# Point ID: 10
# Coordinates: {'X': 0.049, 'Y': 80.079, 'Z': -0.02}
# Point ID: 11
# Coordinates: {'X': 9.976, 'Y': -10.02, 'Z': 0.011}
# Point ID: 12
# Coordinates: {'X': 10.0, 'Y': -0.012, 'Z': 0.013}
# Point ID: 13
# Coordinates: {'X': 10.004, 'Y': 10.0, 'Z': 0.011}
# Point ID: 14
# Coordinates: {'X': 10.002, 'Y': 20.007, 'Z': 0.008}
# Point ID: 15
# Coordinates: {'X': 10.032, 'Y': 30.015, 'Z': 0.007}
# Point ID: 16
# Coordinates: {'X': 10.028, 'Y': 40.029, 'Z': 0.006}
# Point ID: 17
# Coordinates: {'X': 10.038, 'Y': 50.037, 'Z': 0.003}
# Point ID: 18
# Coordinates: {'X': 10.032, 'Y': 60.04, 'Z': -0.001}
# Point ID: 19
# Coordinates: {'X': 10.064, 'Y': 70.06, 'Z': -0.008}
# Point ID: 20
# Coordinates: {'X': 10.075, 'Y': 80.065, 'Z': -0.013}
# Point ID: 21
# Coordinates: {'X': 10.074, 'Y': 90.077, 'Z': -0.02}
# Point ID: 22
# Coordinates: {'X': 20.004, 'Y': -10.034, 'Z': 0.017}
# Point ID: 23
# Coordinates: {'X': 20.01, 'Y': -0.02, 'Z': 0.014}
# Point ID: 24
# Coordinates: {'X': 20.01, 'Y': 10.0, 'Z': 0.011}
# Point ID: 25
# Coordinates: {'X': 20.025, 'Y': 20.009, 'Z': 0.008}
# Point ID: 26
# Coordinates: {'X': 20.029, 'Y': 30.01, 'Z': 0.008}
# Point ID: 27
# Coordinates: {'X': 20.04, 'Y': 40.022, 'Z': 0.009}
# Point ID: 28
# Coordinates: {'X': 20.056, 'Y': 50.041, 'Z': 0.008}
# Point ID: 30
# Coordinates: {'X': 20.039, 'Y': 60.023, 'Z': 0.002}
# Point ID: 31
# Coordinates: {'X': 20.05, 'Y': 70.047, 'Z': -0.005}
# Point ID: 32
# Coordinates: {'X': 20.074, 'Y': 80.065, 'Z': -0.011}
# Point ID: 33
# Coordinates: {'X': 20.077, 'Y': 90.074, 'Z': -0.019}
# Point ID: 34
# Coordinates: {'X': 30.022, 'Y': -10.028, 'Z': 0.015}
# Point ID: 35
# Coordinates: {'X': 30.028, 'Y': -0.012, 'Z': 0.013}
# Point ID: 36
# Coordinates: {'X': 30.025, 'Y': 9.986, 'Z': 0.007}
# Point ID: 37
# Coordinates: {'X': 30.033, 'Y': 20.003, 'Z': 0.008}
# Point ID: 38
# Coordinates: {'X': 30.033, 'Y': 29.993, 'Z': 0.009}
# Point ID: 39
# Coordinates: {'X': 30.051, 'Y': 40.019, 'Z': 0.01}
# Point ID: 40
# Coordinates: {'X': 30.049, 'Y': 50.039, 'Z': 0.007}
# Point ID: 41
# Coordinates: {'X': 30.065, 'Y': 60.035, 'Z': 0.001}
# Point ID: 42
# Coordinates: {'X': 30.067, 'Y': 70.04, 'Z': -0.002}
# Point ID: 43
# Coordinates: {'X': 30.065, 'Y': 80.046, 'Z': -0.009}
# Point ID: 44
# Coordinates: {'X': 30.075, 'Y': 90.066, 'Z': -0.019}
# Point ID: 46
# Coordinates: {'X': 40.016, 'Y': -0.037, 'Z': 0.016}
# Point ID: 47
# Coordinates: {'X': 40.017, 'Y': 9.981, 'Z': 0.013}
# Point ID: 48
# Coordinates: {'X': 40.044, 'Y': 19.984, 'Z': 0.012}
# Point ID: 49
# Coordinates: {'X': 40.045, 'Y': 29.989, 'Z': 0.012}
# Point ID: 50
# Coordinates: {'X': 40.052, 'Y': 40.01, 'Z': 0.012}
# Point ID: 51
# Coordinates: {'X': 40.079, 'Y': 50.022, 'Z': 0.007}
# Point ID: 52
# Coordinates: {'X': 40.077, 'Y': 60.016, 'Z': 0.003}
# Point ID: 53
# Coordinates: {'X': 40.072, 'Y': 70.035, 'Z': 0.001}
# Point ID: 54
# Coordinates: {'X': 40.069, 'Y': 80.048, 'Z': -0.006}
# Point ID: 55
# Coordinates: {'X': 40.088, 'Y': 90.058, 'Z': -0.013}
# Point ID: 56
# Coordinates: {'X': 40.026, 'Y': -10.024, 'Z': 0.016}
# Point ID: 58
# Coordinates: {'X': 50.019, 'Y': -10.046, 'Z': 0.013}
# Point ID: 59
# Coordinates: {'X': 50.038, 'Y': -0.026, 'Z': 0.014}
# Point ID: 60
# Coordinates: {'X': 50.04, 'Y': 9.974, 'Z': 0.011}
# Point ID: 61
# Coordinates: {'X': 50.049, 'Y': 19.982, 'Z': 0.014}
# Point ID: 62
# Coordinates: {'X': 50.051, 'Y': 29.986, 'Z': 0.015}
# Point ID: 63
# Coordinates: {'X': 50.051, 'Y': 39.99, 'Z': 0.015}
# Point ID: 64
# Coordinates: {'X': 50.072, 'Y': 50.009, 'Z': 0.01}
# Point ID: 65
# Coordinates: {'X': 50.074, 'Y': 60.017, 'Z': 0.007}
# Point ID: 66
# Coordinates: {'X': 50.093, 'Y': 70.034, 'Z': 0.002}
# Point ID: 67
# Coordinates: {'X': 50.095, 'Y': 80.047, 'Z': -0.004}
# Point ID: 68
# Coordinates: {'X': 50.106, 'Y': 90.046, 'Z': -0.01}
# Point ID: 69
# Coordinates: {'X': 60.039, 'Y': -10.059, 'Z': 0.008}
# Point ID: 70
# Coordinates: {'X': 60.039, 'Y': -0.05, 'Z': 0.013}
# Point ID: 71
# Coordinates: {'X': 60.037, 'Y': 9.953, 'Z': 0.011}
# Point ID: 72
# Coordinates: {'X': 60.039, 'Y': 19.971, 'Z': 0.015}
# Point ID: 73
# Coordinates: {'X': 60.059, 'Y': 29.977, 'Z': 0.019}
# Point ID: 74
# Coordinates: {'X': 60.065, 'Y': 39.993, 'Z': 0.019}
# Point ID: 75
# Coordinates: {'X': 60.065, 'Y': 50.007, 'Z': 0.015}
# Point ID: 76
# Coordinates: {'X': 60.071, 'Y': 60.018, 'Z': 0.01}
# Point ID: 77
# Coordinates: {'X': 60.077, 'Y': 70.013, 'Z': 0.004}
# Point ID: 78
# Coordinates: {'X': 60.098, 'Y': 90.045, 'Z': -0.005}
# Point ID: 79
# Coordinates: {'X': 60.111, 'Y': 80.052, 'Z': -0.001}
# Point ID: 80
# Coordinates: {'X': 70.054, 'Y': -10.059, 'Z': 0.015}
# Point ID: 81
# Coordinates: {'X': 70.056, 'Y': -0.047, 'Z': 0.017}
# Point ID: 82
# Coordinates: {'X': 70.054, 'Y': 9.952, 'Z': 0.015}
# Point ID: 83
# Coordinates: {'X': 70.078, 'Y': 19.975, 'Z': 0.019}
# Point ID: 84
# Coordinates: {'X': 70.078, 'Y': 29.985, 'Z': 0.023}
# Point ID: 85
# Coordinates: {'X': 70.082, 'Y': 39.983, 'Z': 0.023}
# Point ID: 86
# Coordinates: {'X': 70.078, 'Y': 49.982, 'Z': 0.019}
# Point ID: 87
# Coordinates: {'X': 70.092, 'Y': 60.002, 'Z': 0.013}
# Point ID: 88
# Coordinates: {'X': 70.097, 'Y': 70.016, 'Z': 0.007}
# Point ID: 89
# Coordinates: {'X': 70.117, 'Y': 80.03, 'Z': 0.002}
# Point ID: 90
# Coordinates: {'X': 70.125, 'Y': 90.035, 'Z': -0.003}
# Point ID: 91
# Coordinates: {'X': 80.071, 'Y': -10.054, 'Z': 0.022}
# Point ID: 92
# Coordinates: {'X': 80.061, 'Y': -0.059, 'Z': 0.03}
# Point ID: 93
# Coordinates: {'X': 80.067, 'Y': 9.945, 'Z': 0.026}
# Point ID: 94
# Coordinates: {'X': 80.067, 'Y': 19.961, 'Z': 0.029}
# Point ID: 95
# Coordinates: {'X': 80.082, 'Y': 29.964, 'Z': 0.031}
# Point ID: 96
# Coordinates: {'X': 80.104, 'Y': 39.991, 'Z': 0.029}
# Point ID: 97
# Coordinates: {'X': 80.104, 'Y': 49.994, 'Z': 0.022}
# Point ID: 98
# Coordinates: {'X': 80.107, 'Y': 59.993, 'Z': 0.014}
# Point ID: 99
# Coordinates: {'X': 80.121, 'Y': 70.0, 'Z': 0.006}
# Point ID: 100
# Coordinates: {'X': 80.125, 'Y': 80.024, 'Z': 0.004}
# Point ID: 101
# Coordinates: {'X': 80.131, 'Y': 90.024, 'Z': 0.002}
# Point ID: 102
# Coordinates: {'X': 90.071, 'Y': -10.063, 'Z': 0.022}
# Point ID: 103
# Coordinates: {'X': 90.058, 'Y': -0.066, 'Z': 0.031}
# Point ID: 104
# Coordinates: {'X': 90.077, 'Y': 9.947, 'Z': 0.035}
# Point ID: 105
# Coordinates: {'X': 90.082, 'Y': 19.962, 'Z': 0.041}
# Point ID: 106
# Coordinates: {'X': 90.08, 'Y': 29.946, 'Z': 0.039}
# Point ID: 107
# Coordinates: {'X': 90.1, 'Y': 39.982, 'Z': 0.035}
# Point ID: 108
# Coordinates: {'X': 90.098, 'Y': 49.986, 'Z': 0.025}
# Point ID: 109
# Coordinates: {'X': 90.106, 'Y': 59.99, 'Z': 0.016}
# Point ID: 110
# Coordinates: {'X': 90.121, 'Y': 70.002, 'Z': 0.011}
# Point ID: 111
# Coordinates: {'X': 90.123, 'Y': 79.997, 'Z': 0.009}
# Point ID: 112
# Coordinates: {'X': 90.117, 'Y': 90.028, 'Z': 0.007}
# Point ID: 113
# Coordinates: {'X': 100.07, 'Y': -0.087, 'Z': 0.02}
# Point ID: 114
# Coordinates: {'X': 100.083, 'Y': 9.935, 'Z': 0.026}
# Point ID: 115
# Coordinates: {'X': 100.091, 'Y': 19.947, 'Z': 0.028}
# Point ID: 116
# Coordinates: {'X': 100.095, 'Y': 29.94, 'Z': 0.026}
# Point ID: 117
# Coordinates: {'X': 100.103, 'Y': 39.955, 'Z': 0.024}
# Point ID: 118
# Coordinates: {'X': 100.115, 'Y': 49.973, 'Z': 0.019}
# Point ID: 119
# Coordinates: {'X': 100.135, 'Y': 59.992, 'Z': 0.009}
# Point ID: 120
# Coordinates: {'X': 100.141, 'Y': 69.991, 'Z': 0.005}
# Point ID: 121
# Coordinates: {'X': 100.145, 'Y': 80.01, 'Z': 0.009}

# %%
# Extract X, Y, Z values and corresponding point IDs
point_ids = []
x_values = []
y_values = []
z_values = []

for point_id, coords in point_data:
    point_ids.append(point_id)
    x_values.append(coords['X'])
    y_values.append(coords['Y'])
    z_values.append(coords['Z'])

# Plot the XYZ points relative to their point IDs
fig = plt.figure(figsize=(20, 16))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_values, y_values, z_values)

# Label each point with its corresponding ID
for i, point_id in enumerate(point_ids):
    ax.text(x_values[i], y_values[i], z_values[i], point_id)

# Set labels and title
ax.set_xlabel('X [mm]', fontsize=14, fontweight='bold')
ax.set_ylabel('Y [mm]', fontsize=14, fontweight='bold')
ax.set_zlabel('Z [mm]', fontsize=14, fontweight='bold')
ax.set_title('Position Points XYZ', fontsize=11, fontweight='bold')

plt.show()

# %%
plt.figure(figsize=(15, 11))
plt.scatter(x_values, y_values, c=z_values, cmap='viridis', s=50)
plt.colorbar(label='Z [mm] (Weight)')
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Planarity Plot with Z (Weight)', fontsize=11, fontweight='bold')
plt.grid(True)
plt.show()

# %%
# Create a regular grid to interpolate onto
x_grid = np.linspace(min(x_values), max(x_values), 100)
y_grid = np.linspace(min(y_values), max(y_values), 100)
X, Y = np.meshgrid(x_grid, y_grid)

# Interpolate Z values onto the grid
Z = griddata((x_values, y_values), z_values, (X, Y), method='linear')
Z_grid = np.linspace(min(z_values), max(z_values), 100)
#colorbar = plt.colorbar(heatmap, label='Z [mm]', ticks=np.linspace(Z_grid.min(), Z_grid.max(), num=10))

# Plot the heatmap
plt.figure(figsize=(15, 11))
plt.pcolormesh(X, Y, Z, cmap='viridis')
plt.colorbar(label='Z [mm]', ticks=np.linspace(Z_grid.min(), Z_grid.max(), num=10))
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Interpolated Heatmap of XYZ', fontsize=11, fontweight='bold')
plt.show()

# %%
# Flatten the interpolated Z values
Z_flat = Z.flatten()

# Calculate the Root Mean Square (RMS)
rms = np.sqrt(np.mean(Z_flat**2))

print("Root Mean Square (RMS) of the heatmap:", rms)
# Out:
# Root Mean Square (RMS) of the heatmap: nan

# %%
print(Z_flat)
# Out:
# [nan nan nan ... nan nan nan]

# %%
# Find the NaN points
nan_indices = np.isnan(Z)
nan_points = np.column_stack((X[nan_indices], Y[nan_indices]))

# Print the NaN points
print("NaN Points (X, Y):")
print(nan_points)
# Out:
# NaN Points (X, Y):
# [[-2.00000000e-03 -1.00630000e+01]
#  [ 1.00958586e+00 -1.00630000e+01]
#  [ 2.02117172e+00 -1.00630000e+01]
#  ...
#  [ 9.81218283e+01  9.00770000e+01]
#  [ 9.91334141e+01  9.00770000e+01]
#  [ 1.00145000e+02  9.00770000e+01]]

# %%
# Calculate the Root Mean Square (RMS) excluding NaN values
rms = np.sqrt(np.nanmean(Z_flat**2))

print("Root Mean Square (RMS) of the heatmap (excluding NaN points):", rms)
# Out:
# Root Mean Square (RMS) of the heatmap (excluding NaN points): 0.015627021661135942

# %%
std_dev = np.std(Z_flat, ddof=1)
RMS = round(std_dev, 6)
print("RMS RAW =", RMS)
# Out:
# RMS RAW = nan

# %%
# Create the histogram
plt.figure(figsize=(12, 10))

plt.hist(z_values, bins=50, color='green', edgecolor='black', alpha=0.8)
# Add mean, median, and standard deviation lines
mean_value = np.mean(z_values)
median_value = np.median(z_values)
std_dev = np.std(z_values)

plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean_value:.2f}')
plt.axvline(median_value, color='green', linestyle='dashed', linewidth=1, label=f'Median: {median_value:.2f}')
plt.axvline(mean_value + std_dev, color='orange', linestyle='dashed', linewidth=1, label=f'Standard Deviation: {std_dev:.2f}')
plt.axvline(mean_value - std_dev, color='orange', linestyle='dashed', linewidth=1)

plt.legend()
plt.xlabel('Z Measured [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Entries', fontsize=14, fontweight='bold')
#plt.title('Histogram of Z Values')
#plt.title('Histogram with Statistics')
plt.grid(True)
plt.show()

# %%
# Group Z values by X values
x_groups = {}
for x, z in zip(x_values, z_values):
    if x not in x_groups:
        x_groups[x] = []
    x_groups[x].append(z)

# Plot scatter plots for each X group
plt.figure(figsize=(40, 20))
for x, z_group in x_groups.items():
    plt.scatter([x] * len(z_group), z_group, label=f"X = {x}")

plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Z [mm]', fontsize=14, fontweight='bold')
plt.title('Scatter Plot of Z Values for Each X Group', fontsize=11, fontweight='bold')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Group Z values by Y values
y_groups = {}
for y, z in zip(y_values, z_values):
    if y not in y_groups:
        y_groups[y] = []
    y_groups[y].append(z)

# Plot scatter plots for each X group
plt.figure(figsize=(40, 20))
for y, z_group in y_groups.items():
    indices = range(1, len(z_values) + 1)
    #plt.scatter(indices, z_values, label=f'Y = {y}')

    plt.scatter([y] * len(z_group), z_group, label=f"Y = {y}")

plt.xlabel('Y [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Z [mm]', fontsize=14, fontweight='bold')
plt.title('Scatter Plot of Z Values for Each Y Group', fontsize=11, fontweight='bold')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Initialize variables to store point IDs and corresponding coordinates
point_data = []

# Regular expressions to match point ID and coordinate lines
point_id_pattern = r'\[([\d,]+)\]'
coord_pattern = r'Coord\. ([XYZ]) =\s*([-+]?\d+,\d+)'

# Extract point IDs and coordinates from lines
current_point_id = None
current_coords = {}

skipped_lines = 0
for line in lines:
    if skipped_lines < 3 and not line.startswith('Plan'):
        skipped_lines += 1
        continue
    elif line.startswith('Plan'):
        break
    # Check if the line contains a point ID
    match_id = re.search(point_id_pattern, line)
    if match_id:
        current_point_id = match_id.group(1)
        current_coords = {}
        continue

   # Check if the line contains a coordinate
    match_coord = re.search(coord_pattern, line)
    if match_coord and current_point_id:
        coord_type = match_coord.group(1)
        coord_value = float(match_coord.group(2).replace(',', '.'))
        
        # Check if the Y coordinate is not equal to 0.002
        if coord_type == 'Y' and coord_value == 0.002:
            continue  # Skip this coordinate
        if coord_type == 'X' and coord_value == 0.0 and coord_type == 'Y' and coord_value == 50.0: 
            continue
             
        current_coords[coord_type] = coord_value

        # If all coordinates are found, add them to the point data
        if len(current_coords) == 3 and current_coords['Z']<5.: #and current_coords['X']!=0:# and current_coords['X'] == 150. and current_coords['Y'] == 150.:
            point_data.append((current_point_id, current_coords))
            current_point_id = None

# Convert the data to the desired format
formatted_data = []
for point_id, coords in point_data:
    formatted_coords = {'X': coords['X'], 'Y': coords['Y'], 'Z': coords['Z']}
    formatted_data.append((point_id, formatted_coords))

# Print the formatted data
for point_id, coords in formatted_data:
    print("Point ID:", point_id)
    print("Coordinates:", coords)

# %%
# Group the data by X coordinate
plt.figure(figsize=(40, 20))

grouped_data = {}
for point_id, coords in formatted_data:
    x_coord = coords['X']
    if x_coord not in grouped_data:
        grouped_data[x_coord] = []
    grouped_data[x_coord].append((point_id, coords['Y'], coords['Z']))

# Plot each group separately
for x, points in grouped_data.items():
    point_ids, ys, zs = zip(*points)
    plt.scatter(ys, zs, label=f'X = {x}')

# Add labels and legend
plt.xlabel('Y [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Z [mm]', fontsize=14, fontweight='bold')
plt.title('Scatter Plot of Points with the Same X Coordinate', fontsize=11, fontweight='bold')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Extract X, Y, and Z values from the data
x_values = []
y_values = []
z_values = []
for position, coords in formatted_data:
    x_values.append(coords['X'])
    y_values.append(coords['Y'])
    z_values.append(coords['Z'])

# Perform linear regression to fit a line to the data
slope_y, intercept_y = np.polyfit(y_values, z_values, 1)

# Calculate the fitted line
fitted_line_y = slope_y * np.array(y_values) + intercept_y

# Subtract the fitted line from the original Z values to correct for the slope in the Y direction
corrected_z_values_y = np.array(z_values) - fitted_line_y

# Plot the original and corrected Z values
plt.figure(figsize=(10, 6))
plt.scatter(y_values, z_values, label='Original Z Values')
plt.plot(y_values, fitted_line_y, color='red', label='Fitted Line')
plt.scatter(y_values, corrected_z_values_y, color='green', label='Corrected Z Values')
plt.xlabel('Y [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Z [mm]', fontsize=14, fontweight='bold')
plt.title('Original and Corrected Z Values (Y direction)', fontsize=11, fontweight='bold')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1582/3792976037.py in <module>
#       9
#      10 # Perform linear regression to fit a line to the data
# ---> 11 slope_y, intercept_y = np.polyfit(y_values, z_values, 1)
#      12
#      13 # Calculate the fitted line
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/overrides.py in polyfit(*args, **kwargs)
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     636         raise TypeError("expected 1D vector for x")
#     637     if x.size == 0:
# --> 638         raise TypeError("expected non-empty vector for x")
#     639     if y.ndim < 1 or y.ndim > 2:
#     640         raise TypeError("expected 1D or 2D array for y")
#
# TypeError: expected non-empty vector for x

# %%
# Create a regular grid to interpolate onto
x_grid = np.linspace(min(x_values), max(x_values), 100)
y_grid = np.linspace(min(y_values), max(y_values), 100)
X, Y = np.meshgrid(x_grid, y_grid)

# Interpolate Z values onto the grid
Z = griddata((x_values, y_values), corrected_z_values_y, (X, Y), method='linear')

# Plot the heatmap
plt.figure(figsize=(10, 6))
plt.pcolormesh(X, Y, Z, cmap='viridis')
plt.colorbar(label='Z [mm]')
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Interpolated Heatmap of XYZ with Corrected Z -Simultaneous Fit', fontsize=11, fontweight='bold')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1582/3068511928.py in <module>
#       1 # Create a regular grid to interpolate onto
# ----> 2 x_grid = np.linspace(min(x_values), max(x_values), 100)
#       3 y_grid = np.linspace(min(y_values), max(y_values), 100)
#       4 X, Y = np.meshgrid(x_grid, y_grid)
#       5
#
# ValueError: min() arg is an empty sequence

# %%
# Flatten the interpolated Z values
Z_flat = Z.flatten()

# Calculate the Root Mean Square (RMS) excluding NaN values
rms = np.sqrt(np.nanmean(Z_flat**2))

print("Root Mean Square (RMS) of the heatmap (excluding NaN points):", rms)
# Out:
# Root Mean Square (RMS) of the heatmap (excluding NaN points): 0.015627021661135942

# %%
std_dev = np.std(Z_flat, ddof=1)
RMS = round(std_dev, 6)
print("RMS RAW =", RMS)
# Out:
# RMS RAW = nan

# %%
# Create the histogram
plt.figure(figsize=(12, 10))

plt.hist(corrected_z_values_y, bins=50, color='green', edgecolor='black', alpha=0.8)
# Add mean, median, and standard deviation lines
mean_value = np.mean(corrected_z_values_y)
median_value = np.median(corrected_z_values_y)
std_dev = np.std(corrected_z_values_y)

plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_value:.2f}')
plt.axvline(median_value, color='green', linestyle='dashed', linewidth=1, label=f'Median: {median_value:.2f}')
plt.axvline(mean_value + std_dev, color='orange', linestyle='dashed', linewidth=1, label=f'Standard Deviation: {std_dev:.2f}')
plt.axvline(mean_value - std_dev, color='orange', linestyle='dashed', linewidth=1)

plt.legend()
plt.xlabel('Z [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Entries', fontsize=14, fontweight='bold')
plt.title('Histogram of Z corrected Values -Simultaneous Fit', fontsize=11, fontweight='bold')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1582/913465889.py in <module>
#       2 plt.figure(figsize=(12, 10))
#       3
# ----> 4 plt.hist(corrected_z_values_y, bins=50, color='green', edgecolor='black', alpha=0.8)
#       5 # Add mean, median, and standard deviation lines
#       6 mean_value = np.mean(corrected_z_values_y)
#
# NameError: name 'corrected_z_values_y' is not defined

# %%
# Group the data by X coordinate
plt.figure(figsize=(20, 12))

grouped_data = {}
for point_id, coords in formatted_data:
    y_coord = coords['Y']
    if y_coord not in grouped_data:
        grouped_data[y_coord] = []
    grouped_data[y_coord].append((point_id, coords['X'], coords['Z']))

# Plot each group separately
for y, points in grouped_data.items():
    point_ids, xs, zs = zip(*points)
    plt.scatter(xs, zs, label=f'Y = {y}')

# Add labels and legend
plt.xlabel('Y [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Z [mm]', fontsize=14, fontweight='bold')
plt.title('Scatter Plot of Points with the Same Y Coordinate', fontsize=11, fontweight='bold')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(11, 11))

Z = griddata((x_values, y_values), z_values, (X, Y), method='linear')

# Plot the heatmap
plt.subplot(2, 1, 1)
im = plt.pcolormesh(X, Y, Z, cmap='viridis')
plt.colorbar(im, label='Z [mm]')
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Heatmap of XYZ',  fontsize=11, fontweight='bold')

# Overlay XY points on top of the heatmap
plt.scatter(x_values, y_values, color='brown', marker='o', label='XY Points')
plt.legend()

Z = griddata((x_values, y_values), corrected_z_values_y, (X, Y), method='linear')

# Plot the scatter plot
plt.subplot(2, 1, 2)
sc = plt.pcolormesh(X, Y, Z, cmap='viridis')
plt.colorbar(sc, label='Z [mm]')
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Corrected Heatmap of XYZ - Simultaneous Fit', fontsize=11, fontweight='bold')
# Overlay XY points on top of the heatmap
plt.scatter(x_values, y_values, color='brown', marker='o', label='XY Points')
plt.legend()


plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1582/2364338503.py in <module>
#       1 plt.figure(figsize=(11, 11))
#       2
# ----> 3 Z = griddata((x_values, y_values), z_values, (X, Y), method='linear')
#       4
#       5 # Plot the heatmap
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/scipy/interpolate/_ndgriddata.py in griddata(points, values, xi, method, fill_value, rescale)
#     271         return ip(xi)
#     272     elif method == 'linear':
# --> 273         ip = LinearNDInterpolator(points, values, fill_value=fill_value,
#     274                                   rescale=rescale)
#     275         return ip(xi)
#
# interpnd.pyx in scipy.interpolate.interpnd.LinearNDInterpolator.__init__()
#
# _qhull.pyx in scipy.spatial._qhull.Delaunay.__init__()
#
# _qhull.pyx in scipy.spatial._qhull._Qhull.__init__()
#
# ValueError: No points given

# %%
std_dev = np.std(Z, ddof=1)
RMS = round(std_dev, 6)
print("RMS Simultaneous Fit =", RMS)
# Out:
# RMS Simultaneous Fit = nan

# %% [raw]
# Fitting a plane to a set of 3D points is a common technique used in planarity analysis. This technique is often employed in various fields such as computer vision, robotics, geomatics, and manufacturing to assess the flatness or planarity of a surface.
#
# The fitting of a plane involves finding the best-fitting plane that minimizes the sum of squared distances between the plane and the data points. This can be achieved using mathematical techniques such as least squares regression ddor principal component analysis (PCA).
#
# Once the plane is fitted to the data, various metrics can be calculated to assess the planarity, such as the root mean square (RMS) of the distances between the data points and the fitted plane, or the deviation of the data points from the plane.
#
# Overall, fitting a plane to the data provides a quantitative measure of planarity and can be a useful tool for quality control, surface inspection, and geometric analysis.

# %% [raw]
# The goal is to find the values of a and b that minimize the sum of the squared residuals. This is why it's called "least squares" regression.

# %%
def fit_plane(formatted_data):   
    # Extract X, Y, and Z coordinates from the formatted data 
    X = np.array([coords['X'] for _, coords in formatted_data])
    Y = np.array([coords['Y'] for _, coords in formatted_data])
    Z = np.array([coords['Z'] for _, coords in formatted_data])
    
    # Construct the design matrix contains the independent variables
    A = np.vstack((X, Y, np.ones_like(X))).T #stacking X, Y, and a column of ones (for the intercept term) vertically and transposing it. 
    #This design matrix is used in the least squares regression.
    
    # Perform least squares regression to find the plane parameters
    #params, _, _, _ = np.linalg.lstsq(A, Z, rcond=None) 
    params, residuals, rank, singular_values = np.linalg.lstsq(A, Z, rcond=None)

    #contains the coefficients of the plane equation (a, b, c) that minimize the sum of squared residuals.
    #assigned to _ to indicate that they're being ignored.
    
    # Extract plane parameters (coefficients of the plane equation: ax + by + c = z)
    a, b, c = params
    residuals = residuals  #the residual sum of squares, which represents the sum of squared differences between the observed and predicted values of Z
    singular_values = singular_values # the singular values of A
    return a, b, c, residuals, singular_values

a, b, c, residuals, singular_values = fit_plane(formatted_data)
print("Plane parameters: a =", a, ", b =", b, ", c =", c, ", residuals = ", residuals, ", singular values = ", singular_values)
# Out:
# Plane parameters: a = 0.0 , b = 0.0 , c = 0.0 , residuals =  [] , singular values =  []

# %%
# Visualize the fitted plane and original points
def visualize_plane_and_points(formatted_data, a, b, c, residuals, singular_values):
    X = np.array([coords['X'] for _, coords in formatted_data])
    Y = np.array([coords['Y'] for _, coords in formatted_data])
    Z = np.array([coords['Z'] for _, coords in formatted_data])
    
    # Create a meshgrid for X and Y coordinates
    X_grid, Y_grid = np.meshgrid(np.linspace(min(X), max(X), 10), np.linspace(min(Y), max(Y), 10))
    
    # Calculate Z values for the fitted plane
    Z_plane = a * X_grid + b * Y_grid + c

    # Plot the points
    fig = plt.figure(figsize=(20, 15))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(X, Y, Z, color='b', label='Original Points')
    
    # Plot the fitted plane
    ax.plot_surface(X_grid, Y_grid, Z_plane, alpha=0.5, color='r', label='Fitted Plane')
    
    # Set labels and title
    ax.set_xlabel('X [mm]', fontsize=14, fontweight='bold')
    ax.set_xlabel('X [mm]', fontsize=14, fontweight='bold')
    ax.set_ylabel('Y [mm]', fontsize=14, fontweight='bold')
    ax.set_zlabel('Z [mm]', fontsize=14, fontweight='bold')
    ax.set_title('Planarity Fitted Plane', fontsize=11, fontweight='bold')
    
    # Add legend
    ax.legend()
    
    # Show plot
    plt.show()

# %%
#a, b, c = fit_plane(formatted_data)
a, b, c, residuals, singular_values = fit_plane(formatted_data)
#visualize_plane_and_points(formatted_data, a, b, c)
visualize_plane_and_points(formatted_data, a, b, c, residuals, singular_values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1582/4284795263.py in <module>
#       2 a, b, c, residuals, singular_values = fit_plane(formatted_data)
#       3 #visualize_plane_and_points(formatted_data, a, b, c)
# ----> 4 visualize_plane_and_points(formatted_data, a, b, c, residuals, singular_values)
#
# /tmp/ipykernel_1582/755615009.py in visualize_plane_and_points(formatted_data, a, b, c, residuals, singular_values)
#       6
#       7     # Create a meshgrid for X and Y coordinates
# ----> 8     X_grid, Y_grid = np.meshgrid(np.linspace(min(X), max(X), 10), np.linspace(min(Y), max(Y), 10))
#       9
#      10     # Calculate Z values for the fitted plane
#
# ValueError: min() arg is an empty sequence

# %%
def calculate_planarity_metrics(formatted_data, a, b, c):
    # Extract X, Y, and Z coordinates from the formatted data
    X = np.array([coords['X'] for _, coords in formatted_data])
    Y = np.array([coords['Y'] for _, coords in formatted_data])
    Z = np.array([coords['Z'] for _, coords in formatted_data])
    
    # Calculate distances from points to the fitted plane
    distances = np.abs(a * X + b * Y - Z + c) / np.sqrt(a**2 + b**2 + 1)
    
    # Calculate RMS of the distances
    rms_distance = np.sqrt(np.mean(distances**2))
    
    # Calculate deviation of the points from the plane
    deviation = distances.mean()
    
    return rms_distance, deviation

# %%
rms_distance, deviation = calculate_planarity_metrics(formatted_data, a, b, c)
print("RMS Distance:", rms_distance) #the root mean square (RMS) of the distances between the data points and the fitted plane
print("Deviation:", deviation) #the deviation of the data points from the plane
# Out:
# RMS Distance: nan
# Deviation: nan
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /tmp/ipykernel_1582/493140101.py:14: RuntimeWarning: Mean of empty slice.
#   deviation = distances.mean()

# %% [raw]
# It calculates the distances from each point to the fitted plane, then computes the RMS of these distances and the deviation of the points from the plane.

# %%
# Define the point IDs
point_4_4_id = '4,4'
point_4_13_id = '4,13'
point_13_4_id = '13,4'
point_13_13_id = '13,13'


# Find the XY coordinates corresponding to the specified point IDs
point_4_4_xy = None
point_4_13_xy = None
point_13_4_xy = None
point_13_13_xy = None

for point_id, coords in formatted_data:
    if point_id == point_4_4_id:
        point_4_4_xy = (coords['X'], coords['Y'])
    elif point_id == point_4_13_id:
        point_4_13_xy = (coords['X'], coords['Y'])
    elif point_id == point_13_4_id:
        point_13_4_xy = (coords['X'], coords['Y'])
    elif point_id == point_13_13_id:
        point_13_13_xy = (coords['X'], coords['Y'])

# Plot the heatmap of Z
plt.figure(figsize=(12, 6))
plt.pcolormesh(X, Y, Z, cmap='viridis')
plt.colorbar(label='Z [mm]')
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Heatmap of Z Measured', fontsize=11, fontweight='bold')

# Overlay XY points on top of the heatmap
plt.scatter(x_values, y_values, color='red', marker='o', label='XY Points')

## Connect specified points with lines
# plt.plot([point_4_13_xy[0], point_13_13_xy[0]], [point_4_13_xy[1], point_13_13_xy[1]], color='blue', linestyle='-', linewidth=2)
# plt.plot([point_13_4_xy[0], point_13_13_xy[0]], [point_13_4_xy[1], point_13_13_xy[1]], color='blue', linestyle='-', linewidth=2) #perpendicular
# plt.plot([point_4_4_xy[0], point_4_13_xy[0]], [point_4_4_xy[1], point_4_13_xy[1]], color='blue', linestyle='-', linewidth=2) #perpendicular
# plt.plot([point_4_4_xy[0], point_13_4_xy[0]], [point_4_4_xy[1], point_13_4_xy[1]], color='blue', linestyle='-', linewidth=2) #perpendicular

plt.legend()
plt.tight_layout()
plt.show()

# %%
x_values = np.array([coords['X'] for _, coords in formatted_data])
y_values = np.array([coords['Y'] for _, coords in formatted_data])
z_values = np.array([coords['Z'] for _, coords in formatted_data])

# Correct the Z values based on the fitted plane
corrected_z_values = z_values - (a * x_values + b * y_values + c)

# Create a grid for the heatmap
X, Y = np.meshgrid(np.linspace(min(x_values), max(x_values), 100),
                   np.linspace(min(y_values), max(y_values), 100))

# Interpolate the corrected Z values onto the grid
Z_corrected = griddata((x_values, y_values), corrected_z_values, (X, Y), method='linear')


# Plot the heatmap of corrected Z values
plt.figure(figsize=(10, 10))
plt.pcolormesh(X, Y, Z_corrected, cmap='viridis')
plt.colorbar(label='Corrected fit plane Z [mm]')
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Heatmap of Corrected Z Values - Fit Plane', fontsize=11, fontweight='bold')

# Overlay XY points on top of the heatmap
plt.scatter(x_values, y_values, color='red', marker='o', label='XY Points')

plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1582/883426520.py in <module>
#       7
#       8 # Create a grid for the heatmap
# ----> 9 X, Y = np.meshgrid(np.linspace(min(x_values), max(x_values), 100),
#      10                    np.linspace(min(y_values), max(y_values), 100))
#      11
#
# ValueError: min() arg is an empty sequence

# %%
# Flatten the 2D array Z_corrected into a 1D array
Z_corrected_flat = corrected_z_values.flatten()

# Plot the histogram of the corrected Z values
plt.figure(figsize=(12, 10))
plt.hist(Z_corrected_flat, bins=50, color='green', edgecolor='black', alpha=0.8)
# Add mean, median, and standard deviation lines
mean_value = np.mean(Z_corrected_flat)
median_value = np.median(Z_corrected_flat)
std_deviation = np.std(Z_corrected_flat)
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean_value:.2f}')
plt.axvline(median_value, color='blue', linestyle='dashed', linewidth=1, label=f'Median: {median_value:.2f}')
plt.axvline(mean_value + std_deviation, color='orange', linestyle='dashed', linewidth=1, label=f'Standard Deviation: {std_deviation:.2f}')
plt.axvline(mean_value - std_deviation, color='orange', linestyle='dashed', linewidth=1)
plt.xlabel('Corrected Z [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Entries', fontsize=14, fontweight='bold')
plt.title('Histogram of Corrected Z Values - Fit plane', fontsize=11, fontweight='bold')
plt.legend()
plt.show()
# Out:
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
X_test = np.column_stack((x_values, y_values, np.ones_like(x_values)))

# Fit linear regression model
model = LinearRegression().fit(X_test, z_values)

# Get the coefficients (normal vector) of the plane
normal_vector = model.coef_
intercept = model.intercept_

# Generate points on the plane for visualization
x_plane = np.linspace(min(x_values), max(x_values), 10)
y_plane = np.linspace(min(y_values), max(y_values), 10)
x_plane, y_plane = np.meshgrid(x_plane, y_plane)
z_plane = normal_vector[0] * x_plane + normal_vector[1] * y_plane + intercept

# Plot the original data points
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_values, y_values, z_values, c='b', marker='o', label='Data Points')

# Plot the plane
ax.plot_surface(x_plane, y_plane, z_plane, alpha=0.5)

ax.set_xlabel('X [mm]', fontsize=14, fontweight='bold')
ax.set_ylabel('Y [mm]', fontsize=14, fontweight='bold')
ax.set_zlabel('Z [mm]', fontsize=14, fontweight='bold')
ax.set_title('Plane Fitting')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1582/3405778286.py in <module>
#       2
#       3 # Fit linear regression model
# ----> 4 model = LinearRegression().fit(X_test, z_values)
#       5
#       6 # Get the coefficients (normal vector) of the plane
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     646         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     647
# --> 648         X, y = self._validate_data(
#     649             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650         )
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1104         )
#    1105
# -> 1106     X = check_array(
#    1107         X,
#    1108         accept_sparse=accept_sparse,
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     929         n_samples = _num_samples(array)
#     930         if n_samples < ensure_min_samples:
# --> 931             raise ValueError(
#     932                 "Found array with %d sample(s) (shape=%s) while a"
#     933                 " minimum of %d is required%s."
#
# ValueError: Found array with 0 sample(s) (shape=(0, 3)) while a minimum of 1 is required by LinearRegression.
