# %%
import re
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import griddata
from sklearn.linear_model import LinearRegression
from mpl_toolkits.mplot3d import Axes3D

# %%
##filename = 'Mearure-planarity-PCB-WURTH-Thin.txt'
#filename = 'Mearure-planarity-TOPlayer-sparePCB-Rohacel-original.txt'
filename = 'planarity-bottom.txt'
with open(filename, 'r', encoding='ISO-8859-1') as file:
    lines = file.readlines()

for line in lines: print(line.strip())
# Out:
# Elément            Réel       Val. nom.           Ecart       Tol. sup.       Tol. inf.           OK/HT
# (Dév PR)        (Tol PR)
# Point-1(De 1 pt)
# Coord. X =          123,102
# Coord. Y =          122,753
# Coord. Z =           10,732
#
# Point-2[1,1](De 1 pt)
# Coord. X =            0,001
# Coord. Y =            0,001
# Coord. Z =            0,000
#
# Point-2[1,2](De 1 pt)
# Coord. X =            0,001
# Coord. Y =           10,000
# Coord. Z =            0,004
#
# Point-2[1,3](De 1 pt)
# Coord. X =            0,001
# Coord. Y =           20,000
# Coord. Z =            0,005
#
# Point-2[1,4](De 1 pt)
# Coord. X =            0,001
# Coord. Y =           30,000
# Coord. Z =            0,004
#
# Point-2[1,5](De 1 pt)
# Coord. X =            0,001
# Coord. Y =           40,000
# Coord. Z =           -0,003
#
# Point-2[1,6](De 1 pt)
# Coord. X =            0,001
# Coord. Y =           50,000
# Coord. Z =           -0,005
#
# Point-2[1,7](De 1 pt)
# Coord. X =            0,001
# Coord. Y =           60,000
# Coord. Z =           -0,007
#
# Point-2[1,8](De 1 pt)
# Coord. X =            0,001
# Coord. Y =           70,000
# Coord. Z =           -0,009
#
# Point-2[1,9](De 1 pt)
# Coord. X =            0,001
# Coord. Y =           80,000
# Coord. Z =           -0,011
#
# Point-2[1,10](De 1 pt)
# Coord. X =            0,001
# Coord. Y =           90,000
# Coord. Z =           -0,014
#
# Point-2[1,11](De 1 pt)
# Coord. X =            0,001
# Coord. Y =          100,000
# Coord. Z =           -0,012
#
# Point-2[1,12](De 1 pt)
# Coord. X =            0,001
# Coord. Y =          110,000
# Coord. Z =           -0,014
#
# Point-2[2,1](De 1 pt)
# Coord. X =           10,001
# Coord. Y =            0,001
# Coord. Z =            0,010
#
# Point-2[2,2](De 1 pt)
# Coord. X =           10,001
# Coord. Y =           10,000
# Coord. Z =            0,012
#
# Point-2[2,3](De 1 pt)
# Coord. X =           10,001
# Coord. Y =           20,000
# Coord. Z =            0,012
#
# Point-2[2,4](De 1 pt)
# Coord. X =           10,001
# Coord. Y =           30,000
# Coord. Z =            0,012
#
# Point-2[2,5](De 1 pt)
# Coord. X =           10,001
# Coord. Y =           40,000
# Coord. Z =            0,009
#
# Point-2[2,6](De 1 pt)
# Coord. X =           10,001
# Coord. Y =           50,000
# Coord. Z =            0,007
#
# Point-2[2,7](De 1 pt)
# Coord. X =           10,001
# Coord. Y =           60,000
# Coord. Z =            0,005
#
# Point-2[2,8](De 1 pt)
# Coord. X =           10,001
# Coord. Y =           70,000
# Coord. Z =            0,002
#
# Point-2[2,9](De 1 pt)
# Coord. X =           10,001
# Coord. Y =           80,000
# Coord. Z =           -0,002
#
# Point-2[2,10](De 1 pt)
# Coord. X =           10,001
# Coord. Y =           90,000
# Coord. Z =           -0,002
#
# Point-2[2,11](De 1 pt)
# Coord. X =           10,001
# Coord. Y =          100,000
# Coord. Z =           -0,002
#
# Point-2[2,12](De 1 pt)
# Coord. X =           10,001
# Coord. Y =          110,000
# Coord. Z =            0,000
#
# Point-2[3,1](De 1 pt)
# Coord. X =           20,001
# Coord. Y =            0,001
# Coord. Z =            0,016
#
# Point-2[3,2](De 1 pt)
# Coord. X =           20,001
# Coord. Y =           10,000
# Coord. Z =            0,014
#
# Point-2[3,3](De 1 pt)
# Coord. X =           20,001
# Coord. Y =           20,000
# Coord. Z =            0,017
#
# Point-2[3,4](De 1 pt)
# Coord. X =           20,001
# Coord. Y =           30,000
# Coord. Z =            0,016
#
# Point-2[3,5](De 1 pt)
# Coord. X =           20,001
# Coord. Y =           40,000
# Coord. Z =            0,015
#
# Point-2[3,6](De 1 pt)
# Coord. X =           20,001
# Coord. Y =           50,000
# Coord. Z =            0,013
#
# Point-2[3,7](De 1 pt)
# Coord. X =           20,001
# Coord. Y =           60,000
# Coord. Z =            0,011
#
# Point-2[3,8](De 1 pt)
# Coord. X =           20,001
# Coord. Y =           70,000
# Coord. Z =            0,006
#
# Point-2[3,9](De 1 pt)
# Coord. X =           20,001
# Coord. Y =           80,000
# Coord. Z =            0,004
#
# Point-2[3,10](De 1 pt)
# Coord. X =           20,001
# Coord. Y =           90,000
# Coord. Z =            0,003
#
# Point-2[3,11](De 1 pt)
# Coord. X =           20,001
# Coord. Y =          100,000
# Coord. Z =            0,002
#
# Point-2[3,12](De 1 pt)
# Coord. X =           20,001
# Coord. Y =          110,000
# Coord. Z =            0,002
#
# Point-2[4,1](De 1 pt)
# Coord. X =           30,001
# Coord. Y =            0,001
# Coord. Z =            0,017
#
# Point-2[4,2](De 1 pt)
# Coord. X =           30,001
# Coord. Y =           10,000
# Coord. Z =            0,018
#
# Point-2[4,3](De 1 pt)
# Coord. X =           30,001
# Coord. Y =           20,000
# Coord. Z =            0,017
#
# Point-2[4,4](De 1 pt)
# Coord. X =           30,001
# Coord. Y =           30,000
# Coord. Z =            0,015
#
# Point-2[4,5](De 1 pt)
# Coord. X =           30,001
# Coord. Y =           40,000
# Coord. Z =            0,011
#
# Point-2[4,6](De 1 pt)
# Coord. X =           30,001
# Coord. Y =           50,000
# Coord. Z =            0,010
#
# Point-2[4,7](De 1 pt)
# Coord. X =           30,001
# Coord. Y =           60,000
# Coord. Z =            0,008
#
# Point-2[4,8](De 1 pt)
# Coord. X =           30,001
# Coord. Y =           70,000
# Coord. Z =            0,006
#
# Point-2[4,9](De 1 pt)
# Coord. X =           30,001
# Coord. Y =           80,000
# Coord. Z =           -0,001
#
# Point-2[4,10](De 1 pt)
# Coord. X =           30,001
# Coord. Y =           90,000
# Coord. Z =            0,001
#
# Point-2[4,11](De 1 pt)
# Coord. X =           30,001
# Coord. Y =          100,000
# Coord. Z =            0,002
#
# Point-2[4,12](De 1 pt)
# Coord. X =           30,001
# Coord. Y =          110,000
# Coord. Z =           -0,001
#
# Point-2[5,1](De 1 pt)
# Coord. X =           40,001
# Coord. Y =            0,001
# Coord. Z =            0,017
#
# Point-2[5,2](De 1 pt)
# Coord. X =           40,001
# Coord. Y =           10,000
# Coord. Z =            0,021
#
# Point-2[5,3](De 1 pt)
# Coord. X =           40,001
# Coord. Y =           20,000
# Coord. Z =            0,019
#
# Point-2[5,4](De 1 pt)
# Coord. X =           40,001
# Coord. Y =           30,000
# Coord. Z =            0,015
#
# Point-2[5,5](De 1 pt)
# Coord. X =           40,001
# Coord. Y =           40,000
# Coord. Z =            0,010
#
# Point-2[5,6](De 1 pt)
# Coord. X =           40,001
# Coord. Y =           50,000
# Coord. Z =            0,006
#
# Point-2[5,7](De 1 pt)
# Coord. X =           40,001
# Coord. Y =           60,000
# Coord. Z =            0,008
#
# Point-2[5,8](De 1 pt)
# Coord. X =           40,001
# Coord. Y =           70,000
# Coord. Z =            0,006
#
# Point-2[5,9](De 1 pt)
# Coord. X =           40,001
# Coord. Y =           80,000
# Coord. Z =            0,004
#
# Point-2[5,10](De 1 pt)
# Coord. X =           40,001
# Coord. Y =           90,000
# Coord. Z =            0,004
#
# Point-2[5,11](De 1 pt)
# Coord. X =           40,001
# Coord. Y =          100,000
# Coord. Z =            0,003
#
# Point-2[5,12](De 1 pt)
# Coord. X =           40,001
# Coord. Y =          110,000
# Coord. Z =            0,002
#
# Point-2[6,1](De 1 pt)
# Coord. X =           50,001
# Coord. Y =            0,001
# Coord. Z =            0,017
#
# Point-2[6,2](De 1 pt)
# Coord. X =           50,001
# Coord. Y =           10,000
# Coord. Z =            0,017
#
# Point-2[6,3](De 1 pt)
# Coord. X =           50,001
# Coord. Y =           20,000
# Coord. Z =            0,018
#
# Point-2[6,4](De 1 pt)
# Coord. X =           50,001
# Coord. Y =           30,000
# Coord. Z =            0,013
#
# Point-2[6,5](De 1 pt)
# Coord. X =           50,001
# Coord. Y =           40,000
# Coord. Z =            0,009
#
# Point-2[6,6](De 1 pt)
# Coord. X =           50,001
# Coord. Y =           50,000
# Coord. Z =            0,003
#
# Point-2[6,7](De 1 pt)
# Coord. X =           50,001
# Coord. Y =           60,000
# Coord. Z =            0,007
#
# Point-2[6,8](De 1 pt)
# Coord. X =           50,001
# Coord. Y =           70,000
# Coord. Z =            0,009
#
# Point-2[6,9](De 1 pt)
# Coord. X =           50,001
# Coord. Y =           80,000
# Coord. Z =            0,006
#
# Point-2[6,10](De 1 pt)
# Coord. X =           50,001
# Coord. Y =           90,000
# Coord. Z =            0,008
#
# Point-2[6,11](De 1 pt)
# Coord. X =           50,001
# Coord. Y =          100,000
# Coord. Z =            0,004
#
# Point-2[6,12](De 1 pt)
# Coord. X =           50,001
# Coord. Y =          110,000
# Coord. Z =            0,004
#
# Point-2[7,1](De 1 pt)
# Coord. X =           60,001
# Coord. Y =            0,001
# Coord. Z =            0,017
#
# Point-2[7,2](De 1 pt)
# Coord. X =           60,001
# Coord. Y =           10,000
# Coord. Z =            0,014
#
# Point-2[7,3](De 1 pt)
# Coord. X =           60,001
# Coord. Y =           20,000
# Coord. Z =            0,015
#
# Point-2[7,4](De 1 pt)
# Coord. X =           60,001
# Coord. Y =           30,000
# Coord. Z =            0,013
#
# Point-2[7,5](De 1 pt)
# Coord. X =           60,001
# Coord. Y =           40,000
# Coord. Z =            0,007
#
# Point-2[7,6](De 1 pt)
# Coord. X =           60,001
# Coord. Y =           50,000
# Coord. Z =            0,005
#
# Point-2[7,7](De 1 pt)
# Coord. X =           60,001
# Coord. Y =           60,000
# Coord. Z =            0,005
#
# Point-2[7,8](De 1 pt)
# Coord. X =           60,001
# Coord. Y =           70,000
# Coord. Z =            0,004
#
# Point-2[7,9](De 1 pt)
# Coord. X =           60,001
# Coord. Y =           80,000
# Coord. Z =            0,004
#
# Point-2[7,10](De 1 pt)
# Coord. X =           60,001
# Coord. Y =           90,000
# Coord. Z =            0,005
#
# Point-2[7,11](De 1 pt)
# Coord. X =           60,001
# Coord. Y =          100,000
# Coord. Z =            0,007
#
# Point-2[7,12](De 1 pt)
# Coord. X =           60,001
# Coord. Y =          110,000
# Coord. Z =            0,005
#
# Point-2[8,1](De 1 pt)
# Coord. X =           70,001
# Coord. Y =            0,001
# Coord. Z =            0,020
#
# Point-2[8,2](De 1 pt)
# Coord. X =           70,001
# Coord. Y =           10,000
# Coord. Z =            0,019
#
# Point-2[8,3](De 1 pt)
# Coord. X =           70,001
# Coord. Y =           20,000
# Coord. Z =            0,015
#
# Point-2[8,4](De 1 pt)
# Coord. X =           70,001
# Coord. Y =           30,000
# Coord. Z =            0,010
#
# Point-2[8,5](De 1 pt)
# Coord. X =           70,001
# Coord. Y =           40,000
# Coord. Z =            0,006
#
# Point-2[8,6](De 1 pt)
# Coord. X =           70,001
# Coord. Y =           50,000
# Coord. Z =            0,006
#
# Point-2[8,7](De 1 pt)
# Coord. X =           70,001
# Coord. Y =           60,000
# Coord. Z =            0,003
#
# Point-2[8,8](De 1 pt)
# Coord. X =           70,001
# Coord. Y =           70,000
# Coord. Z =            0,000
#
# Point-2[8,9](De 1 pt)
# Coord. X =           70,001
# Coord. Y =           80,000
# Coord. Z =            0,001
#
# Point-2[8,10](De 1 pt)
# Coord. X =           70,001
# Coord. Y =           90,000
# Coord. Z =           -0,001
#
# Point-2[8,11](De 1 pt)
# Coord. X =           70,001
# Coord. Y =          100,000
# Coord. Z =            0,004
#
# Point-2[8,12](De 1 pt)
# Coord. X =           70,001
# Coord. Y =          110,000
# Coord. Z =            0,004
#
# Point-2[9,1](De 1 pt)
# Coord. X =           80,001
# Coord. Y =            0,001
# Coord. Z =            0,020
#
# Point-2[9,2](De 1 pt)
# Coord. X =           80,001
# Coord. Y =           10,000
# Coord. Z =            0,021
#
# Point-2[9,3](De 1 pt)
# Coord. X =           80,001
# Coord. Y =           20,000
# Coord. Z =            0,016
#
# Point-2[9,4](De 1 pt)
# Coord. X =           80,001
# Coord. Y =           30,000
# Coord. Z =            0,009
#
# Point-2[9,5](De 1 pt)
# Coord. X =           80,001
# Coord. Y =           40,000
# Coord. Z =            0,005
#
# Point-2[9,6](De 1 pt)
# Coord. X =           80,001
# Coord. Y =           50,000
# Coord. Z =            0,006
#
# Point-2[9,7](De 1 pt)
# Coord. X =           80,001
# Coord. Y =           60,000
# Coord. Z =            0,005
#
# Point-2[9,8](De 1 pt)
# Coord. X =           80,001
# Coord. Y =           70,000
# Coord. Z =            0,002
#
# Point-2[9,9](De 1 pt)
# Coord. X =           80,001
# Coord. Y =           80,000
# Coord. Z =           -0,002
#
# Point-2[9,10](De 1 pt)
# Coord. X =           80,001
# Coord. Y =           90,000
# Coord. Z =            0,001
#
# Point-2[9,11](De 1 pt)
# Coord. X =           80,001
# Coord. Y =          100,000
# Coord. Z =            0,008
#
# Point-2[9,12](De 1 pt)
# Coord. X =           80,001
# Coord. Y =          110,000
# Coord. Z =            0,008
#
# Point-2[10,1](De 1 pt)
# Coord. X =           90,001
# Coord. Y =            0,001
# Coord. Z =            0,016
#
# Point-2[10,2](De 1 pt)
# Coord. X =           90,001
# Coord. Y =           10,000
# Coord. Z =            0,017
#
# Point-2[10,3](De 1 pt)
# Coord. X =           90,001
# Coord. Y =           20,000
# Coord. Z =            0,011
#
# Point-2[10,4](De 1 pt)
# Coord. X =           90,001
# Coord. Y =           30,000
# Coord. Z =            0,010
#
# Point-2[10,5](De 1 pt)
# Coord. X =           90,001
# Coord. Y =           40,000
# Coord. Z =            0,008
#
# Point-2[10,6](De 1 pt)
# Coord. X =           90,001
# Coord. Y =           50,000
# Coord. Z =            0,006
#
# Point-2[10,7](De 1 pt)
# Coord. X =           90,001
# Coord. Y =           60,000
# Coord. Z =            0,004
#
# Point-2[10,8](De 1 pt)
# Coord. X =           90,001
# Coord. Y =           70,000
# Coord. Z =           -0,002
#
# Point-2[10,9](De 1 pt)
# Coord. X =           90,001
# Coord. Y =           80,000
# Coord. Z =           -0,006
#
# Point-2[10,10](De 1 pt)
# Coord. X =           90,001
# Coord. Y =           90,000
# Coord. Z =            0,005
#
# Point-2[10,11](De 1 pt)
# Coord. X =           90,001
# Coord. Y =          100,000
# Coord. Z =            0,012
#
# Point-2[10,12](De 1 pt)
# Coord. X =           90,001
# Coord. Y =          110,000
# Coord. Z =            0,012
#
# Point-2[11,1](De 1 pt)
# Coord. X =          100,001
# Coord. Y =            0,001
# Coord. Z =            0,018
#
# Point-2[11,2](De 1 pt)
# Coord. X =          100,001
# Coord. Y =           10,000
# Coord. Z =            0,016
#
# Point-2[11,3](De 1 pt)
# Coord. X =          100,001
# Coord. Y =           20,000
# Coord. Z =            0,014
#
# Point-2[11,4](De 1 pt)
# Coord. X =          100,001
# Coord. Y =           30,000
# Coord. Z =            0,015
#
# Point-2[11,5](De 1 pt)
# Coord. X =          100,001
# Coord. Y =           40,000
# Coord. Z =            0,009
#
# Point-2[11,6](De 1 pt)
# Coord. X =          100,001
# Coord. Y =           50,000
# Coord. Z =            0,007
#
# Point-2[11,7](De 1 pt)
# Coord. X =          100,001
# Coord. Y =           60,000
# Coord. Z =            0,000
#
# Point-2[11,8](De 1 pt)
# Coord. X =          100,001
# Coord. Y =           70,000
# Coord. Z =           -0,010
#
# Point-2[11,9](De 1 pt)
# Coord. X =          100,001
# Coord. Y =           80,000
# Coord. Z =           -0,006
#
# Point-2[11,10](De 1 pt)
# Coord. X =          100,001
# Coord. Y =           90,000
# Coord. Z =            0,005
#
# Point-2[11,11](De 1 pt)
# Coord. X =          100,001
# Coord. Y =          100,000
# Coord. Z =            0,013
#
# Point-2[11,12](De 1 pt)
# Coord. X =          100,001
# Coord. Y =          110,000
# Coord. Z =            0,014
#
# Point-2[12,1](De 1 pt)
# Coord. X =          110,001
# Coord. Y =            0,001
# Coord. Z =            0,024
#
# Point-2[12,2](De 1 pt)
# Coord. X =          110,001
# Coord. Y =           10,000
# Coord. Z =            0,019
#
# Point-2[12,3](De 1 pt)
# Coord. X =          110,001
# Coord. Y =           20,000
# Coord. Z =            0,015
#
# Point-2[12,4](De 1 pt)
# Coord. X =          110,001
# Coord. Y =           30,000
# Coord. Z =            0,015
#
# Point-2[12,5](De 1 pt)
# Coord. X =          110,001
# Coord. Y =           40,000
# Coord. Z =            0,012
#
# Point-2[12,6](De 1 pt)
# Coord. X =          110,001
# Coord. Y =           50,000
# Coord. Z =            0,010
#
# Point-2[12,7](De 1 pt)
# Coord. X =          110,001
# Coord. Y =           60,000
# Coord. Z =            0,005
#
# Point-2[12,8](De 1 pt)
# Coord. X =          110,001
# Coord. Y =           70,000
# Coord. Z =           -0,002
#
# Point-2[12,9](De 1 pt)
# Coord. X =          110,001
# Coord. Y =           80,000
# Coord. Z =            0,002
#
# Point-2[12,10](De 1 pt)
# Coord. X =          110,001
# Coord. Y =           90,000
# Coord. Z =            0,007
#
# Point-2[12,11](De 1 pt)
# Coord. X =          110,001
# Coord. Y =          100,000
# Coord. Z =            0,013
#
# Point-2[12,12](De 1 pt)
# Coord. X =          110,001
# Coord. Y =          110,000
# Coord. Z =            0,016
#
# Point-2[13,1](De 1 pt)
# Coord. X =          120,001
# Coord. Y =            0,001
# Coord. Z =            0,026
#
# Point-2[13,2](De 1 pt)
# Coord. X =          120,001
# Coord. Y =           10,000
# Coord. Z =            0,020
#
# Point-2[13,3](De 1 pt)
# Coord. X =          120,001
# Coord. Y =           20,000
# Coord. Z =            0,012
#
# Point-2[13,4](De 1 pt)
# Coord. X =          120,001
# Coord. Y =           30,000
# Coord. Z =            0,011
#
# Point-2[13,5](De 1 pt)
# Coord. X =          120,001
# Coord. Y =           40,000
# Coord. Z =            0,014
#
# Point-2[13,6](De 1 pt)
# Coord. X =          120,001
# Coord. Y =           50,000
# Coord. Z =            0,012
#
# Point-2[13,7](De 1 pt)
# Coord. X =          120,001
# Coord. Y =           60,000
# Coord. Z =            0,009
#
# Point-2[13,8](De 1 pt)
# Coord. X =          120,001
# Coord. Y =           70,000
# Coord. Z =            0,008
#
# Point-2[13,9](De 1 pt)
# Coord. X =          120,001
# Coord. Y =           80,000
# Coord. Z =            0,009
#
# Point-2[13,10](De 1 pt)
# Coord. X =          120,001
# Coord. Y =           90,000
# Coord. Z =            0,010
#
# Point-2[13,11](De 1 pt)
# Coord. X =          120,001
# Coord. Y =          100,000
# Coord. Z =            0,013
#
# Point-2[13,12](De 1 pt)
# Coord. X =          120,001
# Coord. Y =          110,000
# Coord. Z =            0,016
#
# Point-2[14,1](De 1 pt)
# Coord. X =          130,001
# Coord. Y =            0,001
# Coord. Z =            0,027
#
# Point-2[14,2](De 1 pt)
# Coord. X =          130,001
# Coord. Y =           10,000
# Coord. Z =            0,023
#
# Point-2[14,3](De 1 pt)
# Coord. X =          130,001
# Coord. Y =           20,000
# Coord. Z =            0,021
#
# Point-2[14,4](De 1 pt)
# Coord. X =          130,001
# Coord. Y =           30,000
# Coord. Z =            0,019
#
# Point-2[14,5](De 1 pt)
# Coord. X =          130,001
# Coord. Y =           40,000
# Coord. Z =            0,017
#
# Point-2[14,6](De 1 pt)
# Coord. X =          130,001
# Coord. Y =           50,000
# Coord. Z =            0,016
#
# Point-2[14,7](De 1 pt)
# Coord. X =          130,001
# Coord. Y =           60,000
# Coord. Z =            0,014
#
# Point-2[14,8](De 1 pt)
# Coord. X =          130,001
# Coord. Y =           70,000
# Coord. Z =            0,013
#
# Point-2[14,9](De 1 pt)
# Coord. X =          130,001
# Coord. Y =           80,000
# Coord. Z =            0,011
#
# Point-2[14,10](De 1 pt)
# Coord. X =          130,001
# Coord. Y =           90,000
# Coord. Z =            0,005
#
# Point-2[14,11](De 1 pt)
# Coord. X =          130,001
# Coord. Y =          100,000
# Coord. Z =            0,010
#
# Point-2[14,12](De 1 pt)
# Coord. X =          130,001
# Coord. Y =          110,000
# Coord. Z =            0,014
#
# Point-2[15,1](De 1 pt)
# Coord. X =          140,001
# Coord. Y =            0,001
# Coord. Z =            0,028
#
# Point-2[15,2](De 1 pt)
# Coord. X =          140,001
# Coord. Y =           10,000
# Coord. Z =            0,026
#
# Point-2[15,3](De 1 pt)
# Coord. X =          140,001
# Coord. Y =           20,000
# Coord. Z =            0,023
#
# Point-2[15,4](De 1 pt)
# Coord. X =          140,001
# Coord. Y =           30,000
# Coord. Z =            0,023
#
# Point-2[15,5](De 1 pt)
# Coord. X =          140,001
# Coord. Y =           40,000
# Coord. Z =            0,021
#
# Point-2[15,6](De 1 pt)
# Coord. X =          140,001
# Coord. Y =           50,000
# Coord. Z =            0,020
#
# Point-2[15,7](De 1 pt)
# Coord. X =          140,001
# Coord. Y =           60,000
# Coord. Z =            0,018
#
# Point-2[15,8](De 1 pt)
# Coord. X =          140,001
# Coord. Y =           70,000
# Coord. Z =            0,017
#
# Point-2[15,9](De 1 pt)
# Coord. X =          140,001
# Coord. Y =           80,000
# Coord. Z =            0,011
#
# Point-2[15,10](De 1 pt)
# Coord. X =          140,001
# Coord. Y =           90,000
# Coord. Z =           -0,002
#
# Point-2[15,11](De 1 pt)
# Coord. X =          140,001
# Coord. Y =          100,000
# Coord. Z =            0,001
#
# Point-2[15,12](De 1 pt)
# Coord. X =          140,001
# Coord. Y =          110,000
# Coord. Z =            0,007
#
# Point-2[16,1](De 1 pt)
# Coord. X =          150,001
# Coord. Y =            0,001
# Coord. Z =            0,030
#
# Point-2[16,2](De 1 pt)
# Coord. X =          150,001
# Coord. Y =           10,000
# Coord. Z =            0,029
#
# Point-2[16,3](De 1 pt)
# Coord. X =          150,001
# Coord. Y =           20,000
# Coord. Z =            0,024
#
# Point-2[16,4](De 1 pt)
# Coord. X =          150,001
# Coord. Y =           30,000
# Coord. Z =            0,022
#
# Point-2[16,5](De 1 pt)
# Coord. X =          150,001
# Coord. Y =           40,000
# Coord. Z =            0,021
#
# Point-2[16,6](De 1 pt)
# Coord. X =          150,001
# Coord. Y =           50,000
# Coord. Z =            0,021
#
# Point-2[16,7](De 1 pt)
# Coord. X =          150,001
# Coord. Y =           60,000
# Coord. Z =            0,020
#
# Point-2[16,8](De 1 pt)
# Coord. X =          150,001
# Coord. Y =           70,000
# Coord. Z =            0,009
#
# Point-2[16,9](De 1 pt)
# Coord. X =          150,001
# Coord. Y =           80,000
# Coord. Z =           -0,007
#
# Point-2[16,10](De 1 pt)
# Coord. X =          150,001
# Coord. Y =           90,000
# Coord. Z =           -0,003
#
# Point-2[16,11](De 1 pt)
# Coord. X =          150,001
# Coord. Y =          100,000
# Coord. Z =            0,010
#
# Point-2[16,12](De 1 pt)
# Coord. X =          150,001
# Coord. Y =          110,000
# Coord. Z =            0,014
#
# Plan-1(De 193 pt)
# Coord. X =           74,612
# Coord. Y =           54,715
# Coord. Z =            0,009
# Angle (XY) =          119,769
# Angle X =           90,005
# Angle Y =           89,991
# Angle Z =            0,010
# Planéité =                                            0,031
# Plan. min =                                            0,019
# Plan. max =                                            0,012

# %%
# Initialize variables to store point IDs and corresponding coordinates
point_data = []

# Regular expressions to match point ID and coordinate lines
point_id_pattern = r'\[([\d,]+)\]'
coord_pattern = r'Coord\. ([XYZ]) =\s*([-+]?\d+,\d+)'

# Extract point IDs and coordinates from lines
current_point_id = None
current_coords = {}

skipped_lines = 0
for line in lines:
    if skipped_lines < 3 and not line.startswith('Plan'):
        skipped_lines += 1
        continue
    elif line.startswith('Plan'):
        break
    # Check if the line contains a point ID
    match_id = re.search(point_id_pattern, line)
    if match_id:
        current_point_id = match_id.group(1)
        current_coords = {}
        continue

    # Check if the line contains a coordinate
    match_coord = re.search(coord_pattern, line)
    if match_coord and current_point_id:
        coord_type = match_coord.group(1)
        coord_value = float(match_coord.group(2).replace(',', '.'))
        
        # Check if the Y coordinate is not equal to 0.002
        if coord_type == 'Y' and coord_value == 0.002:
            continue  # Skip this coordinate
        if coord_type == 'X' and coord_value == 0.0 and coord_type == 'Y' and coord_value == 50.0: 
            continue
        if coord_type == 'X' and coord_value == 80.0:
            if coord_type == 'Y' and coord_value == 20.0:
                continue
        current_coords[coord_type] = coord_value

        # If all coordinates are found, add them to the point data
        if len(current_coords) == 3 :#and current_coords['X']!=0 :# and current_coords['X'] == 150. and current_coords['Y'] == 150.:
        #if len(current_coords) == 3 and current_coords['X']>70.0 and current_coords['Y']<25.:
            point_data.append((current_point_id, current_coords))
            current_point_id = None

# Print the extracted point data
for point_id, coords in point_data:
    print("Point ID:", point_id)
    print("Coordinates:", coords)
# Out:
# Point ID: 1,1
# Coordinates: {'X': 0.001, 'Y': 0.001, 'Z': 0.0}
# Point ID: 1,2
# Coordinates: {'X': 0.001, 'Y': 10.0, 'Z': 0.004}
# Point ID: 1,3
# Coordinates: {'X': 0.001, 'Y': 20.0, 'Z': 0.005}
# Point ID: 1,4
# Coordinates: {'X': 0.001, 'Y': 30.0, 'Z': 0.004}
# Point ID: 1,5
# Coordinates: {'X': 0.001, 'Y': 40.0, 'Z': -0.003}
# Point ID: 1,6
# Coordinates: {'X': 0.001, 'Y': 50.0, 'Z': -0.005}
# Point ID: 1,7
# Coordinates: {'X': 0.001, 'Y': 60.0, 'Z': -0.007}
# Point ID: 1,8
# Coordinates: {'X': 0.001, 'Y': 70.0, 'Z': -0.009}
# Point ID: 1,9
# Coordinates: {'X': 0.001, 'Y': 80.0, 'Z': -0.011}
# Point ID: 1,10
# Coordinates: {'X': 0.001, 'Y': 90.0, 'Z': -0.014}
# Point ID: 1,11
# Coordinates: {'X': 0.001, 'Y': 100.0, 'Z': -0.012}
# Point ID: 1,12
# Coordinates: {'X': 0.001, 'Y': 110.0, 'Z': -0.014}
# Point ID: 2,1
# Coordinates: {'X': 10.001, 'Y': 0.001, 'Z': 0.01}
# Point ID: 2,2
# Coordinates: {'X': 10.001, 'Y': 10.0, 'Z': 0.012}
# Point ID: 2,3
# Coordinates: {'X': 10.001, 'Y': 20.0, 'Z': 0.012}
# Point ID: 2,4
# Coordinates: {'X': 10.001, 'Y': 30.0, 'Z': 0.012}
# Point ID: 2,5
# Coordinates: {'X': 10.001, 'Y': 40.0, 'Z': 0.009}
# Point ID: 2,6
# Coordinates: {'X': 10.001, 'Y': 50.0, 'Z': 0.007}
# Point ID: 2,7
# Coordinates: {'X': 10.001, 'Y': 60.0, 'Z': 0.005}
# Point ID: 2,8
# Coordinates: {'X': 10.001, 'Y': 70.0, 'Z': 0.002}
# Point ID: 2,9
# Coordinates: {'X': 10.001, 'Y': 80.0, 'Z': -0.002}
# Point ID: 2,10
# Coordinates: {'X': 10.001, 'Y': 90.0, 'Z': -0.002}
# Point ID: 2,11
# Coordinates: {'X': 10.001, 'Y': 100.0, 'Z': -0.002}
# Point ID: 2,12
# Coordinates: {'X': 10.001, 'Y': 110.0, 'Z': 0.0}
# Point ID: 3,1
# Coordinates: {'X': 20.001, 'Y': 0.001, 'Z': 0.016}
# Point ID: 3,2
# Coordinates: {'X': 20.001, 'Y': 10.0, 'Z': 0.014}
# Coordinates: {'X': 70.001, 'Y': 50.0, 'Z': 0.006}
# Point ID: 8,7
# Coordinates: {'X': 70.001, 'Y': 60.0, 'Z': 0.003}
# Point ID: 8,8
# Coordinates: {'X': 70.001, 'Y': 70.0, 'Z': 0.0}
# Point ID: 8,9
# Coordinates: {'X': 70.001, 'Y': 80.0, 'Z': 0.001}
# Point ID: 8,10
# Coordinates: {'X': 70.001, 'Y': 90.0, 'Z': -0.001}
# Point ID: 8,11
# Coordinates: {'X': 70.001, 'Y': 100.0, 'Z': 0.004}
# Point ID: 8,12
# Coordinates: {'X': 70.001, 'Y': 110.0, 'Z': 0.004}
# Point ID: 9,1
# Coordinates: {'X': 80.001, 'Y': 0.001, 'Z': 0.02}
# Point ID: 9,2
# Coordinates: {'X': 80.001, 'Y': 10.0, 'Z': 0.021}
# Point ID: 9,3
# Coordinates: {'X': 80.001, 'Y': 20.0, 'Z': 0.016}
# Point ID: 9,4
# Coordinates: {'X': 80.001, 'Y': 30.0, 'Z': 0.009}
# Point ID: 9,5
# Coordinates: {'X': 80.001, 'Y': 40.0, 'Z': 0.005}
# Point ID: 9,6
# Coordinates: {'X': 80.001, 'Y': 50.0, 'Z': 0.006}
# Point ID: 9,7
# Coordinates: {'X': 80.001, 'Y': 60.0, 'Z': 0.005}
# Point ID: 9,8
# Coordinates: {'X': 80.001, 'Y': 70.0, 'Z': 0.002}
# Point ID: 9,9
# Coordinates: {'X': 80.001, 'Y': 80.0, 'Z': -0.002}
# Point ID: 9,10
# Coordinates: {'X': 80.001, 'Y': 90.0, 'Z': 0.001}
# Point ID: 9,11
# Coordinates: {'X': 80.001, 'Y': 100.0, 'Z': 0.008}
# Point ID: 9,12
# Coordinates: {'X': 80.001, 'Y': 110.0, 'Z': 0.008}
# Point ID: 10,1
# Coordinates: {'X': 90.001, 'Y': 0.001, 'Z': 0.016}
# Point ID: 10,2
# Coordinates: {'X': 90.001, 'Y': 10.0, 'Z': 0.017}
# Point ID: 10,3
# Coordinates: {'X': 90.001, 'Y': 20.0, 'Z': 0.011}
# Point ID: 10,4
# Coordinates: {'X': 90.001, 'Y': 30.0, 'Z': 0.01}
# Point ID: 10,5
# Coordinates: {'X': 90.001, 'Y': 40.0, 'Z': 0.008}
# Point ID: 10,6
# Coordinates: {'X': 90.001, 'Y': 50.0, 'Z': 0.006}
# Point ID: 10,7
# Coordinates: {'X': 90.001, 'Y': 60.0, 'Z': 0.004}
# Point ID: 10,8
# Coordinates: {'X': 90.001, 'Y': 70.0, 'Z': -0.002}
# Point ID: 10,9
# Coordinates: {'X': 90.001, 'Y': 80.0, 'Z': -0.006}
# Point ID: 10,10
# Coordinates: {'X': 90.001, 'Y': 90.0, 'Z': 0.005}
# Point ID: 10,11
# Coordinates: {'X': 90.001, 'Y': 100.0, 'Z': 0.012}
# Point ID: 10,12
# Coordinates: {'X': 90.001, 'Y': 110.0, 'Z': 0.012}
# Point ID: 11,1
# Coordinates: {'X': 100.001, 'Y': 0.001, 'Z': 0.018}
# Point ID: 16,5
# Coordinates: {'X': 150.001, 'Y': 40.0, 'Z': 0.021}
# Point ID: 16,6
# Coordinates: {'X': 150.001, 'Y': 50.0, 'Z': 0.021}
# Point ID: 16,7
# Coordinates: {'X': 150.001, 'Y': 60.0, 'Z': 0.02}
# Point ID: 16,8
# Coordinates: {'X': 150.001, 'Y': 70.0, 'Z': 0.009}
# Point ID: 16,9
# Coordinates: {'X': 150.001, 'Y': 80.0, 'Z': -0.007}
# Point ID: 16,10
# Coordinates: {'X': 150.001, 'Y': 90.0, 'Z': -0.003}
# Point ID: 16,11
# Coordinates: {'X': 150.001, 'Y': 100.0, 'Z': 0.01}
# Point ID: 16,12
# Coordinates: {'X': 150.001, 'Y': 110.0, 'Z': 0.014}

# %%
# Extract X, Y, Z values and corresponding point IDs
point_ids = []
x_values = []
y_values = []
z_values = []

for point_id, coords in point_data:
    point_ids.append(point_id)
    x_values.append(coords['X'])
    y_values.append(coords['Y'])
    z_values.append(coords['Z'])

# Plot the XYZ points relative to their point IDs
fig = plt.figure(figsize=(20, 16))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_values, y_values, z_values)

# Label each point with its corresponding ID
for i, point_id in enumerate(point_ids):
    ax.text(x_values[i], y_values[i], z_values[i], point_id)

# Set labels and title
ax.set_xlabel('X [mm]', fontsize=14, fontweight='bold')
ax.set_ylabel('Y [mm]', fontsize=14, fontweight='bold')
ax.set_zlabel('Z [mm]', fontsize=14, fontweight='bold')
ax.set_title('Position Points XYZ', fontsize=11, fontweight='bold')

plt.show()

# %%
plt.figure(figsize=(15, 11))
plt.scatter(x_values, y_values, c=z_values, cmap='viridis', s=50)
plt.colorbar(label='Z [mm] (Weight)')
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Planarity Plot with Z (Weight)', fontsize=11, fontweight='bold')
plt.grid(True)
plt.show()

# %%
# Create a regular grid to interpolate onto
x_grid = np.linspace(min(x_values), max(x_values), 100)
y_grid = np.linspace(min(y_values), max(y_values), 100)
X, Y = np.meshgrid(x_grid, y_grid)

# Interpolate Z values onto the grid
Z = griddata((x_values, y_values), z_values, (X, Y), method='linear')
Z_grid = np.linspace(min(z_values), max(z_values), 100)
#colorbar = plt.colorbar(heatmap, label='Z [mm]', ticks=np.linspace(Z_grid.min(), Z_grid.max(), num=10))

# Plot the heatmap
plt.figure(figsize=(15, 11))
plt.pcolormesh(X, Y, Z, cmap='viridis')
plt.colorbar(label='Z [mm]', ticks=np.linspace(Z_grid.min(), Z_grid.max(), num=10))
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Interpolated Heatmap of XYZ', fontsize=11, fontweight='bold')
plt.show()

# %%
# Flatten the interpolated Z values
Z_flat = Z.flatten()

# Calculate the Root Mean Square (RMS)
rms = np.sqrt(np.mean(Z_flat**2))

print("Root Mean Square (RMS) of the heatmap:", rms)
# Out:
# Root Mean Square (RMS) of the heatmap: 0.011986359291599217

# %%
print(Z_flat)
# Out:
# [0.         0.00151515 0.0030303  ... 0.01187879 0.01293939 0.014     ]

# %%
# Find the NaN points
nan_indices = np.isnan(Z)
nan_points = np.column_stack((X[nan_indices], Y[nan_indices]))

# Print the NaN points
print("NaN Points (X, Y):")
print(nan_points)
# Out:
# NaN Points (X, Y):
# []

# %%
# Calculate the Root Mean Square (RMS) excluding NaN values
rms = np.sqrt(np.nanmean(Z_flat**2))

print("Root Mean Square (RMS) of the heatmap (excluding NaN points):", rms)
# Out:
# Root Mean Square (RMS) of the heatmap (excluding NaN points): 0.011986359291599217

# %%
std_dev = np.std(Z_flat, ddof=1)
RMS = round(std_dev, 6)
print("RMS RAW =", RMS)
# Out:
# RMS RAW = 0.007541

# %%
# Create the histogram
plt.figure(figsize=(12, 10))

plt.hist(z_values, bins=50, color='green', edgecolor='black', alpha=0.8)
# Add mean, median, and standard deviation lines
mean_value = np.mean(z_values)
median_value = np.median(z_values)
std_dev = np.std(z_values)

plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean_value:.2f}')
plt.axvline(median_value, color='green', linestyle='dashed', linewidth=1, label=f'Median: {median_value:.2f}')
plt.axvline(mean_value + std_dev, color='orange', linestyle='dashed', linewidth=1, label=f'Standard Deviation: {std_dev:.2f}')
plt.axvline(mean_value - std_dev, color='orange', linestyle='dashed', linewidth=1)

plt.legend()
plt.xlabel('Z Measured [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Entries', fontsize=14, fontweight='bold')
#plt.title('Histogram of Z Values')
#plt.title('Histogram with Statistics')
plt.grid(True)
plt.show()

# %%
# Group Z values by X values
x_groups = {}
for x, z in zip(x_values, z_values):
    if x not in x_groups:
        x_groups[x] = []
    x_groups[x].append(z)

# Plot scatter plots for each X group
plt.figure(figsize=(40, 20))
for x, z_group in x_groups.items():
    plt.scatter([x] * len(z_group), z_group, label=f"X = {x}")

plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Z [mm]', fontsize=14, fontweight='bold')
plt.title('Scatter Plot of Z Values for Each X Group', fontsize=11, fontweight='bold')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Group Z values by Y values
y_groups = {}
for y, z in zip(y_values, z_values):
    if y not in y_groups:
        y_groups[y] = []
    y_groups[y].append(z)

# Plot scatter plots for each X group
plt.figure(figsize=(40, 20))
for y, z_group in y_groups.items():
    indices = range(1, len(z_values) + 1)
    #plt.scatter(indices, z_values, label=f'Y = {y}')

    plt.scatter([y] * len(z_group), z_group, label=f"Y = {y}")

plt.xlabel('Y [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Z [mm]', fontsize=14, fontweight='bold')
plt.title('Scatter Plot of Z Values for Each Y Group', fontsize=11, fontweight='bold')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Initialize variables to store point IDs and corresponding coordinates
point_data = []

# Regular expressions to match point ID and coordinate lines
point_id_pattern = r'\[([\d,]+)\]'
coord_pattern = r'Coord\. ([XYZ]) =\s*([-+]?\d+,\d+)'

# Extract point IDs and coordinates from lines
current_point_id = None
current_coords = {}

skipped_lines = 0
for line in lines:
    if skipped_lines < 3 and not line.startswith('Plan'):
        skipped_lines += 1
        continue
    elif line.startswith('Plan'):
        break
    # Check if the line contains a point ID
    match_id = re.search(point_id_pattern, line)
    if match_id:
        current_point_id = match_id.group(1)
        current_coords = {}
        continue

   # Check if the line contains a coordinate
    match_coord = re.search(coord_pattern, line)
    if match_coord and current_point_id:
        coord_type = match_coord.group(1)
        coord_value = float(match_coord.group(2).replace(',', '.'))
        
        # Check if the Y coordinate is not equal to 0.002
        if coord_type == 'Y' and coord_value == 0.002:
            continue  # Skip this coordinate
        if coord_type == 'X' and coord_value == 0.0 and coord_type == 'Y' and coord_value == 50.0: 
            continue
             
        current_coords[coord_type] = coord_value

        # If all coordinates are found, add them to the point data
        if len(current_coords) == 3 : #and current_coords['X']!=0:# and current_coords['X'] == 150. and current_coords['Y'] == 150.:
            point_data.append((current_point_id, current_coords))
            current_point_id = None

# Convert the data to the desired format
formatted_data = []
for point_id, coords in point_data:
    formatted_coords = {'X': coords['X'], 'Y': coords['Y'], 'Z': coords['Z']}
    formatted_data.append((point_id, formatted_coords))

# Print the formatted data
for point_id, coords in formatted_data:
    print("Point ID:", point_id)
    print("Coordinates:", coords)
# Out:
# Point ID: 1,1
# Coordinates: {'X': 0.001, 'Y': 0.001, 'Z': 0.0}
# Point ID: 1,2
# Coordinates: {'X': 0.001, 'Y': 10.0, 'Z': 0.004}
# Point ID: 1,3
# Coordinates: {'X': 0.001, 'Y': 20.0, 'Z': 0.005}
# Point ID: 1,4
# Coordinates: {'X': 0.001, 'Y': 30.0, 'Z': 0.004}
# Point ID: 1,5
# Coordinates: {'X': 0.001, 'Y': 40.0, 'Z': -0.003}
# Point ID: 1,6
# Coordinates: {'X': 0.001, 'Y': 50.0, 'Z': -0.005}
# Point ID: 1,7
# Coordinates: {'X': 0.001, 'Y': 60.0, 'Z': -0.007}
# Point ID: 1,8
# Coordinates: {'X': 0.001, 'Y': 70.0, 'Z': -0.009}
# Point ID: 1,9
# Coordinates: {'X': 0.001, 'Y': 80.0, 'Z': -0.011}
# Point ID: 1,10
# Coordinates: {'X': 0.001, 'Y': 90.0, 'Z': -0.014}
# Point ID: 1,11
# Coordinates: {'X': 0.001, 'Y': 100.0, 'Z': -0.012}
# Point ID: 1,12
# Coordinates: {'X': 0.001, 'Y': 110.0, 'Z': -0.014}
# Point ID: 2,1
# Coordinates: {'X': 10.001, 'Y': 0.001, 'Z': 0.01}
# Point ID: 2,2
# Coordinates: {'X': 10.001, 'Y': 10.0, 'Z': 0.012}
# Point ID: 2,3
# Coordinates: {'X': 10.001, 'Y': 20.0, 'Z': 0.012}
# Point ID: 2,4
# Coordinates: {'X': 10.001, 'Y': 30.0, 'Z': 0.012}
# Point ID: 2,5
# Coordinates: {'X': 10.001, 'Y': 40.0, 'Z': 0.009}
# Point ID: 2,6
# Coordinates: {'X': 10.001, 'Y': 50.0, 'Z': 0.007}
# Point ID: 2,7
# Coordinates: {'X': 10.001, 'Y': 60.0, 'Z': 0.005}
# Point ID: 2,8
# Coordinates: {'X': 10.001, 'Y': 70.0, 'Z': 0.002}
# Point ID: 2,9
# Coordinates: {'X': 10.001, 'Y': 80.0, 'Z': -0.002}
# Point ID: 2,10
# Coordinates: {'X': 10.001, 'Y': 90.0, 'Z': -0.002}
# Coordinates: {'X': 70.001, 'Y': 10.0, 'Z': 0.019}
# Point ID: 8,3
# Coordinates: {'X': 70.001, 'Y': 20.0, 'Z': 0.015}
# Point ID: 8,4
# Coordinates: {'X': 70.001, 'Y': 30.0, 'Z': 0.01}
# Point ID: 8,5
# Coordinates: {'X': 70.001, 'Y': 40.0, 'Z': 0.006}
# Point ID: 8,6
# Coordinates: {'X': 70.001, 'Y': 50.0, 'Z': 0.006}
# Point ID: 8,7
# Coordinates: {'X': 70.001, 'Y': 60.0, 'Z': 0.003}
# Point ID: 8,8
# Coordinates: {'X': 70.001, 'Y': 70.0, 'Z': 0.0}
# Point ID: 8,9
# Coordinates: {'X': 70.001, 'Y': 80.0, 'Z': 0.001}
# Point ID: 8,10
# Coordinates: {'X': 70.001, 'Y': 90.0, 'Z': -0.001}
# Point ID: 8,11
# Coordinates: {'X': 70.001, 'Y': 100.0, 'Z': 0.004}
# Point ID: 8,12
# Coordinates: {'X': 70.001, 'Y': 110.0, 'Z': 0.004}
# Point ID: 9,1
# Coordinates: {'X': 80.001, 'Y': 0.001, 'Z': 0.02}
# Point ID: 9,2
# Coordinates: {'X': 80.001, 'Y': 10.0, 'Z': 0.021}
# Point ID: 9,3
# Coordinates: {'X': 80.001, 'Y': 20.0, 'Z': 0.016}
# Point ID: 9,4
# Coordinates: {'X': 80.001, 'Y': 30.0, 'Z': 0.009}
# Point ID: 9,5
# Coordinates: {'X': 80.001, 'Y': 40.0, 'Z': 0.005}
# Point ID: 9,6
# Coordinates: {'X': 80.001, 'Y': 50.0, 'Z': 0.006}
# Point ID: 9,7
# Coordinates: {'X': 80.001, 'Y': 60.0, 'Z': 0.005}
# Point ID: 9,8
# Coordinates: {'X': 80.001, 'Y': 70.0, 'Z': 0.002}
# Point ID: 9,9
# Coordinates: {'X': 80.001, 'Y': 80.0, 'Z': -0.002}
# Point ID: 9,10
# Coordinates: {'X': 80.001, 'Y': 90.0, 'Z': 0.001}
# Point ID: 9,11
# Coordinates: {'X': 80.001, 'Y': 100.0, 'Z': 0.008}
# Point ID: 9,12
# Coordinates: {'X': 80.001, 'Y': 110.0, 'Z': 0.008}
# Point ID: 10,1
# Coordinates: {'X': 90.001, 'Y': 0.001, 'Z': 0.016}
# Point ID: 10,2
# Coordinates: {'X': 90.001, 'Y': 10.0, 'Z': 0.017}
# Point ID: 10,3
# Coordinates: {'X': 90.001, 'Y': 20.0, 'Z': 0.011}
# Point ID: 10,4
# Coordinates: {'X': 90.001, 'Y': 30.0, 'Z': 0.01}
# Point ID: 10,5
# Coordinates: {'X': 90.001, 'Y': 40.0, 'Z': 0.008}
# Point ID: 10,6
# Coordinates: {'X': 90.001, 'Y': 50.0, 'Z': 0.006}
# Point ID: 10,7
# Coordinates: {'X': 90.001, 'Y': 60.0, 'Z': 0.004}
# Point ID: 10,8
# Coordinates: {'X': 90.001, 'Y': 70.0, 'Z': -0.002}
# Point ID: 10,9
# Coordinates: {'X': 90.001, 'Y': 80.0, 'Z': -0.006}
# Point ID: 16,1
# Coordinates: {'X': 150.001, 'Y': 0.001, 'Z': 0.03}
# Point ID: 16,2
# Coordinates: {'X': 150.001, 'Y': 10.0, 'Z': 0.029}
# Point ID: 16,3
# Coordinates: {'X': 150.001, 'Y': 20.0, 'Z': 0.024}
# Point ID: 16,4
# Coordinates: {'X': 150.001, 'Y': 30.0, 'Z': 0.022}
# Point ID: 16,5
# Coordinates: {'X': 150.001, 'Y': 40.0, 'Z': 0.021}
# Point ID: 16,6
# Coordinates: {'X': 150.001, 'Y': 50.0, 'Z': 0.021}
# Point ID: 16,7
# Coordinates: {'X': 150.001, 'Y': 60.0, 'Z': 0.02}
# Point ID: 16,8
# Coordinates: {'X': 150.001, 'Y': 70.0, 'Z': 0.009}
# Point ID: 16,9
# Coordinates: {'X': 150.001, 'Y': 80.0, 'Z': -0.007}
# Point ID: 16,10
# Coordinates: {'X': 150.001, 'Y': 90.0, 'Z': -0.003}
# Point ID: 16,11
# Coordinates: {'X': 150.001, 'Y': 100.0, 'Z': 0.01}
# Point ID: 16,12
# Coordinates: {'X': 150.001, 'Y': 110.0, 'Z': 0.014}

# %%
# Group the data by X coordinate
plt.figure(figsize=(40, 20))

grouped_data = {}
for point_id, coords in formatted_data:
    x_coord = coords['X']
    if x_coord not in grouped_data:
        grouped_data[x_coord] = []
    grouped_data[x_coord].append((point_id, coords['Y'], coords['Z']))

# Plot each group separately
for x, points in grouped_data.items():
    point_ids, ys, zs = zip(*points)
    plt.scatter(ys, zs, label=f'X = {x}')

# Add labels and legend
plt.xlabel('Y [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Z [mm]', fontsize=14, fontweight='bold')
plt.title('Scatter Plot of Points with the Same X Coordinate', fontsize=11, fontweight='bold')
plt.legend()
plt.show()

# %%
# Extract X, Y, and Z values from the data
x_values = []
y_values = []
z_values = []
for position, coords in formatted_data:
    x_values.append(coords['X'])
    y_values.append(coords['Y'])
    z_values.append(coords['Z'])

# Perform linear regression to fit a line to the data
slope_y, intercept_y = np.polyfit(y_values, z_values, 1)

# Calculate the fitted line
fitted_line_y = slope_y * np.array(y_values) + intercept_y

# Subtract the fitted line from the original Z values to correct for the slope in the Y direction
corrected_z_values_y = np.array(z_values) - fitted_line_y

# Plot the original and corrected Z values
plt.figure(figsize=(10, 6))
plt.scatter(y_values, z_values, label='Original Z Values')
plt.plot(y_values, fitted_line_y, color='red', label='Fitted Line')
plt.scatter(y_values, corrected_z_values_y, color='green', label='Corrected Z Values')
plt.xlabel('Y [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Z [mm]', fontsize=14, fontweight='bold')
plt.title('Original and Corrected Z Values (Y direction)', fontsize=11, fontweight='bold')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create a regular grid to interpolate onto
x_grid = np.linspace(min(x_values), max(x_values), 100)
y_grid = np.linspace(min(y_values), max(y_values), 100)
X, Y = np.meshgrid(x_grid, y_grid)

# Interpolate Z values onto the grid
Z = griddata((x_values, y_values), corrected_z_values_y, (X, Y), method='linear')

# Plot the heatmap
plt.figure(figsize=(10, 6))
plt.pcolormesh(X, Y, Z, cmap='viridis')
plt.colorbar(label='Z [mm]')
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Interpolated Heatmap of XYZ with Corrected Z -Simultaneous Fit', fontsize=11, fontweight='bold')
plt.show()

# %%
# Flatten the interpolated Z values
Z_flat = Z.flatten()

# Calculate the Root Mean Square (RMS) excluding NaN values
rms = np.sqrt(np.nanmean(Z_flat**2))

print("Root Mean Square (RMS) of the heatmap (excluding NaN points):", rms)
# Out:
# Root Mean Square (RMS) of the heatmap (excluding NaN points): 0.005629985302732754

# %%
std_dev = np.std(Z_flat, ddof=1)
RMS = round(std_dev, 6)
print("RMS RAW =", RMS)
# Out:
# RMS RAW = 0.00563

# %%
# Create the histogram
plt.figure(figsize=(12, 10))

plt.hist(corrected_z_values_y, bins=50, color='green', edgecolor='black', alpha=0.8)
# Add mean, median, and standard deviation lines
mean_value = np.mean(corrected_z_values_y)
median_value = np.median(corrected_z_values_y)
std_dev = np.std(corrected_z_values_y)

plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_value:.2f}')
plt.axvline(median_value, color='green', linestyle='dashed', linewidth=1, label=f'Median: {median_value:.2f}')
plt.axvline(mean_value + std_dev, color='orange', linestyle='dashed', linewidth=1, label=f'Standard Deviation: {std_dev:.2f}')
plt.axvline(mean_value - std_dev, color='orange', linestyle='dashed', linewidth=1)

plt.legend()
plt.xlabel('Z [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Entries', fontsize=14, fontweight='bold')
plt.title('Histogram of Z corrected Values -Simultaneous Fit', fontsize=11, fontweight='bold')
plt.grid(True)
plt.show()

# %%
# Group the data by X coordinate
plt.figure(figsize=(20, 12))

grouped_data = {}
for point_id, coords in formatted_data:
    y_coord = coords['Y']
    if y_coord not in grouped_data:
        grouped_data[y_coord] = []
    grouped_data[y_coord].append((point_id, coords['X'], coords['Z']))

# Plot each group separately
for y, points in grouped_data.items():
    point_ids, xs, zs = zip(*points)
    plt.scatter(xs, zs, label=f'Y = {y}')

# Add labels and legend
plt.xlabel('Y [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Z [mm]', fontsize=14, fontweight='bold')
plt.title('Scatter Plot of Points with the Same Y Coordinate', fontsize=11, fontweight='bold')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(11, 11))

Z = griddata((x_values, y_values), z_values, (X, Y), method='linear')

# Plot the heatmap
plt.subplot(2, 1, 1)
im = plt.pcolormesh(X, Y, Z, cmap='viridis')
plt.colorbar(im, label='Z [mm]')
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Heatmap of XYZ',  fontsize=11, fontweight='bold')

# Overlay XY points on top of the heatmap
plt.scatter(x_values, y_values, color='brown', marker='o', label='XY Points')
plt.legend()

Z = griddata((x_values, y_values), corrected_z_values_y, (X, Y), method='linear')

# Plot the scatter plot
plt.subplot(2, 1, 2)
sc = plt.pcolormesh(X, Y, Z, cmap='viridis')
plt.colorbar(sc, label='Z [mm]')
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Corrected Heatmap of XYZ - Simultaneous Fit', fontsize=11, fontweight='bold')
# Overlay XY points on top of the heatmap
plt.scatter(x_values, y_values, color='brown', marker='o', label='XY Points')
plt.legend()


plt.tight_layout()
plt.show()

# %%
std_dev = np.std(Z, ddof=1)
RMS = round(std_dev, 6)
print("RMS Simultaneous Fit =", RMS)
# Out:
# RMS Simultaneous Fit = 0.00563

# %% [raw]
# Fitting a plane to a set of 3D points is a common technique used in planarity analysis. This technique is often employed in various fields such as computer vision, robotics, geomatics, and manufacturing to assess the flatness or planarity of a surface.
#
# The fitting of a plane involves finding the best-fitting plane that minimizes the sum of squared distances between the plane and the data points. This can be achieved using mathematical techniques such as least squares regression ddor principal component analysis (PCA).
#
# Once the plane is fitted to the data, various metrics can be calculated to assess the planarity, such as the root mean square (RMS) of the distances between the data points and the fitted plane, or the deviation of the data points from the plane.
#
# Overall, fitting a plane to the data provides a quantitative measure of planarity and can be a useful tool for quality control, surface inspection, and geometric analysis.

# %% [raw]
# The goal is to find the values of a and b that minimize the sum of the squared residuals. This is why it's called "least squares" regression.

# %%
def fit_plane(formatted_data):   
    # Extract X, Y, and Z coordinates from the formatted data 
    X = np.array([coords['X'] for _, coords in formatted_data])
    Y = np.array([coords['Y'] for _, coords in formatted_data])
    Z = np.array([coords['Z'] for _, coords in formatted_data])
    
    # Construct the design matrix contains the independent variables
    A = np.vstack((X, Y, np.ones_like(X))).T #stacking X, Y, and a column of ones (for the intercept term) vertically and transposing it. 
    #This design matrix is used in the least squares regression.
    
    # Perform least squares regression to find the plane parameters
    #params, _, _, _ = np.linalg.lstsq(A, Z, rcond=None) 
    params, residuals, rank, singular_values = np.linalg.lstsq(A, Z, rcond=None)

    #contains the coefficients of the plane equation (a, b, c) that minimize the sum of squared residuals.
    #assigned to _ to indicate that they're being ignored.
    
    # Extract plane parameters (coefficients of the plane equation: ax + by + c = z)
    a, b, c = params
    residuals = residuals  #the residual sum of squares, which represents the sum of squared differences between the observed and predicted values of Z
    singular_values = singular_values # the singular values of A
    return a, b, c, residuals, singular_values

a, b, c, residuals, singular_values = fit_plane(formatted_data)
print("Plane parameters: a =", a, ", b =", b, ", c =", c, ", residuals = ", residuals, ", singular values = ", singular_values)
# Out:
# Plane parameters: a = 8.332107843137257e-05 , b = -0.00015212025559186533 , c = 0.01147683753080918 , residuals =  [0.00594118] , singular values =  [1417.9454929  535.9294192    5.5710865]

# %%
# Visualize the fitted plane and original points
def visualize_plane_and_points(formatted_data, a, b, c, residuals, singular_values):
    X = np.array([coords['X'] for _, coords in formatted_data])
    Y = np.array([coords['Y'] for _, coords in formatted_data])
    Z = np.array([coords['Z'] for _, coords in formatted_data])
    
    # Create a meshgrid for X and Y coordinates
    X_grid, Y_grid = np.meshgrid(np.linspace(min(X), max(X), 10), np.linspace(min(Y), max(Y), 10))
    
    # Calculate Z values for the fitted plane
    Z_plane = a * X_grid + b * Y_grid + c

    # Plot the points
    fig = plt.figure(figsize=(20, 15))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(X, Y, Z, color='b', label='Original Points')
    
    # Plot the fitted plane
    ax.plot_surface(X_grid, Y_grid, Z_plane, alpha=0.5, color='r', label='Fitted Plane')
    
    # Set labels and title
    ax.set_xlabel('X [mm]', fontsize=14, fontweight='bold')
    ax.set_xlabel('X [mm]', fontsize=14, fontweight='bold')
    ax.set_ylabel('Y [mm]', fontsize=14, fontweight='bold')
    ax.set_zlabel('Z [mm]', fontsize=14, fontweight='bold')
    ax.set_title('Planarity Fitted Plane', fontsize=11, fontweight='bold')
    
    # Add legend
    ax.legend()
    
    # Show plot
    plt.show()

# %%
#a, b, c = fit_plane(formatted_data)
a, b, c, residuals, singular_values = fit_plane(formatted_data)
#visualize_plane_and_points(formatted_data, a, b, c)
visualize_plane_and_points(formatted_data, a, b, c, residuals, singular_values)

# %%
def calculate_planarity_metrics(formatted_data, a, b, c):
    # Extract X, Y, and Z coordinates from the formatted data
    X = np.array([coords['X'] for _, coords in formatted_data])
    Y = np.array([coords['Y'] for _, coords in formatted_data])
    Z = np.array([coords['Z'] for _, coords in formatted_data])
    
    # Calculate distances from points to the fitted plane
    distances = np.abs(a * X + b * Y - Z + c) / np.sqrt(a**2 + b**2 + 1)
    
    # Calculate RMS of the distances
    rms_distance = np.sqrt(np.mean(distances**2))
    
    # Calculate deviation of the points from the plane
    deviation = distances.mean()
    
    return rms_distance, deviation

# %%
rms_distance, deviation = calculate_planarity_metrics(formatted_data, a, b, c)
print("RMS Distance:", rms_distance) #the root mean square (RMS) of the distances between the data points and the fitted plane
print("Deviation:", deviation) #the deviation of the data points from the plane
# Out:
# RMS Distance: 0.005562701635648538
# Deviation: 0.004426017856387247

# %% [raw]
# It calculates the distances from each point to the fitted plane, then computes the RMS of these distances and the deviation of the points from the plane.

# %%
# Define the point IDs
point_4_4_id = '4,4'
point_4_13_id = '4,13'
point_13_4_id = '13,4'
point_13_13_id = '13,13'


# Find the XY coordinates corresponding to the specified point IDs
point_4_4_xy = None
point_4_13_xy = None
point_13_4_xy = None
point_13_13_xy = None

for point_id, coords in formatted_data:
    if point_id == point_4_4_id:
        point_4_4_xy = (coords['X'], coords['Y'])
    elif point_id == point_4_13_id:
        point_4_13_xy = (coords['X'], coords['Y'])
    elif point_id == point_13_4_id:
        point_13_4_xy = (coords['X'], coords['Y'])
    elif point_id == point_13_13_id:
        point_13_13_xy = (coords['X'], coords['Y'])

# Plot the heatmap of Z
plt.figure(figsize=(12, 6))
plt.pcolormesh(X, Y, Z, cmap='viridis')
plt.colorbar(label='Z [mm]')
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Heatmap of Z Measured', fontsize=11, fontweight='bold')

# Overlay XY points on top of the heatmap
plt.scatter(x_values, y_values, color='red', marker='o', label='XY Points')

## Connect specified points with lines
# plt.plot([point_4_13_xy[0], point_13_13_xy[0]], [point_4_13_xy[1], point_13_13_xy[1]], color='blue', linestyle='-', linewidth=2)
# plt.plot([point_13_4_xy[0], point_13_13_xy[0]], [point_13_4_xy[1], point_13_13_xy[1]], color='blue', linestyle='-', linewidth=2) #perpendicular
# plt.plot([point_4_4_xy[0], point_4_13_xy[0]], [point_4_4_xy[1], point_4_13_xy[1]], color='blue', linestyle='-', linewidth=2) #perpendicular
# plt.plot([point_4_4_xy[0], point_13_4_xy[0]], [point_4_4_xy[1], point_13_4_xy[1]], color='blue', linestyle='-', linewidth=2) #perpendicular

plt.legend()
plt.tight_layout()
plt.show()

# %%
x_values = np.array([coords['X'] for _, coords in formatted_data])
y_values = np.array([coords['Y'] for _, coords in formatted_data])
z_values = np.array([coords['Z'] for _, coords in formatted_data])

# Correct the Z values based on the fitted plane
corrected_z_values = z_values - (a * x_values + b * y_values + c)

# Create a grid for the heatmap
X, Y = np.meshgrid(np.linspace(min(x_values), max(x_values), 100),
                   np.linspace(min(y_values), max(y_values), 100))

# Interpolate the corrected Z values onto the grid
Z_corrected = griddata((x_values, y_values), corrected_z_values, (X, Y), method='linear')


# Plot the heatmap of corrected Z values
plt.figure(figsize=(10, 10))
plt.pcolormesh(X, Y, Z_corrected, cmap='viridis')
plt.colorbar(label='Corrected fit plane Z [mm]')
plt.xlabel('X [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Y [mm]', fontsize=14, fontweight='bold')
plt.title('Heatmap of Corrected Z Values - Fit Plane', fontsize=11, fontweight='bold')

# Overlay XY points on top of the heatmap
plt.scatter(x_values, y_values, color='red', marker='o', label='XY Points')

plt.legend()
plt.tight_layout()
plt.show()

# %%
# Flatten the 2D array Z_corrected into a 1D array
Z_corrected_flat = corrected_z_values.flatten()

# Plot the histogram of the corrected Z values
plt.figure(figsize=(12, 10))
plt.hist(Z_corrected_flat, bins=50, color='green', edgecolor='black', alpha=0.8)
# Add mean, median, and standard deviation lines
mean_value = np.mean(Z_corrected_flat)
median_value = np.median(Z_corrected_flat)
std_deviation = np.std(Z_corrected_flat)
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean_value:.2f}')
plt.axvline(median_value, color='blue', linestyle='dashed', linewidth=1, label=f'Median: {median_value:.2f}')
plt.axvline(mean_value + std_deviation, color='orange', linestyle='dashed', linewidth=1, label=f'Standard Deviation: {std_deviation:.2f}')
plt.axvline(mean_value - std_deviation, color='orange', linestyle='dashed', linewidth=1)
plt.xlabel('Corrected Z [mm]', fontsize=14, fontweight='bold')
plt.ylabel('Entries', fontsize=14, fontweight='bold')
plt.title('Histogram of Corrected Z Values - Fit plane', fontsize=11, fontweight='bold')
plt.legend()
plt.show()

# %%
X_test = np.column_stack((x_values, y_values, np.ones_like(x_values)))

# Fit linear regression model
model = LinearRegression().fit(X_test, z_values)

# Get the coefficients (normal vector) of the plane
normal_vector = model.coef_
intercept = model.intercept_

# Generate points on the plane for visualization
x_plane = np.linspace(min(x_values), max(x_values), 10)
y_plane = np.linspace(min(y_values), max(y_values), 10)
x_plane, y_plane = np.meshgrid(x_plane, y_plane)
z_plane = normal_vector[0] * x_plane + normal_vector[1] * y_plane + intercept

# Plot the original data points
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_values, y_values, z_values, c='b', marker='o', label='Data Points')

# Plot the plane
ax.plot_surface(x_plane, y_plane, z_plane, alpha=0.5)

ax.set_xlabel('X [mm]', fontsize=14, fontweight='bold')
ax.set_ylabel('Y [mm]', fontsize=14, fontweight='bold')
ax.set_zlabel('Z [mm]', fontsize=14, fontweight='bold')
ax.set_title('Plane Fitting')

plt.legend()
plt.show()
